# %%
# import zipfile

# f = zipfile.ZipFile("DRD_Split.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"DRD_Split_Cloud")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# # !pip install tensorflow-addons==0.18.0
# # !pip install scikit-learn
# !pip install seaborn

# %%
from tensorflow_addons.metrics import F1Score

# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

train_dir = '/root/DRD_Split_Cloud/DRD_Split/train'
test_dir = '/root/DRD_Split_Cloud/DRD_Split/test'

batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/DRD_Split_Cloud/DRD_Split/train/diabetic'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2708 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(64, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def simple_model_1(input_shape):
    inputs = Input(shape = input_shape)
    #Input convolution
    x = Conv2D(64, (3, 3), activation = 'leaky_relu',
               padding = 'same',kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)
    
    #First Dethwise Convolution
    x = Conv2D(64, (3, 3),  
               padding = 'same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)

    
    #Second convolutional layer
    x = Conv2D(32, (3, 3), 
               padding = 'same',kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)
    
    
    x = GlobalAveragePooling2D()(x)
    # outputs = Dense(num_classes, activation = 'softmax')(x)
    model_1 = Model(inputs, x)
    
    return model_1

def resnet_inception_simple(input_shape):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(32, (7, 7), strides=(1, 1), padding='same', activation='relu',
               kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual and Inception Blocks
    for filters in [32, 32, 64, 16]:
        # Residual Block
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x)
        x_r = BatchNormalization()(x_r)
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x_r)
        x_r = BatchNormalization()(x_r)

        # Inception Block
        branch_0 = Conv2D(96, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_0 = BatchNormalization()(branch_0)

        branch_1 = Conv2D(64, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_1 = BatchNormalization()(branch_1)
        branch_1 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_1)
        branch_1 = BatchNormalization()(branch_1)

        branch_2 = Conv2D(64, (1, 1), padding='same', activation='relu',
                          kernel_initializer='he_normal')(x)
        branch_2 = BatchNormalization()(branch_2)
        branch_2 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_2)
        branch_2 = BatchNormalization()(branch_2)
        x_i = concatenate([branch_0, branch_1,branch_2], axis = -1)
    
        # Make sure the number of filters after concatenation in x_i matches with x_r
        x_i = Conv2D(filters, (1, 1), padding = 'same', activation = 'relu')(x_i)
        x_i = BatchNormalization()(x_i)
        
        x_r = attention_block_2(x_r)
        x_i = attention_block_2(x_i)
        
        # Combine Residual and Inception Outputs
        x = Add()([x_r, x_i])
        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    # outputs = Dense(2, activation = 'softmax')(x)
    model = Model(inputs, x)
    
    return model

def build_ensemble_model(input_shape):
    inputs = Input(shape = input_shape)

    model_1 = simple_model_1(input_shape)
    output1 = model_1(inputs) 
    
    IR_output = resnet_inception_simple(input_shape)(inputs)
    
    combined_result = concatenate([output1, IR_output])
    
    combined_result = Dropout(0.3)(combined_result)
    
    # 最后的分类层
    outputs = Dense(2, activation='softmax')(combined_result)
    model = Model(inputs = inputs, outputs=outputs)
    
    return model

# %%
ensemble_model = build_ensemble_model(input_shape)
ensemble_model.summary()
# Out:
# 2023-12-10 10:36:50.300979: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-10 10:36:50.859789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  model (Functional)             (None, 32)           150371      ['input_1[0][0]']
#
#  model_1 (Functional)           (None, 16)           489720      ['input_1[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 48)           0           ['model[0][0]',
#                                                                   'model_1[0][0]']
#
#  dropout (Dropout)              (None, 48)           0           ['concatenate_4[0][0]']
#
#  dense (Dense)                  (None, 2)            98          ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 640,189
# Trainable params: 636,637
# Non-trainable params: 3,552
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


ensemble_model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=[
        'accuracy', 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'macro')
    ]
)
lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)
# early_stopping = EarlyStopping(monitor='val_loss', 
#                                patience=20, verbose=1, 
#                                restore_best_weights=True)

# %%
history = ensemble_model.fit(train_generator, epochs = 80, validation_data=(validation_generator), callbacks = [lr_reduction])
# Out:
# Epoch 1/80
# 2023-12-10 10:36:58.050874: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-10 10:37:00.304843: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 85/85 [==============================] - 40s 368ms/step - loss: 0.3336 - accuracy: 0.8682 - precision: 0.8682 - recall: 0.8682 - auc: 0.9341 - f1_score: 0.8681 - val_loss: 0.7752 - val_accuracy: 0.5074 - val_precision: 0.5074 - val_recall: 0.5074 - val_auc: 0.5021 - val_f1_score: 0.3366 - lr: 0.0010
# Epoch 2/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.2657 - accuracy: 0.9084 - precision: 0.9084 - recall: 0.9084 - auc: 0.9561 - f1_score: 0.9084 - val_loss: 0.7707 - val_accuracy: 0.5074 - val_precision: 0.5074 - val_recall: 0.5074 - val_auc: 0.5720 - val_f1_score: 0.3366 - lr: 0.0010
# Epoch 3/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.2375 - accuracy: 0.9106 - precision: 0.9106 - recall: 0.9106 - auc: 0.9643 - f1_score: 0.9106 - val_loss: 0.5097 - val_accuracy: 0.7450 - val_precision: 0.7450 - val_recall: 0.7450 - val_auc: 0.8332 - val_f1_score: 0.7431 - lr: 0.0010
# Epoch 4/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.2338 - accuracy: 0.9180 - precision: 0.9180 - recall: 0.9180 - auc: 0.9655 - f1_score: 0.9180 - val_loss: 0.4935 - val_accuracy: 0.7376 - val_precision: 0.7376 - val_recall: 0.7376 - val_auc: 0.8551 - val_f1_score: 0.7190 - lr: 0.0010
# Epoch 5/80
# 85/85 [==============================] - 29s 345ms/step - loss: 0.2205 - accuracy: 0.9250 - precision: 0.9250 - recall: 0.9250 - auc: 0.9683 - f1_score: 0.9250 - val_loss: 0.9648 - val_accuracy: 0.5817 - val_precision: 0.5817 - val_recall: 0.5817 - val_auc: 0.6599 - val_f1_score: 0.5273 - lr: 0.0010
# Epoch 6/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.2079 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9713 - f1_score: 0.9328 - val_loss: 0.3558 - val_accuracy: 0.8515 - val_precision: 0.8515 - val_recall: 0.8515 - val_auc: 0.9220 - val_f1_score: 0.8515 - lr: 0.0010
# Epoch 7/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.1879 - accuracy: 0.9383 - precision: 0.9383 - recall: 0.9383 - auc: 0.9764 - f1_score: 0.9383 - val_loss: 0.5435 - val_accuracy: 0.7252 - val_precision: 0.7252 - val_recall: 0.7252 - val_auc: 0.8048 - val_f1_score: 0.7125 - lr: 0.0010
# Epoch 8/80
# 85/85 [==============================] - 29s 344ms/step - loss: 0.2190 - accuracy: 0.9265 - precision: 0.9265 - recall: 0.9265 - auc: 0.9695 - f1_score: 0.9265 - val_loss: 0.1696 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9874 - val_f1_score: 0.9480 - lr: 0.0010
# Epoch 9/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.1948 - accuracy: 0.9332 - precision: 0.9332 - recall: 0.9332 - auc: 0.9748 - f1_score: 0.9332 - val_loss: 0.1497 - val_accuracy: 0.9431 - val_precision: 0.9431 - val_recall: 0.9431 - val_auc: 0.9871 - val_f1_score: 0.9430 - lr: 0.0010
# Epoch 10/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.1725 - accuracy: 0.9409 - precision: 0.9409 - recall: 0.9409 - auc: 0.9796 - f1_score: 0.9409 - val_loss: 0.5766 - val_accuracy: 0.6757 - val_precision: 0.6757 - val_recall: 0.6757 - val_auc: 0.7790 - val_f1_score: 0.6414 - lr: 0.0010
# Epoch 11/80
# 85/85 [==============================] - 29s 345ms/step - loss: 0.1735 - accuracy: 0.9453 - precision: 0.9453 - recall: 0.9453 - auc: 0.9790 - f1_score: 0.9453 - val_loss: 0.2426 - val_accuracy: 0.9059 - val_precision: 0.9059 - val_recall: 0.9059 - val_auc: 0.9659 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 12/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.1722 - accuracy: 0.9409 - precision: 0.9409 - recall: 0.9409 - auc: 0.9804 - f1_score: 0.9409 - val_loss: 0.4144 - val_accuracy: 0.8391 - val_precision: 0.8391 - val_recall: 0.8391 - val_auc: 0.9075 - val_f1_score: 0.8369 - lr: 0.0010
# Epoch 13/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.1581 - accuracy: 0.9472 - precision: 0.9472 - recall: 0.9472 - auc: 0.9838 - f1_score: 0.9472 - val_loss: 0.2833 - val_accuracy: 0.8960 - val_precision: 0.8960 - val_recall: 0.8960 - val_auc: 0.9565 - val_f1_score: 0.8954 - lr: 0.0010
# Epoch 14/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.1555 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9835 - f1_score: 0.9505 - val_loss: 0.1059 - val_accuracy: 0.9604 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9932 - val_f1_score: 0.9604 - lr: 0.0010
# Epoch 15/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.1391 - accuracy: 0.9557 - precision: 0.9557 - recall: 0.9557 - auc: 0.9869 - f1_score: 0.9557 - val_loss: 0.0838 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9947 - val_f1_score: 0.9777 - lr: 0.0010
# Epoch 16/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.1489 - accuracy: 0.9520 - precision: 0.9520 - recall: 0.9520 - auc: 0.9843 - f1_score: 0.9520 - val_loss: 0.1619 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9888 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 17/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.1427 - accuracy: 0.9527 - precision: 0.9527 - recall: 0.9527 - auc: 0.9862 - f1_score: 0.9527 - val_loss: 0.3782 - val_accuracy: 0.8292 - val_precision: 0.8292 - val_recall: 0.8292 - val_auc: 0.9212 - val_f1_score: 0.8255 - lr: 0.0010
# Epoch 18/80
# 85/85 [==============================] - 30s 346ms/step - loss: 0.1303 - accuracy: 0.9579 - precision: 0.9579 - recall: 0.9579 - auc: 0.9884 - f1_score: 0.9579 - val_loss: 0.1451 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9871 - val_f1_score: 0.9480 - lr: 0.0010
# Epoch 19/80
# 85/85 [==============================] - 29s 344ms/step - loss: 0.1311 - accuracy: 0.9579 - precision: 0.9579 - recall: 0.9579 - auc: 0.9879 - f1_score: 0.9579 - val_loss: 0.5182 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8449 - val_f1_score: 0.7366 - lr: 0.0010
# Epoch 20/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.1255 - accuracy: 0.9597 - precision: 0.9597 - recall: 0.9597 - auc: 0.9891 - f1_score: 0.9597 - val_loss: 0.3051 - val_accuracy: 0.8688 - val_precision: 0.8688 - val_recall: 0.8688 - val_auc: 0.9440 - val_f1_score: 0.8680 - lr: 0.0010
# Epoch 21/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.1229 - accuracy: 0.9568 - precision: 0.9568 - recall: 0.9568 - auc: 0.9900 - f1_score: 0.9568 - val_loss: 0.1350 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9904 - val_f1_score: 0.9628 - lr: 0.0010
# Epoch 22/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.1199 - accuracy: 0.9634 - precision: 0.9634 - recall: 0.9634 - auc: 0.9894 - f1_score: 0.9634 - val_loss: 0.0883 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9944 - val_f1_score: 0.9728 - lr: 0.0010
# Epoch 23/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.1172 - accuracy: 0.9561 - precision: 0.9561 - recall: 0.9561 - auc: 0.9907 - f1_score: 0.9561 - val_loss: 0.1407 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_auc: 0.9887 - val_f1_score: 0.9406 - lr: 0.0010
# Epoch 24/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.1207 - accuracy: 0.9631 - precision: 0.9631 - recall: 0.9631 - auc: 0.9890 - f1_score: 0.9631 - val_loss: 0.1076 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9939 - val_f1_score: 0.9678 - lr: 0.0010
# Epoch 25/80
# 85/85 [==============================] - ETA: 0s - loss: 0.1061 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9919 - f1_score: 0.9686
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 85/85 [==============================] - 29s 341ms/step - loss: 0.1061 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9919 - f1_score: 0.9686 - val_loss: 0.0995 - val_accuracy: 0.9604 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9930 - val_f1_score: 0.9604 - lr: 0.0010
# Epoch 26/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.1117 - accuracy: 0.9657 - precision: 0.9657 - recall: 0.9657 - auc: 0.9914 - f1_score: 0.9657 - val_loss: 0.0775 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9954 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 27/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.1038 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9922 - f1_score: 0.9642 - val_loss: 0.0676 - val_accuracy: 0.9926 - val_precision: 0.9926 - val_recall: 0.9926 - val_auc: 0.9956 - val_f1_score: 0.9926 - lr: 1.0000e-04
# Epoch 28/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.1037 - accuracy: 0.9668 - precision: 0.9668 - recall: 0.9668 - auc: 0.9923 - f1_score: 0.9668 - val_loss: 0.0811 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9950 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 29/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0943 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712 - auc: 0.9933 - f1_score: 0.9712 - val_loss: 0.0845 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9942 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 30/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0925 - accuracy: 0.9716 - precision: 0.9716 - recall: 0.9716 - auc: 0.9934 - f1_score: 0.9716 - val_loss: 0.0731 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9954 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 31/80
# 85/85 [==============================] - 29s 344ms/step - loss: 0.0937 - accuracy: 0.9679 - precision: 0.9679 - recall: 0.9679 - auc: 0.9935 - f1_score: 0.9679 - val_loss: 0.0685 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9956 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 32/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0830 - accuracy: 0.9760 - precision: 0.9760 - recall: 0.9760 - auc: 0.9949 - f1_score: 0.9760 - val_loss: 0.0799 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9952 - val_f1_score: 0.9876 - lr: 1.0000e-04
# Epoch 33/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0875 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712 - auc: 0.9943 - f1_score: 0.9712 - val_loss: 0.0831 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9953 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 34/80
# 85/85 [==============================] - 29s 345ms/step - loss: 0.0904 - accuracy: 0.9716 - precision: 0.9716 - recall: 0.9716 - auc: 0.9932 - f1_score: 0.9716 - val_loss: 0.0788 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9954 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 35/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0963 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9927 - f1_score: 0.9675 - val_loss: 0.0817 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9945 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 36/80
# 85/85 [==============================] - 29s 345ms/step - loss: 0.0854 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712 - auc: 0.9948 - f1_score: 0.9712 - val_loss: 0.0743 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9956 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 37/80
# 85/85 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9767 - precision: 0.9767 - recall: 0.9767 - auc: 0.9948 - f1_score: 0.9767
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0807 - accuracy: 0.9767 - precision: 0.9767 - recall: 0.9767 - auc: 0.9948 - f1_score: 0.9767 - val_loss: 0.0797 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9946 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 38/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0819 - accuracy: 0.9694 - precision: 0.9694 - recall: 0.9694 - auc: 0.9954 - f1_score: 0.9693 - val_loss: 0.0769 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9951 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 39/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0850 - accuracy: 0.9697 - precision: 0.9697 - recall: 0.9697 - auc: 0.9950 - f1_score: 0.9697 - val_loss: 0.0799 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9952 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 40/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0788 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - auc: 0.9951 - f1_score: 0.9749 - val_loss: 0.0760 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9950 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 41/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0764 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9953 - f1_score: 0.9756 - val_loss: 0.0774 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9953 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 42/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0814 - accuracy: 0.9734 - precision: 0.9734 - recall: 0.9734 - auc: 0.9951 - f1_score: 0.9734 - val_loss: 0.0780 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9957 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 43/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0758 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9960 - f1_score: 0.9745 - val_loss: 0.0890 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9932 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 44/80
# 85/85 [==============================] - 29s 345ms/step - loss: 0.0726 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9961 - f1_score: 0.9771 - val_loss: 0.0722 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9957 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 45/80
# 85/85 [==============================] - 29s 344ms/step - loss: 0.0826 - accuracy: 0.9723 - precision: 0.9723 - recall: 0.9723 - auc: 0.9949 - f1_score: 0.9723 - val_loss: 0.0688 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9955 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 46/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0790 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - auc: 0.9953 - f1_score: 0.9749 - val_loss: 0.0697 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9959 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 47/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0824 - accuracy: 0.9723 - precision: 0.9723 - recall: 0.9723 - auc: 0.9949 - f1_score: 0.9723 - val_loss: 0.0655 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9962 - val_f1_score: 0.9876 - lr: 1.0000e-05
# Epoch 48/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0797 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9954 - f1_score: 0.9753 - val_loss: 0.0762 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9957 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 49/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0801 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9944 - f1_score: 0.9745 - val_loss: 0.0742 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9943 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 50/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0760 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9959 - f1_score: 0.9756 - val_loss: 0.0782 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9951 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 51/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0746 - accuracy: 0.9742 - precision: 0.9742 - recall: 0.9742 - auc: 0.9963 - f1_score: 0.9741 - val_loss: 0.0648 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9957 - val_f1_score: 0.9876 - lr: 1.0000e-05
# Epoch 52/80
# 85/85 [==============================] - 30s 348ms/step - loss: 0.0713 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9964 - f1_score: 0.9764 - val_loss: 0.0747 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9952 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 53/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0769 - accuracy: 0.9760 - precision: 0.9760 - recall: 0.9760 - auc: 0.9953 - f1_score: 0.9760 - val_loss: 0.0824 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9949 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 54/80
# 85/85 [==============================] - 30s 346ms/step - loss: 0.0807 - accuracy: 0.9723 - precision: 0.9723 - recall: 0.9723 - auc: 0.9946 - f1_score: 0.9723 - val_loss: 0.0958 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9944 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 55/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.0768 - accuracy: 0.9734 - precision: 0.9734 - recall: 0.9734 - auc: 0.9958 - f1_score: 0.9734 - val_loss: 0.0752 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9956 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 56/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.0765 - accuracy: 0.9727 - precision: 0.9727 - recall: 0.9727 - auc: 0.9960 - f1_score: 0.9727 - val_loss: 0.0714 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9954 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 57/80
# 85/85 [==============================] - 29s 344ms/step - loss: 0.0773 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9952 - f1_score: 0.9730 - val_loss: 0.0773 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9958 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 58/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.0739 - accuracy: 0.9723 - precision: 0.9723 - recall: 0.9723 - auc: 0.9961 - f1_score: 0.9723 - val_loss: 0.0744 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9959 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 59/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.0811 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9949 - f1_score: 0.9753 - val_loss: 0.0727 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9947 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 60/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0760 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9957 - f1_score: 0.9753 - val_loss: 0.0681 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9953 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 61/80
# 85/85 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9942 - f1_score: 0.9730
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1e-05.
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0817 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9942 - f1_score: 0.9730 - val_loss: 0.0833 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9954 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 62/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0708 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9962 - f1_score: 0.9756 - val_loss: 0.0740 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9957 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 63/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.0865 - accuracy: 0.9705 - precision: 0.9705 - recall: 0.9705 - auc: 0.9945 - f1_score: 0.9705 - val_loss: 0.0646 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9961 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 64/80
# 85/85 [==============================] - 29s 345ms/step - loss: 0.0667 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9972 - f1_score: 0.9753 - val_loss: 0.0736 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9954 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 65/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0662 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9969 - f1_score: 0.9771 - val_loss: 0.0860 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9948 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 66/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0747 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9962 - f1_score: 0.9730 - val_loss: 0.0684 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9961 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 67/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0776 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9958 - f1_score: 0.9730 - val_loss: 0.0868 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9923 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 68/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.0763 - accuracy: 0.9767 - precision: 0.9767 - recall: 0.9767 - auc: 0.9958 - f1_score: 0.9767 - val_loss: 0.0960 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9935 - val_f1_score: 0.9703 - lr: 1.0000e-05
# Epoch 69/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.0721 - accuracy: 0.9742 - precision: 0.9742 - recall: 0.9742 - auc: 0.9965 - f1_score: 0.9741 - val_loss: 0.0900 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9945 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 70/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0768 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - auc: 0.9955 - f1_score: 0.9749 - val_loss: 0.0736 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9957 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 71/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0786 - accuracy: 0.9719 - precision: 0.9719 - recall: 0.9719 - auc: 0.9954 - f1_score: 0.9719 - val_loss: 0.0771 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9947 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 72/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.0735 - accuracy: 0.9778 - precision: 0.9778 - recall: 0.9778 - auc: 0.9955 - f1_score: 0.9778 - val_loss: 0.0637 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9957 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 73/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0695 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9967 - f1_score: 0.9771 - val_loss: 0.0875 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9943 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 74/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0789 - accuracy: 0.9719 - precision: 0.9719 - recall: 0.9719 - auc: 0.9955 - f1_score: 0.9719 - val_loss: 0.0686 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9956 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 75/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0763 - accuracy: 0.9742 - precision: 0.9742 - recall: 0.9742 - auc: 0.9962 - f1_score: 0.9741 - val_loss: 0.0675 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9960 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 76/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0773 - accuracy: 0.9738 - precision: 0.9738 - recall: 0.9738 - auc: 0.9955 - f1_score: 0.9738 - val_loss: 0.0767 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9954 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 77/80
# 85/85 [==============================] - 29s 343ms/step - loss: 0.0747 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - auc: 0.9960 - f1_score: 0.9749 - val_loss: 0.0567 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9960 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 78/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0702 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9965 - f1_score: 0.9764 - val_loss: 0.0844 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9946 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 79/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0707 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9968 - f1_score: 0.9756 - val_loss: 0.0827 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9949 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 80/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0793 - accuracy: 0.9719 - precision: 0.9719 - recall: 0.9719 - auc: 0.9946 - f1_score: 0.9719 - val_loss: 0.0735 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9949 - val_f1_score: 0.9876 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = ensemble_model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 1s 36ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9797711407467505
# F1-Score for each class: [0.98018018 0.9793621 ]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9775280898876404
# specificity: 0.9819494584837545

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = ensemble_model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 17/17 [==============================] - 1s 36ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = ensemble_model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 18/18 [==============================] - 2s 87ms/step - loss: 0.0768 - accuracy: 0.9800 - precision: 0.9800 - recall: 0.9800 - auc: 0.9953 - f1_score: 0.9800
# Test loss: 0.07679533213376999
# Test accuracy: 0.9800000190734863
# Test precision: 0.9800000190734863
# Test recall: 0.9800000190734863
# Test AUC: 0.9953189492225647
# Test F1 Score: 0.9799946546554565

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = ensemble_model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 17/17 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       277
#            1       0.98      0.98      0.98       267
#
#     accuracy                           0.98       544
#    macro avg       0.98      0.98      0.98       544
# weighted avg       0.98      0.98      0.98       544

# %%
import pandas as pd


# Generate a classification report (replace this with your actual data)
report = classification_report(all_true_labels, y_pred_labels, output_dict=True)

# Convert to DataFrame
report_df = pd.DataFrame(report).transpose()

# Drop the 'support' column, as it's not suitable for the heatmap
report_df = report_df.drop(columns=['support'])

# Draw the heatmap with the default colormap
plt.figure(figsize=(10, 6))
sns.heatmap(report_df, annot=True, cbar=False)
plt.title("Classification Report")
plt.show()

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del resnet_inception_simple


from numba import cuda

cuda.select_device(0)
cuda.close()
