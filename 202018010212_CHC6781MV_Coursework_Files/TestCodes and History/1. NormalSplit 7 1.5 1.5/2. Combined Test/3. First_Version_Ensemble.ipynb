# %%
# import zipfile

# f = zipfile.ZipFile("DRD_Split.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"DRD_Split_Cloud")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# # !pip install tensorflow-addons==0.18.0
# # !pip install scikit-learn
# !pip install seaborn

# %%
from tensorflow_addons.metrics import F1Score

# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

train_dir = '/root/DRD_Split_Cloud/DRD_Split/train'
test_dir = '/root/DRD_Split_Cloud/DRD_Split/test'

batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/DRD_Split_Cloud/DRD_Split/train/diabetic'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2708 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
def simple_model_1(input_shape):
    inputs = Input(shape = input_shape)
    #Input convolution
    x = Conv2D(64, (3, 3), activation = 'leaky_relu',
               padding = 'same',kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D(2, 2)(x)
    
    #First Dethwise Convolution
    x = Conv2D(64, (3, 3),  
               padding = 'same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(2, 2)(x)

    
    #Second convolutional layer
    x = Conv2D(32, (3, 3), 
               padding = 'same',kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(2, 2)(x)
    
    
    x = GlobalAveragePooling2D()(x)
    # outputs = Dense(num_classes, activation = 'softmax')(x)
    model_1 = Model(inputs, x)
    
    return model_1

def resnet_inception_simple(input_shape):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(32, (7, 7), strides=(1, 1), padding='same', activation='relu',
               kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual and Inception Blocks
    for filters in [32, 32, 64, 32]:
        # Residual Block
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x)
        x_r = BatchNormalization()(x_r)
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x_r)
        x_r = BatchNormalization()(x_r)

        # Inception Block
        branch_0 = Conv2D(96, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_0 = BatchNormalization()(branch_0)

        branch_1 = Conv2D(64, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_1 = BatchNormalization()(branch_1)
        branch_1 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_1)
        branch_1 = BatchNormalization()(branch_1)

        branch_2 = Conv2D(128, (1, 1), padding='same', activation='relu',
                          kernel_initializer='he_normal')(x)
        branch_2 = BatchNormalization()(branch_2)
        branch_2 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_2)
        branch_2 = BatchNormalization()(branch_2)
        x_i = concatenate([branch_0, branch_1,branch_2], axis = -1)
    
        # Make sure the number of filters after concatenation in x_i matches with x_r
        x_i = Conv2D(filters, (1, 1), padding = 'same', activation = 'relu')(x_i)
        x_i = BatchNormalization()(x_i)

        # Combine Residual and Inception Outputs
        x = Add()([x_r, x_i])
        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    # outputs = Dense(2, activation = 'softmax')(x)
    model = Model(inputs, x)
    
    return model

def build_ensemble_model(input_shape):
    inputs = Input(shape = input_shape)

    model_1 = simple_model_1(input_shape)
    output1 = model_1(inputs) 
    
    IR_output = resnet_inception_simple(input_shape)(inputs)
    
    combined_result = concatenate([output1, IR_output])
    
    combined_result = Dropout(0.3)(combined_result)
    
    # 最后的分类层
    outputs = Dense(2, activation='softmax')(combined_result)
    model = Model(inputs = inputs, outputs=outputs)
    
    return model

# %%
ensemble_model = build_ensemble_model(input_shape)
ensemble_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  model_1 (Functional)           (None, 32)           57824       ['input_3[0][0]']
#
#  model_2 (Functional)           (None, 32)           426976      ['input_3[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 64)           0           ['model_1[0][0]',
#                                                                   'model_2[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['concatenate_12[0][0]']
#
#  dense (Dense)                  (None, 2)            130         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 484,930
# Trainable params: 480,770
# Non-trainable params: 4,160
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


ensemble_model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=[
        'accuracy', 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'macro')
    ]
)
lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)
# early_stopping = EarlyStopping(monitor='val_loss', 
#                                patience=20, verbose=1, 
#                                restore_best_weights=True)

# %%
history = ensemble_model.fit(train_generator, epochs = 80, validation_data=(validation_generator), callbacks = [lr_reduction])
# Out:
# Epoch 1/80
# 2023-12-10 09:23:03.294235: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-10 09:23:05.154741: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 85/85 [==============================] - 37s 356ms/step - loss: 0.4338 - accuracy: 0.8394 - precision: 0.8394 - recall: 0.8394 - auc: 0.9097 - f1_score: 0.8394 - val_loss: 1.7792 - val_accuracy: 0.5074 - val_precision: 0.5074 - val_recall: 0.5074 - val_auc: 0.6051 - val_f1_score: 0.3366 - lr: 0.0010
# Epoch 2/80
# 85/85 [==============================] - 28s 334ms/step - loss: 0.2974 - accuracy: 0.8959 - precision: 0.8959 - recall: 0.8959 - auc: 0.9508 - f1_score: 0.8958 - val_loss: 1.4912 - val_accuracy: 0.5149 - val_precision: 0.5149 - val_recall: 0.5149 - val_auc: 0.5326 - val_f1_score: 0.3531 - lr: 0.0010
# Epoch 3/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.2565 - accuracy: 0.9073 - precision: 0.9073 - recall: 0.9073 - auc: 0.9616 - f1_score: 0.9073 - val_loss: 1.7677 - val_accuracy: 0.5099 - val_precision: 0.5099 - val_recall: 0.5099 - val_auc: 0.5666 - val_f1_score: 0.3422 - lr: 0.0010
# Epoch 4/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.2157 - accuracy: 0.9217 - precision: 0.9217 - recall: 0.9217 - auc: 0.9704 - f1_score: 0.9217 - val_loss: 2.6129 - val_accuracy: 0.5149 - val_precision: 0.5149 - val_recall: 0.5149 - val_auc: 0.5471 - val_f1_score: 0.3531 - lr: 0.0010
# Epoch 5/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.2108 - accuracy: 0.9210 - precision: 0.9210 - recall: 0.9210 - auc: 0.9723 - f1_score: 0.9210 - val_loss: 1.4957 - val_accuracy: 0.5767 - val_precision: 0.5767 - val_recall: 0.5767 - val_auc: 0.6481 - val_f1_score: 0.4895 - lr: 0.0010
# Epoch 6/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.1834 - accuracy: 0.9357 - precision: 0.9357 - recall: 0.9357 - auc: 0.9783 - f1_score: 0.9357 - val_loss: 0.2663 - val_accuracy: 0.8985 - val_precision: 0.8985 - val_recall: 0.8985 - val_auc: 0.9717 - val_f1_score: 0.8983 - lr: 0.0010
# Epoch 7/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1566 - accuracy: 0.9465 - precision: 0.9465 - recall: 0.9465 - auc: 0.9836 - f1_score: 0.9464 - val_loss: 0.4733 - val_accuracy: 0.7723 - val_precision: 0.7723 - val_recall: 0.7723 - val_auc: 0.8866 - val_f1_score: 0.7660 - lr: 0.0010
# Epoch 8/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1501 - accuracy: 0.9509 - precision: 0.9509 - recall: 0.9509 - auc: 0.9845 - f1_score: 0.9509 - val_loss: 0.2054 - val_accuracy: 0.9084 - val_precision: 0.9084 - val_recall: 0.9084 - val_auc: 0.9758 - val_f1_score: 0.9080 - lr: 0.0010
# Epoch 9/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.1573 - accuracy: 0.9450 - precision: 0.9450 - recall: 0.9450 - auc: 0.9834 - f1_score: 0.9450 - val_loss: 0.1946 - val_accuracy: 0.9183 - val_precision: 0.9183 - val_recall: 0.9183 - val_auc: 0.9764 - val_f1_score: 0.9182 - lr: 0.0010
# Epoch 10/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1475 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - auc: 0.9844 - f1_score: 0.9524 - val_loss: 0.1129 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9952 - val_f1_score: 0.9629 - lr: 0.0010
# Epoch 11/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1407 - accuracy: 0.9531 - precision: 0.9531 - recall: 0.9531 - auc: 0.9870 - f1_score: 0.9531 - val_loss: 0.1172 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9909 - val_f1_score: 0.9579 - lr: 0.0010
# Epoch 12/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1232 - accuracy: 0.9609 - precision: 0.9609 - recall: 0.9609 - auc: 0.9891 - f1_score: 0.9609 - val_loss: 0.1281 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9889 - val_f1_score: 0.9479 - lr: 0.0010
# Epoch 13/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.1451 - accuracy: 0.9531 - precision: 0.9531 - recall: 0.9531 - auc: 0.9855 - f1_score: 0.9531 - val_loss: 1.1654 - val_accuracy: 0.5916 - val_precision: 0.5916 - val_recall: 0.5916 - val_auc: 0.7415 - val_f1_score: 0.5189 - lr: 0.0010
# Epoch 14/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1228 - accuracy: 0.9631 - precision: 0.9631 - recall: 0.9631 - auc: 0.9890 - f1_score: 0.9631 - val_loss: 0.2030 - val_accuracy: 0.9208 - val_precision: 0.9208 - val_recall: 0.9208 - val_auc: 0.9747 - val_f1_score: 0.9202 - lr: 0.0010
# Epoch 15/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.1228 - accuracy: 0.9579 - precision: 0.9579 - recall: 0.9579 - auc: 0.9895 - f1_score: 0.9579 - val_loss: 0.2548 - val_accuracy: 0.8886 - val_precision: 0.8886 - val_recall: 0.8886 - val_auc: 0.9654 - val_f1_score: 0.8879 - lr: 0.0010
# Epoch 16/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1271 - accuracy: 0.9531 - precision: 0.9531 - recall: 0.9531 - auc: 0.9888 - f1_score: 0.9531 - val_loss: 0.1923 - val_accuracy: 0.9134 - val_precision: 0.9134 - val_recall: 0.9134 - val_auc: 0.9779 - val_f1_score: 0.9130 - lr: 0.0010
# Epoch 17/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1127 - accuracy: 0.9616 - precision: 0.9616 - recall: 0.9616 - auc: 0.9906 - f1_score: 0.9616 - val_loss: 0.1490 - val_accuracy: 0.9431 - val_precision: 0.9431 - val_recall: 0.9431 - val_auc: 0.9866 - val_f1_score: 0.9431 - lr: 0.0010
# Epoch 18/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.1330 - accuracy: 0.9590 - precision: 0.9590 - recall: 0.9590 - auc: 0.9880 - f1_score: 0.9590 - val_loss: 0.1069 - val_accuracy: 0.9505 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9937 - val_f1_score: 0.9505 - lr: 0.0010
# Epoch 19/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.1234 - accuracy: 0.9579 - precision: 0.9579 - recall: 0.9579 - auc: 0.9892 - f1_score: 0.9579 - val_loss: 0.4545 - val_accuracy: 0.7649 - val_precision: 0.7649 - val_recall: 0.7649 - val_auc: 0.8979 - val_f1_score: 0.7534 - lr: 0.0010
# Epoch 20/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1157 - accuracy: 0.9631 - precision: 0.9631 - recall: 0.9631 - auc: 0.9905 - f1_score: 0.9631 - val_loss: 0.1210 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9895 - val_f1_score: 0.9529 - lr: 0.0010
# Epoch 21/80
# 85/85 [==============================] - 28s 334ms/step - loss: 0.1154 - accuracy: 0.9601 - precision: 0.9601 - recall: 0.9601 - auc: 0.9908 - f1_score: 0.9601 - val_loss: 0.0911 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9934 - val_f1_score: 0.9728 - lr: 0.0010
# Epoch 22/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1088 - accuracy: 0.9634 - precision: 0.9634 - recall: 0.9634 - auc: 0.9917 - f1_score: 0.9634 - val_loss: 0.4752 - val_accuracy: 0.7723 - val_precision: 0.7723 - val_recall: 0.7723 - val_auc: 0.8861 - val_f1_score: 0.7586 - lr: 0.0010
# Epoch 23/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.1230 - accuracy: 0.9572 - precision: 0.9572 - recall: 0.9572 - auc: 0.9895 - f1_score: 0.9572 - val_loss: 0.3134 - val_accuracy: 0.8886 - val_precision: 0.8886 - val_recall: 0.8886 - val_auc: 0.9452 - val_f1_score: 0.8877 - lr: 0.0010
# Epoch 24/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.1173 - accuracy: 0.9609 - precision: 0.9609 - recall: 0.9609 - auc: 0.9901 - f1_score: 0.9609 - val_loss: 0.1007 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9929 - val_f1_score: 0.9529 - lr: 0.0010
# Epoch 25/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0988 - accuracy: 0.9679 - precision: 0.9679 - recall: 0.9679 - auc: 0.9932 - f1_score: 0.9679 - val_loss: 0.3085 - val_accuracy: 0.9010 - val_precision: 0.9010 - val_recall: 0.9010 - val_auc: 0.9537 - val_f1_score: 0.9004 - lr: 0.0010
# Epoch 26/80
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0927 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9935 - f1_score: 0.9675 - val_loss: 0.1749 - val_accuracy: 0.9233 - val_precision: 0.9233 - val_recall: 0.9233 - val_auc: 0.9806 - val_f1_score: 0.9232 - lr: 0.0010
# Epoch 27/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1035 - accuracy: 0.9657 - precision: 0.9657 - recall: 0.9657 - auc: 0.9916 - f1_score: 0.9657 - val_loss: 0.1031 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9914 - val_f1_score: 0.9727 - lr: 0.0010
# Epoch 28/80
# 85/85 [==============================] - 28s 334ms/step - loss: 0.1025 - accuracy: 0.9708 - precision: 0.9708 - recall: 0.9708 - auc: 0.9913 - f1_score: 0.9708 - val_loss: 0.0914 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9934 - val_f1_score: 0.9678 - lr: 0.0010
# Epoch 29/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0996 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712 - auc: 0.9925 - f1_score: 0.9712 - val_loss: 0.0958 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9936 - val_f1_score: 0.9727 - lr: 0.0010
# Epoch 30/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0983 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9926 - f1_score: 0.9675 - val_loss: 0.0894 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9941 - val_f1_score: 0.9728 - lr: 0.0010
# Epoch 31/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0878 - accuracy: 0.9708 - precision: 0.9708 - recall: 0.9708 - auc: 0.9949 - f1_score: 0.9708 - val_loss: 0.1225 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9901 - val_f1_score: 0.9579 - lr: 0.0010
# Epoch 32/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0919 - accuracy: 0.9701 - precision: 0.9701 - recall: 0.9701 - auc: 0.9940 - f1_score: 0.9701 - val_loss: 0.1065 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9906 - val_f1_score: 0.9728 - lr: 0.0010
# Epoch 33/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0859 - accuracy: 0.9727 - precision: 0.9727 - recall: 0.9727 - auc: 0.9939 - f1_score: 0.9727 - val_loss: 0.1220 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9897 - val_f1_score: 0.9629 - lr: 0.0010
# Epoch 34/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0886 - accuracy: 0.9719 - precision: 0.9719 - recall: 0.9719 - auc: 0.9943 - f1_score: 0.9719 - val_loss: 0.0813 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9952 - val_f1_score: 0.9777 - lr: 0.0010
# Epoch 35/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0930 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9934 - f1_score: 0.9730 - val_loss: 0.1430 - val_accuracy: 0.9505 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9851 - val_f1_score: 0.9505 - lr: 0.0010
# Epoch 36/80
# 85/85 [==============================] - 28s 334ms/step - loss: 0.0945 - accuracy: 0.9719 - precision: 0.9719 - recall: 0.9719 - auc: 0.9929 - f1_score: 0.9719 - val_loss: 0.1154 - val_accuracy: 0.9604 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9914 - val_f1_score: 0.9603 - lr: 0.0010
# Epoch 37/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0943 - accuracy: 0.9701 - precision: 0.9701 - recall: 0.9701 - auc: 0.9935 - f1_score: 0.9701 - val_loss: 0.1426 - val_accuracy: 0.9554 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9882 - val_f1_score: 0.9553 - lr: 0.0010
# Epoch 38/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0840 - accuracy: 0.9719 - precision: 0.9719 - recall: 0.9719 - auc: 0.9945 - f1_score: 0.9719 - val_loss: 0.1038 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9923 - val_f1_score: 0.9529 - lr: 0.0010
# Epoch 39/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0904 - accuracy: 0.9690 - precision: 0.9690 - recall: 0.9690 - auc: 0.9943 - f1_score: 0.9690 - val_loss: 0.0932 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9938 - val_f1_score: 0.9777 - lr: 0.0010
# Epoch 40/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0898 - accuracy: 0.9694 - precision: 0.9694 - recall: 0.9694 - auc: 0.9945 - f1_score: 0.9693 - val_loss: 0.1284 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_auc: 0.9884 - val_f1_score: 0.9405 - lr: 0.0010
# Epoch 41/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0892 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9932 - f1_score: 0.9730 - val_loss: 0.1048 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9923 - val_f1_score: 0.9777 - lr: 0.0010
# Epoch 42/80
# 85/85 [==============================] - 28s 336ms/step - loss: 0.0986 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9925 - f1_score: 0.9675 - val_loss: 0.6214 - val_accuracy: 0.7376 - val_precision: 0.7376 - val_recall: 0.7376 - val_auc: 0.8638 - val_f1_score: 0.7205 - lr: 0.0010
# Epoch 43/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0893 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9936 - f1_score: 0.9730 - val_loss: 0.1067 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9932 - val_f1_score: 0.9653 - lr: 0.0010
# Epoch 44/80
# 85/85 [==============================] - ETA: 0s - loss: 0.0907 - accuracy: 0.9708 - precision: 0.9708 - recall: 0.9708 - auc: 0.9941 - f1_score: 0.9708
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0907 - accuracy: 0.9708 - precision: 0.9708 - recall: 0.9708 - auc: 0.9941 - f1_score: 0.9708 - val_loss: 0.1609 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9865 - val_f1_score: 0.9530 - lr: 0.0010
# Epoch 45/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0800 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9950 - f1_score: 0.9745 - val_loss: 0.0788 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9947 - val_f1_score: 0.9653 - lr: 1.0000e-04
# Epoch 46/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0807 - accuracy: 0.9738 - precision: 0.9738 - recall: 0.9738 - auc: 0.9954 - f1_score: 0.9738 - val_loss: 0.0710 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9954 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 47/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0729 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9959 - f1_score: 0.9753 - val_loss: 0.0616 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9962 - val_f1_score: 0.9876 - lr: 1.0000e-04
# Epoch 48/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0638 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9974 - f1_score: 0.9793 - val_loss: 0.0694 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9959 - val_f1_score: 0.9876 - lr: 1.0000e-04
# Epoch 49/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0589 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9978 - f1_score: 0.9804 - val_loss: 0.0719 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9954 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 50/80
# 85/85 [==============================] - 28s 332ms/step - loss: 0.0625 - accuracy: 0.9760 - precision: 0.9760 - recall: 0.9760 - auc: 0.9971 - f1_score: 0.9760 - val_loss: 0.0657 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9962 - val_f1_score: 0.9876 - lr: 1.0000e-04
# Epoch 51/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0612 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9973 - f1_score: 0.9812 - val_loss: 0.0635 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9960 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 52/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0552 - accuracy: 0.9815 - precision: 0.9815 - recall: 0.9815 - auc: 0.9978 - f1_score: 0.9815 - val_loss: 0.0640 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9962 - val_f1_score: 0.9876 - lr: 1.0000e-04
# Epoch 53/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0630 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9972 - f1_score: 0.9793 - val_loss: 0.0775 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9957 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 54/80
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0573 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9977 - f1_score: 0.9812 - val_loss: 0.0808 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9951 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 55/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0579 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9978 - f1_score: 0.9804 - val_loss: 0.0867 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9946 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 56/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0557 - accuracy: 0.9823 - precision: 0.9823 - recall: 0.9823 - auc: 0.9976 - f1_score: 0.9823 - val_loss: 0.0791 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9958 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 57/80
# 85/85 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9969 - f1_score: 0.9804
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0570 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9969 - f1_score: 0.9804 - val_loss: 0.0853 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9945 - val_f1_score: 0.9728 - lr: 1.0000e-04
# Epoch 58/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0441 - accuracy: 0.9845 - precision: 0.9845 - recall: 0.9845 - auc: 0.9986 - f1_score: 0.9845 - val_loss: 0.0977 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9921 - val_f1_score: 0.9703 - lr: 1.0000e-05
# Epoch 59/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0536 - accuracy: 0.9841 - precision: 0.9841 - recall: 0.9841 - auc: 0.9975 - f1_score: 0.9841 - val_loss: 0.0746 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9961 - val_f1_score: 0.9876 - lr: 1.0000e-05
# Epoch 60/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0535 - accuracy: 0.9834 - precision: 0.9834 - recall: 0.9834 - auc: 0.9978 - f1_score: 0.9834 - val_loss: 0.0749 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9953 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 61/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0585 - accuracy: 0.9790 - precision: 0.9790 - recall: 0.9790 - auc: 0.9975 - f1_score: 0.9789 - val_loss: 0.0997 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9919 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 62/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0551 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9978 - f1_score: 0.9812 - val_loss: 0.0803 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9949 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 63/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0485 - accuracy: 0.9830 - precision: 0.9830 - recall: 0.9830 - auc: 0.9983 - f1_score: 0.9830 - val_loss: 0.0803 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9954 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 64/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0582 - accuracy: 0.9790 - precision: 0.9790 - recall: 0.9790 - auc: 0.9976 - f1_score: 0.9789 - val_loss: 0.0840 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9943 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 65/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0498 - accuracy: 0.9808 - precision: 0.9808 - recall: 0.9808 - auc: 0.9986 - f1_score: 0.9808 - val_loss: 0.0931 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9924 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 66/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0507 - accuracy: 0.9845 - precision: 0.9845 - recall: 0.9845 - auc: 0.9980 - f1_score: 0.9845 - val_loss: 0.0939 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9941 - val_f1_score: 0.9703 - lr: 1.0000e-05
# Epoch 67/80
# 85/85 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9815 - precision: 0.9815 - recall: 0.9815 - auc: 0.9982 - f1_score: 0.9815
# Epoch 67: ReduceLROnPlateau reducing learning rate to 1e-05.
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0507 - accuracy: 0.9815 - precision: 0.9815 - recall: 0.9815 - auc: 0.9982 - f1_score: 0.9815 - val_loss: 0.0736 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9957 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 68/80
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0529 - accuracy: 0.9808 - precision: 0.9808 - recall: 0.9808 - auc: 0.9980 - f1_score: 0.9808 - val_loss: 0.0708 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9959 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 69/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0537 - accuracy: 0.9815 - precision: 0.9815 - recall: 0.9815 - auc: 0.9981 - f1_score: 0.9815 - val_loss: 0.0717 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9961 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 70/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0485 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9987 - f1_score: 0.9804 - val_loss: 0.0732 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9952 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 71/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0481 - accuracy: 0.9841 - precision: 0.9841 - recall: 0.9841 - auc: 0.9982 - f1_score: 0.9841 - val_loss: 0.0757 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9954 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 72/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0505 - accuracy: 0.9819 - precision: 0.9819 - recall: 0.9819 - auc: 0.9981 - f1_score: 0.9819 - val_loss: 0.0677 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9953 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 73/80
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0478 - accuracy: 0.9834 - precision: 0.9834 - recall: 0.9834 - auc: 0.9985 - f1_score: 0.9834 - val_loss: 0.0803 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9947 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 74/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0512 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9980 - f1_score: 0.9826 - val_loss: 0.0714 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9950 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 75/80
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0523 - accuracy: 0.9801 - precision: 0.9801 - recall: 0.9801 - auc: 0.9983 - f1_score: 0.9801 - val_loss: 0.0816 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9953 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 76/80
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0473 - accuracy: 0.9860 - precision: 0.9860 - recall: 0.9860 - auc: 0.9985 - f1_score: 0.9860 - val_loss: 0.0785 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9958 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 77/80
# 85/85 [==============================] - 28s 335ms/step - loss: 0.0465 - accuracy: 0.9845 - precision: 0.9845 - recall: 0.9845 - auc: 0.9983 - f1_score: 0.9845 - val_loss: 0.0770 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9956 - val_f1_score: 0.9703 - lr: 1.0000e-05
# Epoch 78/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0466 - accuracy: 0.9823 - precision: 0.9823 - recall: 0.9823 - auc: 0.9983 - f1_score: 0.9823 - val_loss: 0.0745 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9954 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 79/80
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0542 - accuracy: 0.9819 - precision: 0.9819 - recall: 0.9819 - auc: 0.9977 - f1_score: 0.9819 - val_loss: 0.0754 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9955 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 80/80
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0498 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9981 - f1_score: 0.9826 - val_loss: 0.0689 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9942 - val_f1_score: 0.9802 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = ensemble_model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 1s 27ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9768284500111832
# F1-Score for each class: [0.97647059 0.97718631]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9771863117870723
# specificity: 0.9764705882352941

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = ensemble_model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 17/17 [==============================] - 1s 28ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = ensemble_model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0671 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9949 - f1_score: 0.9764
# Test loss: 0.06706072390079498
# Test accuracy: 0.9763636589050293
# Test precision: 0.9763636589050293
# Test recall: 0.9763636589050293
# Test AUC: 0.9949371814727783
# Test F1 Score: 0.9763573408126831

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = ensemble_model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 17/17 [==============================] - 1s 28ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       255
#            1       0.98      0.98      0.98       263
#
#     accuracy                           0.98       518
#    macro avg       0.98      0.98      0.98       518
# weighted avg       0.98      0.98      0.98       518

# %%
import pandas as pd


# Generate a classification report (replace this with your actual data)
report = classification_report(all_true_labels, y_pred_labels, output_dict=True)

# Convert to DataFrame
report_df = pd.DataFrame(report).transpose()

# Drop the 'support' column, as it's not suitable for the heatmap
report_df = report_df.drop(columns=['support'])

# Draw the heatmap with the default colormap
plt.figure(figsize=(10, 6))
sns.heatmap(report_df, annot=True, cbar=False)
plt.title("Classification Report")
plt.show()

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del resnet_inception_simple


from numba import cuda

cuda.select_device(0)
cuda.close()
