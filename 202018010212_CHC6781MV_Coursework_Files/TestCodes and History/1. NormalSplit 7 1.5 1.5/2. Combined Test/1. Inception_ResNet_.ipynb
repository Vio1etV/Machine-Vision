# %%
# import zipfile

# f = zipfile.ZipFile("DRD_Split.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"DRD_Split_Cloud")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# # !pip install tensorflow-addons==0.18.0
# # !pip install scikit-learn
# !pip install seaborn

# %%
from tensorflow_addons.metrics import F1Score

# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

train_dir = '/root/DRD_Split_Cloud/DRD_Split/train'
test_dir = '/root/DRD_Split_Cloud/DRD_Split/test'

batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/DRD_Split_Cloud/DRD_Split/train/diabetic'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2708 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
def resnet_inception_simple(input_shape):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(32, (7, 7), strides=(1, 1), padding='same', activation='relu',
               kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual and Inception Blocks
    for filters in [32, 32, 64, 32]:
        # Residual Block
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x)
        x_r = BatchNormalization()(x_r)
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x_r)
        x_r = BatchNormalization()(x_r)

        # Inception Block
        branch_0 = Conv2D(96, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_0 = BatchNormalization()(branch_0)

        branch_1 = Conv2D(64, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_1 = BatchNormalization()(branch_1)
        branch_1 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_1)
        branch_1 = BatchNormalization()(branch_1)

        branch_2 = Conv2D(128, (1, 1), padding='same', activation='relu',
                          kernel_initializer='he_normal')(x)
        branch_2 = BatchNormalization()(branch_2)
        branch_2 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_2)
        branch_2 = BatchNormalization()(branch_2)
        x_i = concatenate([branch_0, branch_1,branch_2], axis = -1)
    
        # Make sure the number of filters after concatenation in x_i matches with x_r
        x_i = Conv2D(filters, (1, 1), padding = 'same', activation = 'relu')(x_i)
        x_i = BatchNormalization()(x_i)

        # Combine Residual and Inception Outputs
        x = Add()([x_r, x_i])
        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(2, activation = 'softmax')(x)
    model = Model(inputs, outputs)
    
    return model

# %%
ensemble_model = resnet_inception_simple(input_shape)
ensemble_model.summary()
# Out:
# 2023-12-09 20:43:39.134453: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:43:39.706883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:41:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 32  4736        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 64  2112        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 112, 112, 12  4224        ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 64  256        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  batch_normalization_6 (BatchNo  (None, 112, 112, 12  512        ['conv2d_6[0][0]']
#  rmalization)                   8)
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 96  3168        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 32  18464       ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 112, 112, 32  36896       ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 32  9248        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 96  384        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  batch_normalization_7 (BatchNo  (None, 112, 112, 32  128        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  concatenate (Concatenate)      (None, 112, 112, 16  0           ['batch_normalization_3[0][0]',
#                                 0)                                'batch_normalization_5[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 32  9248        ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 112, 112, 32  5152        ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 112, 112, 32  0           ['batch_normalization_2[0][0]',
#                                 )                                 'batch_normalization_8[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 32)  0           ['add[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 64)   2112        ['max_pooling2d_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 128)  4224        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 56, 56, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 96)   3168        ['max_pooling2d_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 32)   18464       ['batch_normalization_12[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 56, 56, 32)   36896       ['batch_normalization_14[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 32)   9248        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 96)  384         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 32)  128         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 56, 56, 32)  128         ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 32)  128         ['conv2d_9[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 160)  0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_13[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 32)   9248        ['batch_normalization_9[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 56, 56, 32)   5152        ['concatenate_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 32)  128         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 56, 56, 32)  128         ['conv2d_16[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 56, 56, 32)   0           ['batch_normalization_10[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 32)  0           ['add_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 64)   2112        ['max_pooling2d_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 28, 28, 128)  4224        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 96)   3168        ['max_pooling2d_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 32)   18464       ['batch_normalization_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 32)   36896       ['batch_normalization_22[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 64)   18496       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 96)  384         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 32)  128         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 160)  0           ['batch_normalization_19[0][0]',
#                                                                   'batch_normalization_21[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 64)   36928       ['batch_normalization_17[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 64)   10304       ['concatenate_2[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 28, 28, 64)   0           ['batch_normalization_18[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 64)  0           ['add_2[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 64)   4160        ['max_pooling2d_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 128)  8320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 128)  512        ['conv2d_30[0][0]']
#  ormalization)
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 96)   6240        ['max_pooling2d_3[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 32)   18464       ['batch_normalization_28[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 32)   36896       ['batch_normalization_30[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 32)   18464       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 96)  384         ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 32)  128         ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 32)  128         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 32)  128         ['conv2d_25[0][0]']
#  ormalization)
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 160)  0           ['batch_normalization_27[0][0]',
#                                                                   'batch_normalization_29[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 32)   9248        ['batch_normalization_25[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 32)   5152        ['concatenate_3[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 32)  128         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 32)  128         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 14, 14, 32)   0           ['batch_normalization_26[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 32)    0           ['add_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['max_pooling2d_4[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            66          ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 427,042
# Trainable params: 423,202
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


ensemble_model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=[
        'accuracy', 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)
lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)
early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=20, verbose=1, 
                               restore_best_weights=True)

# %%
history = ensemble_model.fit(train_generator, epochs = 100, validation_data=(validation_generator), callbacks = [lr_reduction, early_stopping])
# Out:
# Epoch 1/100
# 2023-12-09 20:43:45.440351: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-09 20:43:47.159067: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 85/85 [==============================] - 37s 360ms/step - loss: 0.3698 - accuracy: 0.8549 - precision: 0.8549 - recall: 0.8549 - auc: 0.9210 - f1_score: 0.8549 - val_loss: 0.8605 - val_accuracy: 0.5594 - val_precision: 0.5594 - val_recall: 0.5594 - val_auc: 0.5846 - val_f1_score: 0.5594 - lr: 0.0010
# Epoch 2/100
# 85/85 [==============================] - 29s 341ms/step - loss: 0.2480 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9615 - f1_score: 0.9058 - val_loss: 1.3538 - val_accuracy: 0.5074 - val_precision: 0.5074 - val_recall: 0.5074 - val_auc: 0.6024 - val_f1_score: 0.5074 - lr: 0.0010
# Epoch 3/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.2376 - accuracy: 0.9151 - precision: 0.9151 - recall: 0.9151 - auc: 0.9633 - f1_score: 0.9151 - val_loss: 1.6097 - val_accuracy: 0.5371 - val_precision: 0.5371 - val_recall: 0.5371 - val_auc: 0.5153 - val_f1_score: 0.5371 - lr: 0.0010
# Epoch 4/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0.2319 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206 - auc: 0.9654 - f1_score: 0.9206 - val_loss: 1.6739 - val_accuracy: 0.5297 - val_precision: 0.5297 - val_recall: 0.5297 - val_auc: 0.5704 - val_f1_score: 0.5297 - lr: 0.0010
# Epoch 5/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0
- val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9948 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 34/100
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0649 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9975 - f1_score: 0.9756 - val_loss: 0.0874 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9943 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 35/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0703 - accuracy: 0.9760 - precision: 0.9760 - recall: 0.9760 - auc: 0.9963 - f1_score: 0.9760 - val_loss: 0.0746 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9954 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 36/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0691 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9964 - f1_score: 0.9771 - val_loss: 0.0799 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9942 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 37/100
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0705 - accuracy: 0.9738 - precision: 0.9738 - recall: 0.9738 - auc: 0.9965 - f1_score: 0.9738 - val_loss: 0.1058 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9924 - val_f1_score: 0.9703 - lr: 1.0000e-04
# Epoch 38/100
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0642 - accuracy: 0.9767 - precision: 0.9767 - recall: 0.9767 - auc: 0.9971 - f1_score: 0.9767 - val_loss: 0.0751 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9953 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 39/100
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0607 - accuracy: 0.9782 - precision: 0.9782 - recall: 0.9782 - auc: 0.9976 - f1_score: 0.9782 - val_loss: 0.0907 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9943 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 40/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0646 - accuracy: 0.9797 - precision: 0.9797 - recall: 0.9797 - auc: 0.9970 - f1_score: 0.9797
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0646 - accuracy: 0.9797 - precision: 0.9797 - recall: 0.9797 - auc: 0.9970 - f1_score: 0.9797 - val_loss: 0.0920 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9926 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 41/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0658 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9968 - f1_score: 0.9771 - val_loss: 0.0803 - val_accuracy: 0.9901 - val_precision: 0.9901 - val_recall: 0.9901 - val_auc: 0.9940 - val_f1_score: 0.9901 - lr: 1.0000e-05
# Epoch 42/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0657 - accuracy: 0.9790 - precision: 0.9790 - recall: 0.9790 - auc: 0.9973 - f1_score: 0.9790 - val_loss: 0.0733 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9957 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 43/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0571 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9982 - f1_score: 0.9764 - val_loss: 0.0760 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9955 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 44/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0659 - accuracy: 0.9767 - precision: 0.9767 - recall: 0.9767 - auc: 0.9970 - f1_score: 0.9767 - val_loss: 0.0822 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9952 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 45/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0598 - accuracy: 0.9808 - precision: 0.9808 - recall: 0.9808 - auc: 0.9977 - f1_score: 0.9808 - val_loss: 0.0679 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9959 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 46/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0610 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9972 - f1_score: 0.9793 - val_loss: 0.0770 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9956 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 47/100
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0554 - accuracy: 0.9815 - precision: 0.9815 - recall: 0.9815 - auc: 0.9982 - f1_score: 0.9815 - val_loss: 0.0727 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9959 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 48/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0591 - accuracy: 0.9808 - precision: 0.9808 - recall: 0.9808 - auc: 0.9976 - f1_score: 0.9808 - val_loss: 0.0881 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9945 - val_f1_score: 0.9703 - lr: 1.0000e-05
# Epoch 49/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0621 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9974 - f1_score: 0.9793 - val_loss: 0.0822 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9948 - val_f1_score: 0.9703 - lr: 1.0000e-05
# Epoch 50/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0589 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9978 - f1_score: 0.9812 - val_loss: 0.0673 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9954 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 51/100
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0622 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9968 - f1_score: 0.9812 - val_loss: 0.0925 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9933 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 52/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0645 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9972 - f1_score: 0.9764 - val_loss: 0.0867 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9945 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 53/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0609 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9972 - f1_score: 0.9793 - val_loss: 0.0758 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9954 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 54/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0552 - accuracy: 0.9797 - precision: 0.9797 - recall: 0.9797 - auc: 0.9981 - f1_score: 0.9797 - val_loss: 0.0812 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9944 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 55/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0555 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9981 - f1_score: 0.9793 - val_loss: 0.0656 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9960 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 56/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0566 - accuracy: 0.9786 - precision: 0.9786 - recall: 0.9786 - auc: 0.9979 - f1_score: 0.9786 - val_loss: 0.0776 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9951 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 57/100
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0562 - accuracy: 0.9815 - precision: 0.9815 - recall: 0.9815 - auc: 0.9980 - f1_score: 0.9815 - val_loss: 0.0828 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9947 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 58/100
# 85/85 [==============================] - 29s 342ms/step - loss: 0.0585 - accuracy: 0.9790 - precision: 0.9790 - recall: 0.9790 - auc: 0.9977 - f1_score: 0.9790 - val_loss: 0.0842 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9947 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 59/100
# 85/85 [==============================] - 29s 344ms/step - loss: 0.0623 - accuracy: 0.9797 - precision: 0.9797 - recall: 0.9797 - auc: 0.9976 - f1_score: 0.9797 - val_loss: 0.0644 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9959 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 60/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0608 - accuracy: 0.9767 - precision: 0.9767 - recall: 0.9767 - auc: 0.9975 - f1_score: 0.9767 - val_loss: 0.0874 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9939 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 61/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0587 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9972 - f1_score: 0.9793 - val_loss: 0.0894 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9944 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 62/100
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0525 - accuracy: 0.9823 - precision: 0.9823 - recall: 0.9823 - auc: 0.9983 - f1_score: 0.9823 - val_loss: 0.0910 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9935 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 63/100
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0588 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9976 - f1_score: 0.9812 - val_loss: 0.0897 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9948 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 64/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0623 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9975 - f1_score: 0.9753 - val_loss: 0.0758 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9953 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 65/100
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0640 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9968 - f1_score: 0.9775 - val_loss: 0.0811 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9956 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 66/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0643 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9968 - f1_score: 0.9771 - val_loss: 0.0679 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9952 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 67/100
# 85/85 [==============================] - 29s 344ms/step - loss: 0.0530 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9982 - f1_score: 0.9804 - val_loss: 0.0776 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9955 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 68/100
# 85/85 [==============================] - 29s 341ms/step - loss: 0.0562 - accuracy: 0.9786 - precision: 0.9786 - recall: 0.9786 - auc: 0.9980 - f1_score: 0.9786 - val_loss: 0.0685 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9956 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 69/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9819 - precision: 0.9819 - recall: 0.9819 - auc: 0.9983 - f1_score: 0.9819
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1e-05.
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0525 - accuracy: 0.9819 - precision: 0.9819 - recall: 0.9819 - auc: 0.9983 - f1_score: 0.9819 - val_loss: 0.0826 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9950 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 70/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0611 - accuracy: 0.9808 - precision: 0.9808 - recall: 0.9808 - auc: 0.9976 - f1_score: 0.9808 - val_loss: 0.1021 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9938 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 71/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0593 - accuracy: 0.9782 - precision: 0.9782 - recall: 0.9782 - auc: 0.9974 - f1_score: 0.9782 - val_loss: 0.0810 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9942 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 72/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0582 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9968 - f1_score: 0.9812 - val_loss: 0.0837 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9950 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 73/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0659 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9970 - f1_score: 0.9745 - val_loss: 0.0707 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9949 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 74/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0580 - accuracy: 0.9808 - precision: 0.9808 - recall: 0.9808 - auc: 0.9972 - f1_score: 0.9808 - val_loss: 0.0948 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9932 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 75/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0546 - accuracy: 0.9823 - precision: 0.9823 - recall: 0.9823 - auc: 0.9980 - f1_score: 0.9823 - val_loss: 0.0824 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9952 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 76/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0581 - accuracy: 0.9830 - precision: 0.9830 - recall: 0.9830 - auc: 0.9973 - f1_score: 0.9830 - val_loss: 0.0939 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9933 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 77/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0510 - accuracy: 0.9834 - precision: 0.9834 - recall: 0.9834 - auc: 0.9981 - f1_score: 0.9834 - val_loss: 0.0753 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9952 - val_f1_score: 0.9876 - lr: 1.0000e-05
# Epoch 78/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0557 - accuracy: 0.9782 - precision: 0.9782 - recall: 0.9782 - auc: 0.9981 - f1_score: 0.9782 - val_loss: 0.0737 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9952 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 79/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9801 - precision: 0.9801 - recall: 0.9801 - auc: 0.9980 - f1_score: 0.9801Restoring model weights from the end of the best epoch: 59.
# 85/85 [==============================] - 29s 338ms/step - loss: 0.0546 - accuracy: 0.9801 - precision: 0.9801 - recall: 0.9801 - auc: 0.9980 - f1_score: 0.9801 - val_loss: 0.0861 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9949 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 79: early stopping

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = ensemble_model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 1s 20ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9816086980040029
# F1-Score for each class: [0.98201439 0.98120301]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9775280898876404
# specificity: 0.9855595667870036

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = ensemble_model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 17/17 [==============================] - 0s 20ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = ensemble_model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 18/18 [==============================] - 1s 75ms/step - loss: 0.0668 - accuracy: 0.9800 - precision: 0.9800 - recall: 0.9800 - auc: 0.9959 - f1_score: 0.9800
# Test loss: 0.06682799756526947
# Test accuracy: 0.9800000190734863
# Test precision: 0.9800000190734863
# Test recall: 0.9800000190734863
# Test AUC: 0.9959438443183899
# Test F1 Score: 0.9800000190734863

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = ensemble_model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 17/17 [==============================] - 0s 20ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       277
#            1       0.98      0.98      0.98       267
#
#     accuracy                           0.98       544
#    macro avg       0.98      0.98      0.98       544
# weighted avg       0.98      0.98      0.98       544

# %%
import pandas as pd


# Generate a classification report (replace this with your actual data)
report = classification_report(all_true_labels, y_pred_labels, output_dict=True)

# Convert to DataFrame
report_df = pd.DataFrame(report).transpose()

# Drop the 'support' column, as it's not suitable for the heatmap
report_df = report_df.drop(columns=['support'])

# Draw the heatmap with the default colormap
plt.figure(figsize=(10, 6))
sns.heatmap(report_df, annot=True, cbar=False)
plt.title("Classification Report")
plt.show()

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del resnet_inception_simple


from numba import cuda

cuda.select_device(0)
cuda.close()
