# %%
# import zipfile

# f = zipfile.ZipFile("DRD_Split.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"DRD_Split_Cloud")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# # !pip install tensorflow-addons==0.18.0
# # !pip install scikit-learn
# !pip install seaborn

# %%
from tensorflow_addons.metrics import F1Score

# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

train_dir = '/root/DRD_Split_Cloud/DRD_Split/train'
test_dir = '/root/DRD_Split_Cloud/DRD_Split/test'

batch_size = 8
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/DRD_Split_Cloud/DRD_Split/train/diabetic'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2708 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
filter_factor = 4
def branch_and_skip(input_shape):
    input_shape = Input(input_shape)
    Original = input_shape
    
    
    #Give three branches, and let the tensor be calculated in each branch
    B1 = Conv2D(16//filter_factor, (1, 1), activation = 'relu', padding = 'same')(input_shape)
    B1 = Conv2D(32//filter_factor, (1, 1), activation = 'relu', padding = 'same')(B1)

    
    
    B2 = Conv2D(32//filter_factor, (3, 3), activation = 'relu', padding = 'same')(input_shape)
    B2 = Conv2D(64//filter_factor, (3, 3), activation = 'relu', padding = 'same')(B2)


    B3 = Conv2D(128//filter_factor, (1, 1), activation = 'relu', padding = 'same')(input_shape)
    B3 = Conv2D(256//filter_factor, (1, 1), activation = 'relu', padding = 'same')(B3)
    B3 = Conv2D(384//filter_factor, (1, 1), activation = 'relu', padding = 'same')(B3)

    x = concatenate([B1, B2, B3, Original], axis = -1)
    x = Conv2D(1024//filter_factor, (1, 1), activation = 'relu', padding = 'same')(x)
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation = 'softmax')(x)
    return Model(input_shape, outputs)

# %%
ensemble_model = branch_and_skip(input_shape)
ensemble_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 224, 224, 32  128         ['input_2[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 224, 224, 4)  16          ['input_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 8)  224         ['input_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 224, 224, 64  2112        ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 8)  40          ['conv2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 224, 224, 16  1168        ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 224, 224, 96  6240        ['conv2d_5[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 224, 224, 12  0           ['conv2d_1[0][0]',
#                                 3)                                'conv2d_3[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'input_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 224, 224, 25  31744       ['concatenate[0][0]']
#                                 6)
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['conv2d_7[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 42,186
# Trainable params: 42,186
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2023-12-09 16:40:55.841537: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 16:40:56.397179: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:41:00.0, compute capability: 8.6

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


ensemble_model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=[
        'accuracy', 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)
lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)
early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=20, verbose=1, 
                               restore_best_weights=True)

# %%
history = ensemble_model.fit(train_generator, epochs = 100, validation_data=(validation_generator), callbacks = [lr_reduction, early_stopping])
# Out:
# Epoch 1/100
# 2023-12-09 16:41:22.708537: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-09 16:41:24.103258: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 339/339 [==============================] - 34s 91ms/step - loss: 0.6305 - accuracy: 0.6137 - precision: 0.6137 - recall: 0.6137 - auc: 0.6798 - f1_score: 0.6137 - val_loss: 0.5131 - val_accuracy: 0.7129 - val_precision: 0.7129 - val_recall: 0.7129 - val_auc: 0.8253 - val_f1_score: 0.7129 - lr: 0.0010
# Epoch 2/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.3990 - accuracy: 0.8235 - precision: 0.8235 - recall: 0.8235 - auc: 0.9054 - f1_score: 0.8235 - val_loss: 0.3010 - val_accuracy: 0.8762 - val_precision: 0.8762 - val_recall: 0.8762 - val_auc: 0.9537 - val_f1_score: 0.8762 - lr: 0.0010
# Epoch 3/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2838 - accuracy: 0.9036 - precision: 0.9036 - recall: 0.9036 - auc: 0.9520 - f1_score: 0.9036 - val_loss: 0.2156 - val_accuracy: 0.9257 - val_precision: 0.9257 - val_recall: 0.9257 - val_auc: 0.9774 - val_f1_score: 0.9257 - lr: 0.0010
# Epoch 4/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2670 - accuracy: 0.9132 - precision: 0.9132 - recall: 0.9132 - auc: 0.9558 - f1_score: 0.9132 - val_loss: 0.1909 - val_accuracy: 0.9332 - val_precision: 0.9332 - val_recall: 0.9332 - val_auc: 0.9804 - val_f1_score: 0.9332 - lr: 0.0010
# Epoch 5/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2558 - accuracy: 0.9147 - precision: 0.9147 - recall: 0.9147 - auc: 0.9588 - f1_score: 0.9147 - val_loss: 0.2057 - val_accuracy: 0.9356 - val_precision: 0.9356 - val_recall: 0.9356 - val_auc: 0.9779 - val_f1_score: 0.9356 - lr: 0.0010
# Epoch 6/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2626 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9567 - f1_score: 0.9103 - val_loss: 0.2073 - val_accuracy: 0.9282 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9737 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 7/100
# 339/339 [==============================] - 30s 90ms/step - loss: 0.2536 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9584 - f1_score: 0.9213 - val_loss: 0.2113 - val_accuracy: 0.9183 - val_precision: 0.9183 - val_recall: 0.9183 - val_auc: 0.9768 - val_f1_score: 0.9183 - lr: 0.0010
# Epoch 8/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2468 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9603 - f1_score: 0.9213 - val_loss: 0.2354 - val_accuracy: 0.9010 - val_precision: 0.9010 - val_recall: 0.9010 - val_auc: 0.9666 - val_f1_score: 0.9010 - lr: 0.0010
# Epoch 9/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2429 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206 - auc: 0.9612 - f1_score: 0.9206 - val_loss: 0.1840 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9832 - val_f1_score: 0.9480 - lr: 0.0010
# Epoch 10/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2393 - accuracy: 0.9247 - precision: 0.9247 - recall: 0.9247 - auc: 0.9623 - f1_score: 0.9247 - val_loss: 0.1848 - val_accuracy: 0.9381 - val_precision: 0.9381 - val_recall: 0.9381 - val_auc: 0.9814 - val_f1_score: 0.9381 - lr: 0.0010
# Epoch 11/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2390 - accuracy: 0.9158 - precision: 0.9158 - recall: 0.9158 - auc: 0.9627 - f1_score: 0.9158 - val_loss: 0.1870 - val_accuracy: 0.9332 - val_precision: 0.9332 - val_recall: 0.9332 - val_auc: 0.9804 - val_f1_score: 0.9332 - lr: 0.0010
# Epoch 12/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2411 - accuracy: 0.9154 - precision: 0.9154 - recall: 0.9154 - auc: 0.9629 - f1_score: 0.9154 - val_loss: 0.1846 - val_accuracy: 0.9208 - val_precision: 0.9208 - val_recall: 0.9208 - val_auc: 0.9793 - val_f1_score: 0.9208 - lr: 0.0010
# Epoch 13/100
# 339/339 [==============================] - 30s 90ms/step - loss: 0.2351 - accuracy: 0.9225 - precision: 0.9225 - recall: 0.9225 - auc: 0.9637 - f1_score: 0.9225 - val_loss: 0.1832 - val_accuracy: 0.9381 - val_precision: 0.9381 - val_recall: 0.9381 - val_auc: 0.9791 - val_f1_score: 0.9381 - lr: 0.0010
# Epoch 14/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2283 - accuracy: 0.9250 - precision: 0.9250 - recall: 0.9250 - auc: 0.9656 - f1_score: 0.9250 - val_loss: 0.1959 - val_accuracy: 0.9282 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9790 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 15/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2371 - accuracy: 0.9202 - precision: 0.9202 - recall: 0.9202 - auc: 0.9633 - f1_score: 0.9202 - val_loss: 0.2412 - val_accuracy: 0.8985 - val_precision: 0.8985 - val_recall: 0.8985 - val_auc: 0.9651 - val_f1_score: 0.8985 - lr: 0.0010
# Epoch 16/100
# 339/339 [==============================] - 31s 90ms/step - loss: 0.2321 - accuracy: 0.9199 - precision: 0.9199 - recall: 0.9199 - auc: 0.9652 - f1_score: 0.9199 - val_loss: 0.1882 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9820 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 17/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2292 - accuracy: 0.9254 - precision: 0.9254 - recall: 0.9254 - auc: 0.9653 - f1_score: 0.9254 - val_loss: 0.1806 - val_accuracy: 0.9282 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9818 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 18/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2375 - accuracy: 0.9217 - precision: 0.9217 - recall: 0.9217 - auc: 0.9626 - f1_score: 0.9217 - val_loss: 0.1733 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_auc: 0.9809 - val_f1_score: 0.9406 - lr: 0.0010
# Epoch 19/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2252 - accuracy: 0.9254 - precision: 0.9254 - recall: 0.9254 - auc: 0.9666 - f1_score: 0.9254 - val_loss: 0.1701 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_auc: 0.9838 - val_f1_score: 0.9406 - lr: 0.0010
# Epoch 20/100
# 339/339 [==============================] - 30s 90ms/step - loss: 0.2260 - accuracy: 0.9199 - precision: 0.9199 - recall: 0.9199 - auc: 0.9664 - f1_score: 0.9199 - val_loss: 0.1891 - val_accuracy: 0.9183 - val_precision: 0.9183 - val_recall: 0.9183 - val_auc: 0.9778 - val_f1_score: 0.9183 - lr: 0.0010
# Epoch 21/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2291 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9653 - f1_score: 0.9258 - val_loss: 0.1724 - val_accuracy: 0.9356 - val_precision: 0.9356 - val_recall: 0.9356 - val_auc: 0.9830 - val_f1_score: 0.9356 - lr: 0.0010
# Epoch 22/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2339 - accuracy: 0.9239 - precision: 0.9239 - recall: 0.9239 - auc: 0.9643 - f1_score: 0.9239 - val_loss: 0.1737 - val_accuracy: 0.9332 - val_precision: 0.9332 - val_recall: 0.9332 - val_auc: 0.9835 - val_f1_score: 0.9332 - lr: 0.0010
# Epoch 23/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2269 - accuracy: 0.9217 - precision: 0.9217 - recall: 0.9217 - auc: 0.9661 - f1_score: 0.9217 - val_loss: 0.1664 - val_accuracy: 0.9505 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9849 - val_f1_score: 0.9505 - lr: 0.0010
# Epoch 24/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2184 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9681 - f1_score: 0.9280 - val_loss: 0.2178 - val_accuracy: 0.9208 - val_precision: 0.9208 - val_recall: 0.9208 - val_auc: 0.9724 - val_f1_score: 0.9208 - lr: 0.0010
# Epoch 25/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2287 - accuracy: 0.9217 - precision: 0.9217 - recall: 0.9217 - auc: 0.9660 - f1_score: 0.9217 - val_loss: 0.1744 - val_accuracy: 0.9381 - val_precision: 0.9381 - val_recall: 0.9381 - val_auc: 0.9804 - val_f1_score: 0.9381 - lr: 0.0010
# Epoch 26/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2189 - accuracy: 0.9269 - precision: 0.9269 - recall: 0.9269 - auc: 0.9682 - f1_score: 0.9269 - val_loss: 0.1722 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_auc: 0.9848 - val_f1_score: 0.9406 - lr: 0.0010
# Epoch 27/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2327 - accuracy: 0.9254 - precision: 0.9254 - recall: 0.9254 - auc: 0.9638 - f1_score: 0.9254 - val_loss: 0.2139 - val_accuracy: 0.9158 - val_precision: 0.9158 - val_recall: 0.9158 - val_auc: 0.9746 - val_f1_score: 0.9158 - lr: 0.0010
# Epoch 28/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2248 - accuracy: 0.9243 - precision: 0.9243 - recall: 0.9243 - auc: 0.9669 - f1_score: 0.9243 - val_loss: 0.1697 - val_accuracy: 0.9431 - val_precision: 0.9431 - val_recall: 0.9431 - val_auc: 0.9850 - val_f1_score: 0.9431 - lr: 0.0010
# Epoch 29/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2240 - accuracy: 0.9291 - precision: 0.9291 - recall: 0.9291 - auc: 0.9662 - f1_score: 0.9291 - val_loss: 0.1811 - val_accuracy: 0.9282 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9803 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 30/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2214 - accuracy: 0.9276 - precision: 0.9276 - recall: 0.9276 - auc: 0.9676 - f1_score: 0.9276 - val_loss: 0.1844 - val_accuracy: 0.9356 - val_precision: 0.9356 - val_recall: 0.9356 - val_auc: 0.9784 - val_f1_score: 0.9356 - lr: 0.0010
# Epoch 31/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2211 - accuracy: 0.9243 - precision: 0.9243 - recall: 0.9243 - auc: 0.9679 - f1_score: 0.9243 - val_loss: 0.1742 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9854 - val_f1_score: 0.9530 - lr: 0.0010
# Epoch 32/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2197 - accuracy: 0.9265 - precision: 0.9265 - recall: 0.9265 - auc: 0.9676 - f1_score: 0.9265 - val_loss: 0.1654 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9845 - val_f1_score: 0.9480 - lr: 0.0010
# Epoch 33/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2234 - accuracy: 0.9228 - precision: 0.9228 - recall: 0.9228 - auc: 0.9669 - f1_score: 0.9228 - val_loss: 0.1857 - val_accuracy: 0.9381 - val_precision: 0.9381 - val_recall: 0.9381 - val_auc: 0.9801 - val_f1_score: 0.9381 - lr: 0.0010
# Epoch 34/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2225 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9663 - f1_score: 0.9302 - val_loss: 0.1833 - val_accuracy: 0.9356 - val_precision: 0.9356 - val_recall: 0.9356 - val_auc: 0.9801 - val_f1_score: 0.9356 - lr: 0.0010
# Epoch 35/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2203 - accuracy: 0.9232 - precision: 0.9232 - recall: 0.9232 - auc: 0.9673 - f1_score: 0.9232 - val_loss: 0.1847 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9816 - val_f1_score: 0.9480 - lr: 0.0010
# Epoch 36/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2224 - accuracy: 0.9261 - precision: 0.9261 - recall: 0.9261 - auc: 0.9674 - f1_score: 0.9261 - val_loss: 0.1946 - val_accuracy: 0.9431 - val_precision: 0.9431 - val_recall: 0.9431 - val_auc: 0.9780 - val_f1_score: 0.9431 - lr: 0.0010
# Epoch 37/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2232 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9660 - f1_score: 0.9280 - val_loss: 0.1557 - val_accuracy: 0.9554 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9862 - val_f1_score: 0.9554 - lr: 0.0010
# Epoch 38/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2131 - accuracy: 0.9265 - precision: 0.9265 - recall: 0.9265 - auc: 0.9702 - f1_score: 0.9265 - val_loss: 0.1741 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9798 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 39/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2144 - accuracy: 0.9317 - precision: 0.9317 - recall: 0.9317 - auc: 0.9697 - f1_score: 0.9317 - val_loss: 0.1825 - val_accuracy: 0.9332 - val_precision: 0.9332 - val_recall: 0.9332 - val_auc: 0.9810 - val_f1_score: 0.9332 - lr: 0.0010
# Epoch 40/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2072 - accuracy: 0.9343 - precision: 0.9343 - recall: 0.9343 - auc: 0.9709 - f1_score: 0.9343 - val_loss: 0.1722 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9825 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 41/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2159 - accuracy: 0.9317 - precision: 0.9317 - recall: 0.9317 - auc: 0.9679 - f1_score: 0.9317 - val_loss: 0.1677 - val_accuracy: 0.9431 - val_precision: 0.9431 - val_recall: 0.9431 - val_auc: 0.9812 - val_f1_score: 0.9431 - lr: 0.0010
# Epoch 42/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2181 - accuracy: 0.9276 - precision: 0.9276 - recall: 0.9276 - auc: 0.9681 - f1_score: 0.9276 - val_loss: 0.1818 - val_accuracy: 0.9356 - val_precision: 0.9356 - val_recall: 0.9356 - val_auc: 0.9822 - val_f1_score: 0.9356 - lr: 0.0010
# Epoch 43/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2129 - accuracy: 0.9324 - precision: 0.9324 - recall: 0.9324 - auc: 0.9694 - f1_score: 0.9324 - val_loss: 0.1814 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_auc: 0.9806 - val_f1_score: 0.9406 - lr: 0.0010
# Epoch 44/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2168 - accuracy: 0.9269 - precision: 0.9269 - recall: 0.9269 - auc: 0.9684 - f1_score: 0.9269 - val_loss: 0.1376 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9888 - val_f1_score: 0.9530 - lr: 0.0010
# Epoch 45/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2131 - accuracy: 0.9265 - precision: 0.9265 - recall: 0.9265 - auc: 0.9698 - f1_score: 0.9265 - val_loss: 0.1701 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_auc: 0.9822 - val_f1_score: 0.9406 - lr: 0.0010
# Epoch 46/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2168 - accuracy: 0.9306 - precision: 0.9306 - recall: 0.9306 - auc: 0.9679 - f1_score: 0.9306 - val_loss: 0.1611 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9836 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 47/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2097 - accuracy: 0.9306 - precision: 0.9306 - recall: 0.9306 - auc: 0.9705 - f1_score: 0.9306 - val_loss: 0.1922 - val_accuracy: 0.9282 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9770 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 48/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2084 - accuracy: 0.9295 - precision: 0.9295 - recall: 0.9295 - auc: 0.9711 - f1_score: 0.9295 - val_loss: 0.1966 - val_accuracy: 0.9208 - val_precision: 0.9208 - val_recall: 0.9208 - val_auc: 0.9786 - val_f1_score: 0.9208 - lr: 0.0010
# Epoch 49/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2111 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9701 - f1_score: 0.9280 - val_loss: 0.1713 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9839 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 50/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2004 - accuracy: 0.9354 - precision: 0.9354 - recall: 0.9354 - auc: 0.9726 - f1_score: 0.9354 - val_loss: 0.1605 - val_accuracy: 0.9554 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9842 - val_f1_score: 0.9554 - lr: 0.0010
# Epoch 51/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2133 - accuracy: 0.9324 - precision: 0.9324 - recall: 0.9324 - auc: 0.9678 - f1_score: 0.9324 - val_loss: 0.1704 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9821 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 52/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.2015 - accuracy: 0.9309 - precision: 0.9309 - recall: 0.9309 - auc: 0.9729 - f1_score: 0.9309 - val_loss: 0.1992 - val_accuracy: 0.9282 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9773 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 53/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2137 - accuracy: 0.9295 - precision: 0.9295 - recall: 0.9295 - auc: 0.9690 - f1_score: 0.9295 - val_loss: 0.1675 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9842 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 54/100
# 339/339 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9714 - f1_score: 0.9280
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 339/339 [==============================] - 30s 90ms/step - loss: 0.2066 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9714 - f1_score: 0.9280 - val_loss: 0.1730 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9833 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 55/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1939 - accuracy: 0.9339 - precision: 0.9339 - recall: 0.9339 - auc: 0.9745 - f1_score: 0.9339 - val_loss: 0.1626 - val_accuracy: 0.9381 - val_precision: 0.9381 - val_recall: 0.9381 - val_auc: 0.9824 - val_f1_score: 0.9381 - lr: 1.0000e-04
# Epoch 56/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1872 - accuracy: 0.9376 - precision: 0.9376 - recall: 0.9376 - auc: 0.9763 - f1_score: 0.9376 - val_loss: 0.1616 - val_accuracy: 0.9505 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9829 - val_f1_score: 0.9505 - lr: 1.0000e-04
# Epoch 57/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1984 - accuracy: 0.9332 - precision: 0.9332 - recall: 0.9332 - auc: 0.9731 - f1_score: 0.9332 - val_loss: 0.1493 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9864 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 58/100
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1973 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9731 - f1_score: 0.9350 - val_loss: 0.1560 - val_accuracy: 0.9554 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9856 - val_f1_score: 0.9554 - lr: 1.0000e-04
# Epoch 59/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.1850 - accuracy: 0.9376 - precision: 0.9376 - recall: 0.9376 - auc: 0.9763 - f1_score: 0.9376 - val_loss: 0.1503 - val_accuracy: 0.9554 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9844 - val_f1_score: 0.9554 - lr: 1.0000e-04
# Epoch 60/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.1961 - accuracy: 0.9354 - precision: 0.9354 - recall: 0.9354 - auc: 0.9733 - f1_score: 0.9354 - val_loss: 0.1529 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9844 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 61/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.1941 - accuracy: 0.9387 - precision: 0.9387 - recall: 0.9387 - auc: 0.9729 - f1_score: 0.9387 - val_loss: 0.1601 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9843 - val_f1_score: 0.9480 - lr: 1.0000e-04
# Epoch 62/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.1891 - accuracy: 0.9380 - precision: 0.9380 - recall: 0.9380 - auc: 0.9751 - f1_score: 0.9380 - val_loss: 0.1396 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9868 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 63/100
# 339/339 [==============================] - 30s 89ms/step - loss: 0.1906 - accuracy: 0.9376 - precision: 0.9376 - recall: 0.9376 - auc: 0.9747 - f1_score: 0.9376 - val_loss: 0.1469 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9862 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 64/100
# 339/339 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9405 - precision: 0.9405 - recall: 0.9405 - auc: 0.9738 - f1_score: 0.9405
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Restoring model weights from the end of the best epoch: 44.
# 339/339 [==============================] - 30s 89ms/step - loss: 0.1930 - accuracy: 0.9405 - precision: 0.9405 - recall: 0.9405 - auc: 0.9738 - f1_score: 0.9405 - val_loss: 0.1509 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9843 - val_f1_score: 0.9530 - lr: 1.0000e-04
# Epoch 64: early stopping

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = ensemble_model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 1s 35ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9390893023160777
# F1-Score for each class: [0.93785311 0.9403255 ]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9774436090225563
# specificity: 0.9021739130434783

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = ensemble_model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 17/17 [==============================] - 1s 35ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = ensemble_model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 69/69 [==============================] - 1s 19ms/step - loss: 0.1867 - accuracy: 0.9364 - precision: 0.9364 - recall: 0.9364 - auc: 0.9768 - f1_score: 0.9364
# Test loss: 0.18671958148479462
# Test accuracy: 0.9363636374473572
# Test precision: 0.9363636374473572
# Test recall: 0.9363636374473572
# Test AUC: 0.9768083095550537
# Test F1 Score: 0.9363636374473572

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = ensemble_model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 17/17 [==============================] - 1s 35ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94       276
#            1       0.91      0.98      0.94       266
#
#     accuracy                           0.94       542
#    macro avg       0.94      0.94      0.94       542
# weighted avg       0.94      0.94      0.94       542

# %%
import pandas as pd


# Generate a classification report (replace this with your actual data)
report = classification_report(all_true_labels, y_pred_labels, output_dict=True)

# Convert to DataFrame
report_df = pd.DataFrame(report).transpose()

# Drop the 'support' column, as it's not suitable for the heatmap
report_df = report_df.drop(columns=['support'])

# Draw the heatmap with the default colormap
plt.figure(figsize=(10, 6))
sns.heatmap(report_df, annot=True, cbar=False)
plt.title("Classification Report")
plt.show()

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del branch_and_skip


from numba import cuda

cuda.select_device(0)
cuda.close()
