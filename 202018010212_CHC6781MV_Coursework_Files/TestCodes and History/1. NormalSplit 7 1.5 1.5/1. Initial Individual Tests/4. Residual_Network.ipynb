# %%
# import zipfile

# f = zipfile.ZipFile("DRD_Split.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"DRD_Split_Cloud")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# # !pip install tensorflow-addons==0.18.0
# # !pip install scikit-learn
# !pip install seaborn

# %%
from tensorflow_addons.metrics import F1Score

# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

train_dir = '/root/DRD_Split_Cloud/DRD_Split/train'
test_dir = '/root/DRD_Split_Cloud/DRD_Split/test'

batch_size = 8
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/DRD_Split_Cloud/DRD_Split/train/diabetic'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2708 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
def simple_resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual Blocks
    for filters in [64, 128, 64, 128]:
        # Residual connection
        identity = x

        # Adjust the number of filters in identity to match x if necessary
        if identity.shape[-1] != filters:
            identity = Conv2D(filters, (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(identity)
            identity = BatchNormalization()(identity)

        # First Convolution
        x = Conv2D(filters, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Second Convolution
        x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Add Residual Connection
        x = Add()([x, identity])
        x = Activation('relu')(x)

        # Optional: Additional MaxPooling
        x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model


model = simple_resnet(input_shape, num_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 64  9472        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 64)   36928       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 64)   36928       ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['batch_normalization_7[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['add_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  147584      ['batch_normalization_9[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 128)  8320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_10[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_2 (Activation)      (None, 28, 28, 128)  0           ['add_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 64)   73792       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 14, 14, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 64)   36928       ['batch_normalization_12[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 64)   8256        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 14, 14, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_13[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  activation_3 (Activation)      (None, 14, 14, 64)   0           ['add_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 64)    0           ['activation_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 7, 7, 128)    73856       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 7, 7, 128)   512         ['conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 7, 7, 128)    147584      ['batch_normalization_15[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 7, 7, 128)    8320        ['max_pooling2d_5[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 7, 7, 128)   512         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 7, 7, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_16[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_4 (Activation)      (None, 7, 7, 128)    0           ['add_5[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 4, 4, 128)   0           ['activation_4[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['max_pooling2d_6[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            258         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 666,690
# Trainable params: 664,386
# Non-trainable params: 2,304
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=[
        'accuracy', 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)
lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)
# early_stopping = EarlyStopping(monitor='val_loss', 
#                                patience=20, verbose=1, 
#                                restore_best_weights=True)

# %%
history = model.fit(train_generator, epochs = 80, validation_data=(validation_generator), callbacks = [lr_reduction])
# Out:
# Epoch 1/80
# 2023-12-09 19:12:42.432821: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-09 19:12:43.776054: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 339/339 [==============================] - 34s 90ms/step - loss: 0.3722 - accuracy: 0.8493 - precision: 0.8493 - recall: 0.8493 - auc: 0.9190 - f1_score: 0.8493 - val_loss: 0.6651 - val_accuracy: 0.6213 - val_precision: 0.6213 - val_recall: 0.6213 - val_auc: 0.6379 - val_f1_score: 0.6213 - lr: 0.0010
# Epoch 2/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2974 - accuracy: 0.8973 - precision: 0.8973 - recall: 0.8973 - auc: 0.9465 - f1_score: 0.8973 - val_loss: 0.2411 - val_accuracy: 0.9158 - val_precision: 0.9158 - val_recall: 0.9158 - val_auc: 0.9693 - val_f1_score: 0.9158 - lr: 0.0010
# Epoch 3/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2813 - accuracy: 0.9051 - precision: 0.9051 - recall: 0.9051 - auc: 0.9509 - f1_score: 0.9051 - val_loss: 0.3270 - val_accuracy: 0.8663 - val_precision: 0.8663 - val_recall: 0.8663 - val_auc: 0.9343 - val_f1_score: 0.8663 - lr: 0.0010
# Epoch 4/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.2577 - accuracy: 0.9117 - precision: 0.9117 - recall: 0.9117 - auc: 0.9589 - f1_score: 0.9117 - val_loss: 0.2895 - val_accuracy: 0.8960 - val_precision: 0.8960 - val_recall: 0.8960 - val_auc: 0.9491 - val_f1_score: 0.8960 - lr: 0.0010
# Epoch 5/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2320 - accuracy: 0.9217 - precision: 0.9217 - recall: 0.9217 - auc: 0.9647 - f1_score: 0.9217 - val_loss: 0.1740 - val_accuracy: 0.9505 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9875 - val_f1_score: 0.9505 - lr: 0.0010
# Epoch 6/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.2197 - accuracy: 0.9250 - precision: 0.9250 - recall: 0.9250 - auc: 0.9688 - f1_score: 0.9250 - val_loss: 0.2312 - val_accuracy: 0.9109 - val_precision: 0.9109 - val_recall: 0.9109 - val_auc: 0.9658 - val_f1_score: 0.9109 - lr: 0.0010
# Epoch 7/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2114 - accuracy: 0.9265 - precision: 0.9265 - recall: 0.9265 - auc: 0.9711 - f1_score: 0.9265 - val_loss: 0.2051 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9903 - val_f1_score: 0.9530 - lr: 0.0010
# Epoch 8/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1883 - accuracy: 0.9383 - precision: 0.9383 - recall: 0.9383 - auc: 0.9761 - f1_score: 0.9383 - val_loss: 0.1703 - val_accuracy: 0.9406 - val_precision: 0.9406 - val_recall: 0.9406 - val_auc: 0.9807 - val_f1_score: 0.9406 - lr: 0.0010
# Epoch 9/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1940 - accuracy: 0.9357 - precision: 0.9357 - recall: 0.9357 - auc: 0.9752 - f1_score: 0.9357 - val_loss: 0.1936 - val_accuracy: 0.9307 - val_precision: 0.9307 - val_recall: 0.9307 - val_auc: 0.9783 - val_f1_score: 0.9307 - lr: 0.0010
# Epoch 10/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1696 - accuracy: 0.9465 - precision: 0.9465 - recall: 0.9465 - auc: 0.9800 - f1_score: 0.9465 - val_loss: 0.1125 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9909 - val_f1_score: 0.9653 - lr: 0.0010
# Epoch 11/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.2149 - accuracy: 0.9239 - precision: 0.9239 - recall: 0.9239 - auc: 0.9703 - f1_score: 0.9239 - val_loss: 0.1608 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9828 - val_f1_score: 0.9480 - lr: 0.0010
# Epoch 12/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1940 - accuracy: 0.9313 - precision: 0.9313 - recall: 0.9313 - auc: 0.9754 - f1_score: 0.9313 - val_loss: 0.1302 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9898 - val_f1_score: 0.9678 - lr: 0.0010
# Epoch 13/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1839 - accuracy: 0.9402 - precision: 0.9402 - recall: 0.9402 - auc: 0.9767 - f1_score: 0.9402 - val_loss: 0.1442 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9892 - val_f1_score: 0.9579 - lr: 0.0010
# Epoch 14/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1616 - accuracy: 0.9457 - precision: 0.9457 - recall: 0.9457 - auc: 0.9820 - f1_score: 0.9457 - val_loss: 0.1473 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9908 - val_f1_score: 0.9579 - lr: 0.0010
# Epoch 15/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1589 - accuracy: 0.9457 - precision: 0.9457 - recall: 0.9457 - auc: 0.9828 - f1_score: 0.9457 - val_loss: 0.1056 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9914 - val_f1_score: 0.9629 - lr: 0.0010
# Epoch 16/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1671 - accuracy: 0.9420 - precision: 0.9420 - recall: 0.9420 - auc: 0.9817 - f1_score: 0.9420 - val_loss: 0.1678 - val_accuracy: 0.9282 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9852 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 17/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.1377 - accuracy: 0.9579 - precision: 0.9579 - recall: 0.9579 - auc: 0.9866 - f1_score: 0.9579 - val_loss: 0.1442 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9870 - val_f1_score: 0.9530 - lr: 0.0010
# Epoch 18/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.1464 - accuracy: 0.9527 - precision: 0.9527 - recall: 0.9527 - auc: 0.9852 - f1_score: 0.9527 - val_loss: 0.1833 - val_accuracy: 0.9183 - val_precision: 0.9183 - val_recall: 0.9183 - val_auc: 0.9797 - val_f1_score: 0.9183 - lr: 0.0010
# Epoch 19/80
# 339/339 [==============================] - 30s 89ms/step - loss: 0.1467 - accuracy: 0.9520 - precision: 0.9520 - recall: 0.9520 - auc: 0.9850 - f1_score: 0.9520 - val_loss: 0.1213 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9922 - val_f1_score: 0.9629 - lr: 0.0010
# Epoch 20/80
# 339/339 [==============================] - 30s 89ms/step - loss: 0.1453 - accuracy: 0.9498 - precision: 0.9498 - recall: 0.9498 - auc: 0.9859 - f1_score: 0.9498 - val_loss: 0.1744 - val_accuracy: 0.9158 - val_precision: 0.9158 - val_recall: 0.9158 - val_auc: 0.9819 - val_f1_score: 0.9158 - lr: 0.0010
# Epoch 21/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.1250 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - auc: 0.9896 - f1_score: 0.9524 - val_loss: 0.0788 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9947 - val_f1_score: 0.9802 - lr: 0.0010
# Epoch 22/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1258 - accuracy: 0.9579 - precision: 0.9579 - recall: 0.9579 - auc: 0.9883 - f1_score: 0.9579 - val_loss: 0.1070 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9919 - val_f1_score: 0.9728 - lr: 0.0010
# Epoch 23/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1394 - accuracy: 0.9542 - precision: 0.9542 - recall: 0.9542 - auc: 0.9860 - f1_score: 0.9542 - val_loss: 0.0865 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9949 - val_f1_score: 0.9728 - lr: 0.0010
# Epoch 24/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1357 - accuracy: 0.9557 - precision: 0.9557 - recall: 0.9557 - auc: 0.9870 - f1_score: 0.9557 - val_loss: 0.1711 - val_accuracy: 0.9307 - val_precision: 0.9307 - val_recall: 0.9307 - val_auc: 0.9832 - val_f1_score: 0.9307 - lr: 0.0010
# Epoch 25/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.1249 - accuracy: 0.9597 - precision: 0.9597 - recall: 0.9597 - auc: 0.9889 - f1_score: 0.9597 - val_loss: 0.2590 - val_accuracy: 0.8936 - val_precision: 0.8936 - val_recall: 0.8936 - val_auc: 0.9608 - val_f1_score: 0.8936 - lr: 0.0010
# Epoch 26/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1282 - accuracy: 0.9561 - precision: 0.9561 - recall: 0.9561 - auc: 0.9887 - f1_score: 0.9561 - val_loss: 0.0889 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9953 - val_f1_score: 0.9678 - lr: 0.0010
# Epoch 27/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1211 - accuracy: 0.9620 - precision: 0.9620 - recall: 0.9620 - auc: 0.9885 - f1_score: 0.9620 - val_loss: 0.0988 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9916 - val_f1_score: 0.9703 - lr: 0.0010
# Epoch 28/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.1145 - accuracy: 0.9616 - precision: 0.9616 - recall: 0.9616 - auc: 0.9903 - f1_score: 0.9616 - val_loss: 0.0943 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9944 - val_f1_score: 0.9653 - lr: 0.0010
# Epoch 29/80
# 339/339 [==============================] - 30s 89ms/step - loss: 0.1204 - accuracy: 0.9590 - precision: 0.9590 - recall: 0.9590 - auc: 0.9895 - f1_score: 0.9590 - val_loss: 0.1284 - val_accuracy: 0.9554 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9910 - val_f1_score: 0.9554 - lr: 0.0010
# Epoch 30/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1191 - accuracy: 0.9594 - precision: 0.9594 - recall: 0.9594 - auc: 0.9906 - f1_score: 0.9594 - val_loss: 0.1727 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9829 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 31/80
# 339/339 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9549 - precision: 0.9549 - recall: 0.9549 - auc: 0.9886 - f1_score: 0.9549
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 339/339 [==============================] - 30s 87ms/step - loss: 0.1270 - accuracy: 0.9549 - precision: 0.9549 - recall: 0.9549 - auc: 0.9886 - f1_score: 0.9549 - val_loss: 0.1470 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9863 - val_f1_score: 0.9480 - lr: 0.0010
# Epoch 32/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.1071 - accuracy: 0.9660 - precision: 0.9660 - recall: 0.9660 - auc: 0.9914 - f1_score: 0.9660 - val_loss: 0.0919 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9942 - val_f1_score: 0.9653 - lr: 1.0000e-04
# Epoch 33/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.1035 - accuracy: 0.9634 - precision: 0.9634 - recall: 0.9634 - auc: 0.9926 - f1_score: 0.9634 - val_loss: 0.0665 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9948 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 34/80
# 339/339 [==============================] - 30s 89ms/step - loss: 0.0930 - accuracy: 0.9727 - precision: 0.9727 - recall: 0.9727 - auc: 0.9933 - f1_score: 0.9727 - val_loss: 0.0785 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9942 - val_f1_score: 0.9728 - lr: 1.0000e-04
# Epoch 35/80
# 339/339 [==============================] - 30s 89ms/step - loss: 0.0962 - accuracy: 0.9708 - precision: 0.9708 - recall: 0.9708 - auc: 0.9931 - f1_score: 0.9708 - val_loss: 0.0837 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9940 - val_f1_score: 0.9728 - lr: 1.0000e-04
# Epoch 36/80
# 339/339 [==============================] - 30s 89ms/step - loss: 0.0887 - accuracy: 0.9705 - precision: 0.9705 - recall: 0.9705 - auc: 0.9946 - f1_score: 0.9705 - val_loss: 0.0704 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9953 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 37/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.0869 - accuracy: 0.9742 - precision: 0.9742 - recall: 0.9742 - auc: 0.9943 - f1_score: 0.9742 - val_loss: 0.0777 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9947 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 38/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0800 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9955 - f1_score: 0.9730 - val_loss: 0.0606 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9955 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 39/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0885 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - auc: 0.9933 - f1_score: 0.9749 - val_loss: 0.0772 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9956 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 40/80
# 339/339 [==============================] - 30s 89ms/step - loss: 0.0821 - accuracy: 0.9723 - precision: 0.9723 - recall: 0.9723 - auc: 0.9953 - f1_score: 0.9723 - val_loss: 0.0585 - val_accuracy: 0.9901 - val_precision: 0.9901 - val_recall: 0.9901 - val_auc: 0.9982 - val_f1_score: 0.9901 - lr: 1.0000e-04
# Epoch 41/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0859 - accuracy: 0.9705 - precision: 0.9705 - recall: 0.9705 - auc: 0.9938 - f1_score: 0.9705 - val_loss: 0.0845 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9948 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 42/80
# 339/339 [==============================] - 31s 90ms/step - loss: 0.0773 - accuracy: 0.9738 - precision: 0.9738 - recall: 0.9738 - auc: 0.9958 - f1_score: 0.9738 - val_loss: 0.0906 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9946 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 43/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0807 - accuracy: 0.9716 - precision: 0.9716 - recall: 0.9716 - auc: 0.9956 - f1_score: 0.9716 - val_loss: 0.0945 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9941 - val_f1_score: 0.9728 - lr: 1.0000e-04
# Epoch 44/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0844 - accuracy: 0.9734 - precision: 0.9734 - recall: 0.9734 - auc: 0.9945 - f1_score: 0.9734 - val_loss: 0.0792 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9943 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 45/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.0818 - accuracy: 0.9738 - precision: 0.9738 - recall: 0.9738 - auc: 0.9948 - f1_score: 0.9738 - val_loss: 0.1067 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9925 - val_f1_score: 0.9678 - lr: 1.0000e-04
# Epoch 46/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0856 - accuracy: 0.9734 - precision: 0.9734 - recall: 0.9734 - auc: 0.9945 - f1_score: 0.9734 - val_loss: 0.0843 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9944 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 47/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0786 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9953 - f1_score: 0.9745 - val_loss: 0.0837 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9939 - val_f1_score: 0.9703 - lr: 1.0000e-04
# Epoch 48/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.0833 - accuracy: 0.9742 - precision: 0.9742 - recall: 0.9742 - auc: 0.9948 - f1_score: 0.9742 - val_loss: 0.0982 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9925 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 49/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.0820 - accuracy: 0.9716 - precision: 0.9716 - recall: 0.9716 - auc: 0.9950 - f1_score: 0.9716 - val_loss: 0.1088 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9919 - val_f1_score: 0.9703 - lr: 1.0000e-04
# Epoch 50/80
# 339/339 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9734 - precision: 0.9734 - recall: 0.9734 - auc: 0.9952 - f1_score: 0.9734
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0777 - accuracy: 0.9734 - precision: 0.9734 - recall: 0.9734 - auc: 0.9952 - f1_score: 0.9734 - val_loss: 0.0866 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9939 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 51/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.0737 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9961 - f1_score: 0.9775 - val_loss: 0.0727 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9952 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 52/80
# 339/339 [==============================] - 30s 89ms/step - loss: 0.0690 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9965 - f1_score: 0.9756 - val_loss: 0.0743 - val_accuracy: 0.9851 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9959 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 53/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0718 - accuracy: 0.9778 - precision: 0.9778 - recall: 0.9778 - auc: 0.9959 - f1_score: 0.9778 - val_loss: 0.0844 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9944 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 54/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0740 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9962 - f1_score: 0.9745 - val_loss: 0.0708 - val_accuracy: 0.9876 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9956 - val_f1_score: 0.9876 - lr: 1.0000e-05
# Epoch 55/80
# 339/339 [==============================] - 29s 87ms/step - loss: 0.0718 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9965 - f1_score: 0.9775 - val_loss: 0.0745 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9952 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 56/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0761 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - auc: 0.9957 - f1_score: 0.9749 - val_loss: 0.0873 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9954 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 57/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0760 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9956 - f1_score: 0.9764 - val_loss: 0.0800 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9956 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 58/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0758 - accuracy: 0.9734 - precision: 0.9734 - recall: 0.9734 - auc: 0.9961 - f1_score: 0.9734 - val_loss: 0.0876 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9946 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 59/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.0746 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9959 - f1_score: 0.9775 - val_loss: 0.0786 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9945 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 60/80
# 339/339 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9966 - f1_score: 0.9730
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1e-05.
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0735 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9966 - f1_score: 0.9730 - val_loss: 0.0922 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9936 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 61/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0752 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9959 - f1_score: 0.9771 - val_loss: 0.0870 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9942 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 62/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0771 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9953 - f1_score: 0.9753 - val_loss: 0.0686 - val_accuracy: 0.9827 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9954 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 63/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.0735 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9955 - f1_score: 0.9753 - val_loss: 0.0730 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9953 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 64/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0649 - accuracy: 0.9797 - precision: 0.9797 - recall: 0.9797 - auc: 0.9968 - f1_score: 0.9797 - val_loss: 0.0968 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9941 - val_f1_score: 0.9678 - lr: 1.0000e-05
# Epoch 65/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0731 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9956 - f1_score: 0.9775 - val_loss: 0.0919 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9940 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 66/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0700 - accuracy: 0.9782 - precision: 0.9782 - recall: 0.9782 - auc: 0.9963 - f1_score: 0.9782 - val_loss: 0.0721 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9953 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 67/80
# 339/339 [==============================] - 30s 87ms/step - loss: 0.0764 - accuracy: 0.9742 - precision: 0.9742 - recall: 0.9742 - auc: 0.9957 - f1_score: 0.9742 - val_loss: 0.0816 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9952 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 68/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0720 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9962 - f1_score: 0.9745 - val_loss: 0.0950 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9940 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 69/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0652 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9970 - f1_score: 0.9804 - val_loss: 0.0851 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9938 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 70/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0679 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9967 - f1_score: 0.9771 - val_loss: 0.0856 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9944 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 71/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0734 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9962 - f1_score: 0.9753 - val_loss: 0.0762 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9952 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 72/80
# 339/339 [==============================] - 29s 87ms/step - loss: 0.0686 - accuracy: 0.9760 - precision: 0.9760 - recall: 0.9760 - auc: 0.9971 - f1_score: 0.9760 - val_loss: 0.1073 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9933 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 73/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0693 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9968 - f1_score: 0.9753 - val_loss: 0.0814 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9951 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 74/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0755 - accuracy: 0.9760 - precision: 0.9760 - recall: 0.9760 - auc: 0.9955 - f1_score: 0.9760 - val_loss: 0.0956 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9937 - val_f1_score: 0.9678 - lr: 1.0000e-05
# Epoch 75/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0734 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9956 - f1_score: 0.9745 - val_loss: 0.0839 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9914 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 76/80
# 339/339 [==============================] - 30s 89ms/step - loss: 0.0711 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9966 - f1_score: 0.9753 - val_loss: 0.0861 - val_accuracy: 0.9777 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9939 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 77/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0702 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9965 - f1_score: 0.9771 - val_loss: 0.0788 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9947 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 78/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0774 - accuracy: 0.9719 - precision: 0.9719 - recall: 0.9719 - auc: 0.9961 - f1_score: 0.9719 - val_loss: 0.0750 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9956 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 79/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0742 - accuracy: 0.9760 - precision: 0.9760 - recall: 0.9760 - auc: 0.9962 - f1_score: 0.9760 - val_loss: 0.0842 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9950 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 80/80
# 339/339 [==============================] - 30s 88ms/step - loss: 0.0707 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9965 - f1_score: 0.9745 - val_loss: 0.0982 - val_accuracy: 0.9728 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9918 - val_f1_score: 0.9728 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 1s 10ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9742591390871728
# F1-Score for each class: [0.97463768 0.9738806 ]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9630996309963099
# specificity: 0.9853479853479854

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 17/17 [==============================] - 0s 10ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 69/69 [==============================] - 2s 21ms/step - loss: 0.0789 - accuracy: 0.9745 - precision: 0.9745 - recall: 0.9745 - auc: 0.9949 - f1_score: 0.9745
# Test loss: 0.07892842590808868
# Test accuracy: 0.9745454788208008
# Test precision: 0.9745454788208008
# Test recall: 0.9745454788208008
# Test AUC: 0.9948627948760986
# Test F1 Score: 0.9745455384254456

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 17/17 [==============================] - 0s 10ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       273
#            1       0.98      0.96      0.97       271
#
#     accuracy                           0.97       544
#    macro avg       0.97      0.97      0.97       544
# weighted avg       0.97      0.97      0.97       544

# %%
import pandas as pd


# Generate a classification report (replace this with your actual data)
report = classification_report(all_true_labels, y_pred_labels, output_dict=True)

# Convert to DataFrame
report_df = pd.DataFrame(report).transpose()

# Drop the 'support' column, as it's not suitable for the heatmap
report_df = report_df.drop(columns=['support'])

# Draw the heatmap with the default colormap
plt.figure(figsize=(10, 6))
sns.heatmap(report_df, annot=True, cbar=False)
plt.title("Classification Report")
plt.show()

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
