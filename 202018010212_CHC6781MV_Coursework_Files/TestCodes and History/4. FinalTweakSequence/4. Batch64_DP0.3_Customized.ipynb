# %%
# import zipfile

# f = zipfile.ZipFile("DRD_Split.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"DRD_Split_Cloud")               # 解压到的位置
# f.close()

# %% [markdown]
# <h1>
#     batch size = 64
#     simple_model_1 first layer filters = 128
#     loop filters => 32, 32 64, 32
#     branch filters = 96
#     dropout = 0.3
# </h1>

# %%
# !pip install scipy

# %%
# # !pip install tensorflow-addons==0.18.0
# # !pip install scikit-learn
# !pip install seaborn

# %%
from tensorflow_addons.metrics import F1Score

# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

train_dir = 'DRD_Split_Cloud/DRD_Split/train'
test_dir = 'DRD_Split_Cloud/DRD_Split/test'

batch_size = 64
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = 'DRD_Split_Cloud/DRD_Split/train/diabetic'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2708 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def simple_model_1(input_shape):
    inputs = Input(shape = input_shape)
    #Input convolution
    x = Conv2D(128, (3, 3), activation = 'leaky_relu',
               padding = 'same',kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)
    
    #First Dethwise Convolution
    x = Conv2D(64, (3, 3),  
               padding = 'same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)

    
    #Second convolutional layer
    x = Conv2D(32, (3, 3), 
               padding = 'same',kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)
    
    
    x = GlobalAveragePooling2D()(x)
    model_1 = Model(inputs, x)
    
    return model_1

def resnet_inception_simple(input_shape):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(32, (7, 7), strides=(1, 1), padding='same', activation='relu',
               kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual and Inception Blocks
    for filters in [32, 32, 64, 32]:
        # Residual Block
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x)
        x_r = BatchNormalization()(x_r)
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x_r)
        x_r = BatchNormalization()(x_r)

        # Inception Block
        branch_0 = Conv2D(96, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_0 = BatchNormalization()(branch_0)

        branch_1 = Conv2D(64, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_1 = BatchNormalization()(branch_1)
        branch_1 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_1)
        branch_1 = BatchNormalization()(branch_1)

        branch_2 = Conv2D(128, (1, 1), padding='same', activation='relu',
                          kernel_initializer='he_normal')(x)
        branch_2 = BatchNormalization()(branch_2)
        branch_2 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_2)
        branch_2 = BatchNormalization()(branch_2)
#         branch_2 = Conv2D(64, (3, 3), padding='same', activation='relu')(branch_2)
#         branch_2 = BatchNormalization()(branch_2)

#         branch_3 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(x)
#         branch_3 = Conv2D(64, (1, 1), padding='same', activation='relu')(branch_3)
#         branch_3 = BatchNormalization()(branch_3)

        # Ensure concatenation along the channel axis
        x_i = concatenate([branch_0, branch_1,branch_2], axis = -1)
    
        # Make sure the number of filters after concatenation in x_i matches with x_r
        x_i = Conv2D(filters, (1, 1), padding = 'same', activation = 'relu')(x_i)
        x_i = BatchNormalization()(x_i)
        
        x_r = attention_block_2(x_r)
        x_i = attention_block_2(x_i)

        # Combine Residual and Inception Outputs
        x = Add()([x_r, x_i])
        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    model = Model(inputs, x)
    
    return model



def build_ensemble_model(input_shape):
    inputs = Input(shape = input_shape)

    model_1 = simple_model_1(input_shape)
    output1 = model_1(inputs) 
    
    IR_output = resnet_inception_simple(input_shape)(inputs)
    
    combined_result = concatenate([output1, IR_output])
    
    combined_result = Dropout(0.3)(combined_result)
    
    # 最后的分类层
    outputs = Dense(2, activation='softmax')(combined_result)
    model = Model(inputs = inputs, outputs=outputs)
    
    return model

# %%
model1 = simple_model_1(input_shape)
model1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 96  55392       ['batch_normalization[0][0]']
#                                 )
#
#  activation (Activation)        (None, 224, 224, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 224, 224, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 224, 224, 64  0           ['batch_normalization[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 64  0           ['multiply[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 64  36928       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 96  55392       ['activation_2[0][0]']
#                                 )
#
#  activation_3 (Activation)      (None, 112, 112, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 1)  97          ['activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 112, 112, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 112, 112, 64  0           ['activation_2[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['multiply_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   18464       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 32)  128         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 32)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 96)   27744       ['activation_5[0][0]']
#
#  activation_6 (Activation)      (None, 56, 56, 96)   0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 1)    97          ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 56, 56, 1)    0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 56, 56, 32)   0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 32)  0           ['multiply_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['max_pooling2d_2[0][0]']
#  alAveragePooling2D)
#
# ==================================================================================================
# Total params: 196,643
# Trainable params: 196,323
# Non-trainable params: 320
# __________________________________________________________________________________________________
# 2023-12-08 15:38:30.118747: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-08 15:38:30.650663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6

# %%
model2 = resnet_inception_simple(input_shape)
model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_9 (Conv2D)              (None, 224, 224, 32  4736        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 224, 224, 32  128        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 112, 112, 32  0          ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 112, 112, 64  2112        ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 112, 112, 12  4224        ['max_pooling2d_3[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 112, 112, 64  256        ['conv2d_13[0][0]']
#  rmalization)                   )
#
#  batch_normalization_9 (BatchNo  (None, 112, 112, 12  512        ['conv2d_15[0][0]']
#  rmalization)                   8)
#
#  conv2d_12 (Conv2D)             (None, 112, 112, 96  3168        ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 112, 112, 32  18464       ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 112, 112, 32  36896       ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 112, 112, 32  9248        ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 112, 112, 96  384        ['conv2d_12[0][0]']
#  rmalization)                   )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_14[0][0]']
#  rmalization)                   )
#
#  batch_normalization_10 (BatchN  (None, 112, 112, 32  128        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 32  128        ['conv2d_10[0][0]']
#  rmalization)                   )
#
#  concatenate (Concatenate)      (None, 112, 112, 16  0           ['batch_normalization_6[0][0]',
#                                 0)                                'batch_normalization_8[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 112, 112, 32  9248        ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 112, 112, 32  5152        ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 32  128        ['conv2d_11[0][0]']
#  rmalization)                   )
#
#  batch_normalization_11 (BatchN  (None, 112, 112, 32  128        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 112, 112, 96  27744       ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 112, 112, 96  27744       ['batch_normalization_11[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 112, 112, 96  0           ['conv2d_18[0][0]']
#                                 )
#
#  activation_10 (Activation)     (None, 112, 112, 96  0           ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 112, 112, 1)  97          ['activation_8[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 1)  97          ['activation_10[0][0]']
#
#  activation_9 (Activation)      (None, 112, 112, 1)  0           ['conv2d_19[0][0]']
#
#  activation_11 (Activation)     (None, 112, 112, 1)  0           ['conv2d_21[0][0]']
#
#  multiply_3 (Multiply)          (None, 112, 112, 32  0           ['batch_normalization_5[0][0]',
#                                 )                                 'activation_9[0][0]']
#
#  multiply_4 (Multiply)          (None, 112, 112, 32  0           ['batch_normalization_11[0][0]',
#                                 )                                 'activation_11[0][0]']
#
#  add (Add)                      (None, 112, 112, 32  0           ['multiply_3[0][0]',
#                                 )                                 'multiply_4[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 32)  0           ['add[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 56, 56, 64)   2112        ['max_pooling2d_4[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 56, 56, 128)  4224        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 56, 56, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 56, 56, 128)  512        ['conv2d_27[0][0]']
#  ormalization)
#
#  conv2d_24 (Conv2D)             (None, 56, 56, 96)   3168        ['max_pooling2d_4[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 56, 56, 32)   18464       ['batch_normalization_15[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 56, 56, 32)   36896       ['batch_normalization_17[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 56, 56, 32)   9248        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 56, 56, 96)  384         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 56, 56, 32)  128         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 56, 56, 32)  128         ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 160)  0           ['batch_normalization_14[0][0]',
#                                                                   'batch_normalization_16[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 56, 56, 32)   9248        ['batch_normalization_12[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 56, 56, 32)   5152        ['concatenate_1[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 56, 56, 32)  128         ['conv2d_29[0][0]']
#  ormalization)
#
#  conv2d_30 (Conv2D)             (None, 56, 56, 96)   27744       ['batch_normalization_13[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 56, 56, 96)   27744       ['batch_normalization_19[0][0]']
#
#  activation_12 (Activation)     (None, 56, 56, 96)   0           ['conv2d_30[0][0]']
#
#  activation_14 (Activation)     (None, 56, 56, 96)   0           ['conv2d_32[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 56, 56, 1)    97          ['activation_12[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 56, 56, 1)    97          ['activation_14[0][0]']
#
#  activation_13 (Activation)     (None, 56, 56, 1)    0           ['conv2d_31[0][0]']
#
#  activation_15 (Activation)     (None, 56, 56, 1)    0           ['conv2d_33[0][0]']
#
#  multiply_5 (Multiply)          (None, 56, 56, 32)   0           ['batch_normalization_13[0][0]',
#                                                                   'activation_13[0][0]']
#
#  multiply_6 (Multiply)          (None, 56, 56, 32)   0           ['batch_normalization_19[0][0]',
#                                                                   'activation_15[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 32)   0           ['multiply_5[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 32)  0           ['add_1[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 28, 28, 64)   2112        ['max_pooling2d_5[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 28, 28, 128)  4224        ['max_pooling2d_5[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 128)  512        ['conv2d_39[0][0]']
#  ormalization)
#
#  conv2d_36 (Conv2D)             (None, 28, 28, 96)   3168        ['max_pooling2d_5[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 28, 28, 32)   18464       ['batch_normalization_23[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 28, 28, 32)   36896       ['batch_normalization_25[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 28, 28, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 96)  384         ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 32)  128         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 28, 28, 32)  128         ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 64)  256         ['conv2d_34[0][0]']
#  ormalization)
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 160)  0           ['batch_normalization_22[0][0]',
#                                                                   'batch_normalization_24[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 28, 28, 64)   36928       ['batch_normalization_20[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 28, 28, 64)   10304       ['concatenate_2[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 28, 28, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  conv2d_42 (Conv2D)             (None, 28, 28, 96)   55392       ['batch_normalization_21[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 28, 28, 96)   55392       ['batch_normalization_27[0][0]']
#
#  activation_16 (Activation)     (None, 28, 28, 96)   0           ['conv2d_42[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 96)   0           ['conv2d_44[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 28, 28, 1)    97          ['activation_16[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 28, 28, 1)    97          ['activation_18[0][0]']
#
#  activation_17 (Activation)     (None, 28, 28, 1)    0           ['conv2d_43[0][0]']
#
#  activation_19 (Activation)     (None, 28, 28, 1)    0           ['conv2d_45[0][0]']
#
#  multiply_7 (Multiply)          (None, 28, 28, 64)   0           ['batch_normalization_21[0][0]',
#                                                                   'activation_17[0][0]']
#
#  multiply_8 (Multiply)          (None, 28, 28, 64)   0           ['batch_normalization_27[0][0]',
#                                                                   'activation_19[0][0]']
#
#  add_2 (Add)                    (None, 28, 28, 64)   0           ['multiply_7[0][0]',
#                                                                   'multiply_8[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 64)  0           ['add_2[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 64)   4160        ['max_pooling2d_6[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 14, 14, 128)  8320        ['max_pooling2d_6[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 64)  256         ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 96)   6240        ['max_pooling2d_6[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 32)   18464       ['batch_normalization_31[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 32)   36896       ['batch_normalization_33[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 32)   18464       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 96)  384         ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 32)  128         ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 32)  128         ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 32)  128         ['conv2d_46[0][0]']
#  ormalization)
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 160)  0           ['batch_normalization_30[0][0]',
#                                                                   'batch_normalization_32[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 32)   9248        ['batch_normalization_28[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 32)   5152        ['concatenate_3[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 32)  128         ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 32)  128         ['conv2d_53[0][0]']
#  ormalization)
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 96)   27744       ['batch_normalization_29[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 96)   27744       ['batch_normalization_35[0][0]']
#
#  activation_20 (Activation)     (None, 14, 14, 96)   0           ['conv2d_54[0][0]']
#
#  activation_22 (Activation)     (None, 14, 14, 96)   0           ['conv2d_56[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 1)    97          ['activation_20[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 1)    97          ['activation_22[0][0]']
#
#  activation_21 (Activation)     (None, 14, 14, 1)    0           ['conv2d_55[0][0]']
#
#  activation_23 (Activation)     (None, 14, 14, 1)    0           ['conv2d_57[0][0]']
#
#  multiply_9 (Multiply)          (None, 14, 14, 32)   0           ['batch_normalization_29[0][0]',
#                                                                   'activation_21[0][0]']
#
#  multiply_10 (Multiply)         (None, 14, 14, 32)   0           ['batch_normalization_35[0][0]',
#                                                                   'activation_23[0][0]']
#
#  add_3 (Add)                    (None, 14, 14, 32)   0           ['multiply_9[0][0]',
#                                                                   'multiply_10[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 32)    0           ['add_3[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 32)          0           ['max_pooling2d_7[0][0]']
#  obalAveragePooling2D)
#
# ==================================================================================================
# Total params: 705,000
# Trainable params: 701,160
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
ensemble_model = build_ensemble_model(input_shape)
ensemble_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  model_2 (Functional)           (None, 32)           196643      ['input_3[0][0]']
#
#  model_3 (Functional)           (None, 32)           705000      ['input_3[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 64)           0           ['model_2[0][0]',
#                                                                   'model_3[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['concatenate_8[0][0]']
#
#  dense (Dense)                  (None, 2)            130         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 901,773
# Trainable params: 897,613
# Non-trainable params: 4,160
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


def custum_accuracy(y_true, y_pred):
    # 将预测值四舍五入为0或1
    y_pred_rounded = K.round(y_pred)
    # 比较预测值和真实值
    correct_predictions = K.equal(y_true, y_pred_rounded)
    # 将布尔值转换为浮点数并计算平均值，得到准确率
    return K.mean(K.cast(correct_predictions, 'float32'))

def custom_categorical_crossentropy(y_true, y_pred):
    # 避免0值导致数值问题
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
    # 计算分类交叉熵
    crossentropy = -K.mean(K.sum(y_true * K.log(y_pred), axis=-1))
    return crossentropy


ensemble_model.compile(
    optimizer='adam',
    loss = custom_categorical_crossentropy,
    metrics=[
        custum_accuracy, 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)
lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)
early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=20, verbose=1, 
                               restore_best_weights=True)

# %%
history = ensemble_model.fit(train_generator, epochs = 100, validation_data=(validation_generator), callbacks = [lr_reduction, early_stopping])
# Out:
# Epoch 1/100
# 2023-12-08 15:38:39.087840: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-08 15:38:42.083390: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 43/43 [==============================] - 43s 766ms/step - loss: 0.3752 - custum_accuracy: 0.8437 - precision: 0.8419 - recall: 0.8419 - auc: 0.9149 - f1_score: 0.8419 - val_loss: 0.8352 - val_custum_accuracy: 0.4897 - val_precision: 0.5050 - val_recall: 0.5050 - val_auc: 0.6530 - val_f1_score: 0.5050 - lr: 0.0010
# Epoch 2/100
# 43/43 [==============================] - 30s 719ms/step - loss: 0.2544 - custum_accuracy: 0.9050 - precision: 0.9051 - recall: 0.9051 - auc: 0.9593 - f1_score: 0.9051 - val_loss: 1.1883 - val_custum_accuracy: 0.5116 - val_precision: 0.5074 - val_recall: 0.5074 - val_auc: 0.5655 - val_f1_score: 0.5074 - lr: 0.0010
# Epoch 3/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.2447 - custum_accuracy: 0.9211 - precision: 0.9199 - recall: 0.9199 - auc: 0.9613 - f1_score: 0.9199 - val_loss: 1.1888 - val_custum_accuracy: 0.5165 - val_precision: 0.5074 - val_recall: 0.5074 - val_auc: 0.6169 - val_f1_score: 0.5074 - lr: 0.0010
# Epoch 4/100
# 43/43 [==============================] - 30s 694ms/step - loss: 0.2271 - custum_accuracy: 0.9225 - precision: 0.9221 - recall: 0.9221 - auc: 0.9652 - f1_score: 0.9221 - val_loss: 1.6673 - val_custum_accuracy: 0.4920 - val_precision: 0.5074 - val_recall: 0.5074 - val_auc: 0.4354 - val_f1_score: 0.5074 - lr: 0.0010
# Epoch 5/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.2266 - custum_accuracy: 0.9167 - precision: 0.9162 - recall: 0.9162 - auc: 0.9660 - f1_score: 0.9162 - val_loss: 1.0556 - val_custum_accuracy: 0.5067 - val_precision: 0.5074 - val_recall: 0.5074 - val_auc: 0.6616 - val_f1_score: 0.5074 - lr: 0.0010
# Epoch 6/100
# 43/43 [==============================] - 30s 703ms/step - loss: 0.2139 - custum_accuracy: 0.9297 - precision: 0.9302 - recall: 0.9302 - auc: 0.9687 - f1_score: 0.9302 - val_loss: 0.5259 - val_custum_accuracy: 0.7558 - val_precision: 0.7401 - val_recall: 0.7401 - val_auc: 0.8259 - val_f1_score: 0.7401 - lr: 0.0010
# Epoch 7/100
# 43/43 [==============================] - 30s 703ms/step - loss: 0.2190 - custum_accuracy: 0.9299 - precision: 0.9287 - recall: 0.9287 - auc: 0.9674 - f1_score: 0.9287 - val_loss: 0.7404 - val_custum_accuracy: 0.5786 - val_precision: 0.5817 - val_recall: 0.5817 - val_auc: 0.7101 - val_f1_score: 0.5817 - lr: 0.0010
# Epoch 8/100
# 43/43 [==============================] - 30s 698ms/step - loss: 0.1997 - custum_accuracy: 0.9306 - precision: 0.9295 - recall: 0.9295 - auc: 0.9739 - f1_score: 0.9295 - val_loss: 0.4925 - val_custum_accuracy: 0.7527 - val_precision: 0.7475 - val_recall: 0.7475 - val_auc: 0.8355 - val_f1_score: 0.7475 - lr: 0.0010
# Epoch 9/100
# 43/43 [==============================] - 31s 706ms/step - loss: 0.2080 - custum_accuracy: 0.9272 - precision: 0.9276 - recall: 0.9276 - auc: 0.9709 - f1_score: 0.9276 - val_loss: 0.3187 - val_custum_accuracy: 0.8714 - val_precision: 0.8738 - val_recall: 0.8738 - val_auc: 0.9546 - val_f1_score: 0.8738 - lr: 0.0010
# Epoch 10/100
# 43/43 [==============================] - 30s 697ms/step - loss: 0.1903 - custum_accuracy: 0.9370 - precision: 0.9376 - recall: 0.9376 - auc: 0.9752 - f1_score: 0.9376 - val_loss: 0.4043 - val_custum_accuracy: 0.8330 - val_precision: 0.8366 - val_recall: 0.8366 - val_auc: 0.9055 - val_f1_score: 0.8366 - lr: 0.0010
# Epoch 11/100
# 43/43 [==============================] - 31s 706ms/step - loss: 0.2043 - custum_accuracy: 0.9262 - precision: 0.9258 - recall: 0.9258 - auc: 0.9722 - f1_score: 0.9258 - val_loss: 0.3252 - val_custum_accuracy: 0.8991 - val_precision: 0.8936 - val_recall: 0.8936 - val_auc: 0.9530 - val_f1_score: 0.8936 - lr: 0.0010
# Epoch 12/100
# 43/43 [==============================] - 30s 700ms/step - loss: 0.2099 - custum_accuracy: 0.9272 - precision: 0.9276 - recall: 0.9276 - auc: 0.9715 - f1_score: 0.9276 - val_loss: 0.9720 - val_custum_accuracy: 0.5527 - val_precision: 0.5421 - val_recall: 0.5421 - val_auc: 0.7195 - val_f1_score: 0.5421 - lr: 0.0010
# Epoch 13/100
# 43/43 [==============================] - 31s 704ms/step - loss: 0.2072 - custum_accuracy: 0.9240 - precision: 0.9236 - recall: 0.9236 - auc: 0.9721 - f1_score: 0.9236 - val_loss: 1.9368 - val_custum_accuracy: 0.5665 - val_precision: 0.5520 - val_recall: 0.5520 - val_auc: 0.5364 - val_f1_score: 0.5520 - lr: 0.0010
# Epoch 14/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.1929 - custum_accuracy: 0.9338 - precision: 0.9335 - recall: 0.9335 - auc: 0.9755 - f1_score: 0.9335 - val_loss: 0.4996 - val_custum_accuracy: 0.7049 - val_precision: 0.7054 - val_recall: 0.7054 - val_auc: 0.8304 - val_f1_score: 0.7054 - lr: 0.0010
# Epoch 15/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.1884 - custum_accuracy: 0.9347 - precision: 0.9361 - recall: 0.9361 - auc: 0.9767 - f1_score: 0.9361 - val_loss: 0.3820 - val_custum_accuracy: 0.8362 - val_precision: 0.8292 - val_recall: 0.8292 - val_auc: 0.9192 - val_f1_score: 0.8292 - lr: 0.0010
# Epoch 16/100
# 43/43 [==============================] - 30s 697ms/step - loss: 0.1748 - custum_accuracy: 0.9432 - precision: 0.9431 - recall: 0.9431 - auc: 0.9791 - f1_score: 0.9431 - val_loss: 0.3068 - val_custum_accuracy: 0.8875 - val_precision: 0.8861 - val_recall: 0.8861 - val_auc: 0.9437 - val_f1_score: 0.8861 - lr: 0.0010
# Epoch 17/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.1665 - custum_accuracy: 0.9509 - precision: 0.9501 - recall: 0.9501 - auc: 0.9799 - f1_score: 0.9501 - val_loss: 0.1468 - val_custum_accuracy: 0.9527 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9889 - val_f1_score: 0.9530 - lr: 0.0010
# Epoch 18/100
# 43/43 [==============================] - 31s 706ms/step - loss: 0.1595 - custum_accuracy: 0.9442 - precision: 0.9457 - recall: 0.9457 - auc: 0.9827 - f1_score: 0.9457 - val_loss: 0.3558 - val_custum_accuracy: 0.8487 - val_precision: 0.8540 - val_recall: 0.8540 - val_auc: 0.9412 - val_f1_score: 0.8540 - lr: 0.0010
# Epoch 19/100
# 43/43 [==============================] - 30s 703ms/step - loss: 0.1709 - custum_accuracy: 0.9437 - precision: 0.9428 - recall: 0.9428 - auc: 0.9810 - f1_score: 0.9428 - val_loss: 0.2420 - val_custum_accuracy: 0.9125 - val_precision: 0.9084 - val_recall: 0.9084 - val_auc: 0.9675 - val_f1_score: 0.9084 - lr: 0.0010
# Epoch 20/100
# 43/43 [==============================] - 30s 700ms/step - loss: 0.1537 - custum_accuracy: 0.9501 - precision: 0.9501 - recall: 0.9501 - auc: 0.9837 - f1_score: 0.9501 - val_loss: 0.1598 - val_custum_accuracy: 0.9504 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9859 - val_f1_score: 0.9505 - lr: 0.0010
# Epoch 21/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.1538 - custum_accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9838 - f1_score: 0.9505 - val_loss: 0.3758 - val_custum_accuracy: 0.8321 - val_precision: 0.8465 - val_recall: 0.8465 - val_auc: 0.9147 - val_f1_score: 0.8465 - lr: 0.0010
# Epoch 22/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.1473 - custum_accuracy: 0.9546 - precision: 0.9538 - recall: 0.9538 - auc: 0.9847 - f1_score: 0.9538 - val_loss: 0.2369 - val_custum_accuracy: 0.9353 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9713 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 23/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.1308 - custum_accuracy: 0.9597 - precision: 0.9590 - recall: 0.9590 - auc: 0.9882 - f1_score: 0.9590 - val_loss: 0.3809 - val_custum_accuracy: 0.8665 - val_precision: 0.8738 - val_recall: 0.8738 - val_auc: 0.9222 - val_f1_score: 0.8738 - lr: 0.0010
# Epoch 24/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.1494 - custum_accuracy: 0.9483 - precision: 0.9490 - recall: 0.9490 - auc: 0.9848 - f1_score: 0.9490 - val_loss: 0.2522 - val_custum_accuracy: 0.8754 - val_precision: 0.8837 - val_recall: 0.8837 - val_auc: 0.9609 - val_f1_score: 0.8837 - lr: 0.0010
# Epoch 25/100
# 43/43 [==============================] - 30s 695ms/step - loss: 0.1366 - custum_accuracy: 0.9593 - precision: 0.9586 - recall: 0.9586 - auc: 0.9872 - f1_score: 0.9586 - val_loss: 0.2644 - val_custum_accuracy: 0.8964 - val_precision: 0.8960 - val_recall: 0.8960 - val_auc: 0.9578 - val_f1_score: 0.8960 - lr: 0.0010
# Epoch 26/100
# 43/43 [==============================] - 30s 702ms/step - loss: 0.1228 - custum_accuracy: 0.9625 - precision: 0.9627 - recall: 0.9627 - auc: 0.9886 - f1_score: 0.9627 - val_loss: 0.2895 - val_custum_accuracy: 0.9054 - val_precision: 0.9059 - val_recall: 0.9059 - val_auc: 0.9640 - val_f1_score: 0.9059 - lr: 0.0010
# Epoch 27/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.1252 - custum_accuracy: 0.9593 - precision: 0.9586 - recall: 0.9586 - auc: 0.9894 - f1_score: 0.9586 - val_loss: 0.0964 - val_custum_accuracy: 0.9710 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9948 - val_f1_score: 0.9678 - lr: 0.0010
# Epoch 28/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.1175 - custum_accuracy: 0.9558 - precision: 0.9575 - recall: 0.9575 - auc: 0.9906 - f1_score: 0.9575 - val_loss: 0.1479 - val_custum_accuracy: 0.9478 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9870 - val_f1_score: 0.9530 - lr: 0.0010
# Epoch 29/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.1178 - custum_accuracy: 0.9648 - precision: 0.9642 - recall: 0.9642 - auc: 0.9895 - f1_score: 0.9642 - val_loss: 0.0838 - val_custum_accuracy: 0.9750 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9946 - val_f1_score: 0.9777 - lr: 0.0010
# Epoch 30/100
# 43/43 [==============================] - 30s 694ms/step - loss: 0.1050 - custum_accuracy: 0.9651 - precision: 0.9645 - recall: 0.9645 - auc: 0.9922 - f1_score: 0.9645 - val_loss: 0.1817 - val_custum_accuracy: 0.9237 - val_precision: 0.9208 - val_recall: 0.9208 - val_auc: 0.9815 - val_f1_score: 0.9208 - lr: 0.0010
# Epoch 31/100
# 43/43 [==============================] - 31s 708ms/step - loss: 0.1348 - custum_accuracy: 0.9541 - precision: 0.9542 - recall: 0.9542 - auc: 0.9878 - f1_score: 0.9542 - val_loss: 0.1232 - val_custum_accuracy: 0.9500 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9891 - val_f1_score: 0.9554 - lr: 0.0010
# Epoch 32/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.1159 - custum_accuracy: 0.9655 - precision: 0.9649 - recall: 0.9649 - auc: 0.9902 - f1_score: 0.9649 - val_loss: 0.1758 - val_custum_accuracy: 0.9504 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9842 - val_f1_score: 0.9505 - lr: 0.0010
# Epoch 33/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.1079 - custum_accuracy: 0.9618 - precision: 0.9620 - recall: 0.9620 - auc: 0.9917 - f1_score: 0.9620 - val_loss: 0.1182 - val_custum_accuracy: 0.9643 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9902 - val_f1_score: 0.9604 - lr: 0.0010
# Epoch 34/100
# 43/43 [==============================] - 30s 688ms/step - loss: 0.0932 - custum_accuracy: 0.9713 - precision: 0.9708 - recall: 0.9708 - auc: 0.9932 - f1_score: 0.9708 - val_loss: 0.0894 - val_custum_accuracy: 0.9705 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9942 - val_f1_score: 0.9728 - lr: 0.0010
# Epoch 35/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.0950 - custum_accuracy: 0.9698 - precision: 0.9694 - recall: 0.9694 - auc: 0.9931 - f1_score: 0.9694 - val_loss: 0.3011 - val_custum_accuracy: 0.9304 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9640 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 36/100
# 43/43 [==============================] - 30s 695ms/step - loss: 0.0956 - custum_accuracy: 0.9706 - precision: 0.9701 - recall: 0.9701 - auc: 0.9936 - f1_score: 0.9701 - val_loss: 0.1390 - val_custum_accuracy: 0.9638 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9855 - val_f1_score: 0.9653 - lr: 0.0010
# Epoch 37/100
# 43/43 [==============================] - 30s 697ms/step - loss: 0.0987 - custum_accuracy: 0.9669 - precision: 0.9664 - recall: 0.9664 - auc: 0.9935 - f1_score: 0.9664 - val_loss: 0.1007 - val_custum_accuracy: 0.9888 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9925 - val_f1_score: 0.9876 - lr: 0.0010
# Epoch 38/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.1094 - custum_accuracy: 0.9604 - precision: 0.9597 - recall: 0.9597 - auc: 0.9918 - f1_score: 0.9597 - val_loss: 0.1808 - val_custum_accuracy: 0.9460 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9815 - val_f1_score: 0.9455 - lr: 0.0010
# Epoch 39/100
# 43/43 [==============================] - ETA: 0s - loss: 0.1089 - custum_accuracy: 0.9654 - precision: 0.9657 - recall: 0.9657 - auc: 0.9911 - f1_score: 0.9657
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 43/43 [==============================] - 30s 700ms/step - loss: 0.1089 - custum_accuracy: 0.9654 - precision: 0.9657 - recall: 0.9657 - auc: 0.9911 - f1_score: 0.9657 - val_loss: 0.1756 - val_custum_accuracy: 0.9348 - val_precision: 0.9332 - val_recall: 0.9332 - val_auc: 0.9872 - val_f1_score: 0.9332 - lr: 0.0010
# Epoch 40/100
# 43/43 [==============================] - 30s 700ms/step - loss: 0.0927 - custum_accuracy: 0.9683 - precision: 0.9686 - recall: 0.9686 - auc: 0.9944 - f1_score: 0.9686 - val_loss: 0.1183 - val_custum_accuracy: 0.9545 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9921 - val_f1_score: 0.9604 - lr: 1.0000e-04
# Epoch 41/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.0834 - custum_accuracy: 0.9716 - precision: 0.9719 - recall: 0.9719 - auc: 0.9952 - f1_score: 0.9719 - val_loss: 0.0967 - val_custum_accuracy: 0.9777 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9934 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 42/100
# 43/43 [==============================] - 31s 710ms/step - loss: 0.0846 - custum_accuracy: 0.9706 - precision: 0.9701 - recall: 0.9701 - auc: 0.9952 - f1_score: 0.9701 - val_loss: 0.0949 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9939 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 43/100
# 43/43 [==============================] - 31s 711ms/step - loss: 0.0771 - custum_accuracy: 0.9741 - precision: 0.9753 - recall: 0.9753 - auc: 0.9962 - f1_score: 0.9753 - val_loss: 0.0856 - val_custum_accuracy: 0.9750 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9941 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 44/100
# 43/43 [==============================] - 30s 702ms/step - loss: 0.0759 - custum_accuracy: 0.9742 - precision: 0.9738 - recall: 0.9738 - auc: 0.9962 - f1_score: 0.9738 - val_loss: 0.0886 - val_custum_accuracy: 0.9732 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9947 - val_f1_score: 0.9703 - lr: 1.0000e-04
# Epoch 45/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.0803 - custum_accuracy: 0.9689 - precision: 0.9708 - recall: 0.9708 - auc: 0.9959 - f1_score: 0.9708 - val_loss: 0.0773 - val_custum_accuracy: 0.9866 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9921 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 46/100
# 43/43 [==============================] - 30s 687ms/step - loss: 0.0745 - custum_accuracy: 0.9752 - precision: 0.9756 - recall: 0.9756 - auc: 0.9963 - f1_score: 0.9756 - val_loss: 0.0810 - val_custum_accuracy: 0.9754 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9950 - val_f1_score: 0.9728 - lr: 1.0000e-04
# Epoch 47/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.0695 - custum_accuracy: 0.9760 - precision: 0.9756 - recall: 0.9756 - auc: 0.9969 - f1_score: 0.9756 - val_loss: 0.0794 - val_custum_accuracy: 0.9772 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9953 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 48/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.0703 - custum_accuracy: 0.9741 - precision: 0.9745 - recall: 0.9745 - auc: 0.9970 - f1_score: 0.9745 - val_loss: 0.0781 - val_custum_accuracy: 0.9750 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9948 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 49/100
# 43/43 [==============================] - 30s 695ms/step - loss: 0.0780 - custum_accuracy: 0.9735 - precision: 0.9730 - recall: 0.9730 - auc: 0.9958 - f1_score: 0.9730 - val_loss: 0.0788 - val_custum_accuracy: 0.9844 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9941 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 50/100
# 43/43 [==============================] - 30s 692ms/step - loss: 0.0719 - custum_accuracy: 0.9760 - precision: 0.9756 - recall: 0.9756 - auc: 0.9965 - f1_score: 0.9756 - val_loss: 0.0910 - val_custum_accuracy: 0.9772 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9932 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 51/100
# 43/43 [==============================] - 30s 692ms/step - loss: 0.0697 - custum_accuracy: 0.9746 - precision: 0.9742 - recall: 0.9742 - auc: 0.9967 - f1_score: 0.9742 - val_loss: 0.0927 - val_custum_accuracy: 0.9705 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9941 - val_f1_score: 0.9728 - lr: 1.0000e-04
# Epoch 52/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.0606 - custum_accuracy: 0.9751 - precision: 0.9764 - recall: 0.9764 - auc: 0.9978 - f1_score: 0.9764 - val_loss: 0.0850 - val_custum_accuracy: 0.9844 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9941 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 53/100
# 43/43 [==============================] - 30s 689ms/step - loss: 0.0657 - custum_accuracy: 0.9748 - precision: 0.9760 - recall: 0.9760 - auc: 0.9974 - f1_score: 0.9760 - val_loss: 0.0804 - val_custum_accuracy: 0.9844 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9948 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 54/100
# 43/43 [==============================] - 30s 692ms/step - loss: 0.0611 - custum_accuracy: 0.9793 - precision: 0.9790 - recall: 0.9790 - auc: 0.9973 - f1_score: 0.9790 - val_loss: 0.0773 - val_custum_accuracy: 0.9844 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9946 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 55/100
# 43/43 [==============================] - 30s 691ms/step - loss: 0.0621 - custum_accuracy: 0.9749 - precision: 0.9753 - recall: 0.9753 - auc: 0.9978 - f1_score: 0.9753 - val_loss: 0.0771 - val_custum_accuracy: 0.9821 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9943 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 56/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.0612 - custum_accuracy: 0.9775 - precision: 0.9771 - recall: 0.9771 - auc: 0.9976 - f1_score: 0.9771 - val_loss: 0.0946 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9935 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 57/100
# 43/43 [==============================] - 30s 694ms/step - loss: 0.0691 - custum_accuracy: 0.9767 - precision: 0.9771 - recall: 0.9771 - auc: 0.9966 - f1_score: 0.9771 - val_loss: 0.0937 - val_custum_accuracy: 0.9754 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9928 - val_f1_score: 0.9728 - lr: 1.0000e-04
# Epoch 58/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.0641 - custum_accuracy: 0.9775 - precision: 0.9771 - recall: 0.9771 - auc: 0.9972 - f1_score: 0.9771 - val_loss: 0.0975 - val_custum_accuracy: 0.9777 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9938 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 59/100
# 43/43 [==============================] - 30s 690ms/step - loss: 0.0623 - custum_accuracy: 0.9767 - precision: 0.9764 - recall: 0.9764 - auc: 0.9970 - f1_score: 0.9764 - val_loss: 0.0903 - val_custum_accuracy: 0.9683 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9936 - val_f1_score: 0.9703 - lr: 1.0000e-04
# Epoch 60/100
# 43/43 [==============================] - 30s 694ms/step - loss: 0.0626 - custum_accuracy: 0.9767 - precision: 0.9771 - recall: 0.9771 - auc: 0.9976 - f1_score: 0.9771 - val_loss: 0.0922 - val_custum_accuracy: 0.9777 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9919 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 61/100
# 43/43 [==============================] - 30s 692ms/step - loss: 0.0649 - custum_accuracy: 0.9760 - precision: 0.9756 - recall: 0.9756 - auc: 0.9972 - f1_score: 0.9756 - val_loss: 0.0818 - val_custum_accuracy: 0.9723 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9947 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 62/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.0630 - custum_accuracy: 0.9804 - precision: 0.9801 - recall: 0.9801 - auc: 0.9967 - f1_score: 0.9801 - val_loss: 0.0933 - val_custum_accuracy: 0.9732 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9942 - val_f1_score: 0.9703 - lr: 1.0000e-04
# Epoch 63/100
# 43/43 [==============================] - 30s 689ms/step - loss: 0.0599 - custum_accuracy: 0.9760 - precision: 0.9756 - recall: 0.9756 - auc: 0.9978 - f1_score: 0.9756 - val_loss: 0.0832 - val_custum_accuracy: 0.9844 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9927 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 64/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.0633 - custum_accuracy: 0.9786 - precision: 0.9782 - recall: 0.9782 - auc: 0.9968 - f1_score: 0.9782 - val_loss: 0.0890 - val_custum_accuracy: 0.9777 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9935 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 65/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0554 - custum_accuracy: 0.9807 - precision: 0.9804 - recall: 0.9804 - auc: 0.9977 - f1_score: 0.9804
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 43/43 [==============================] - 30s 701ms/step - loss: 0.0554 - custum_accuracy: 0.9807 - precision: 0.9804 - recall: 0.9804 - auc: 0.9977 - f1_score: 0.9804 - val_loss: 0.0951 - val_custum_accuracy: 0.9777 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9934 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 66/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.0524 - custum_accuracy: 0.9795 - precision: 0.9808 - recall: 0.9808 - auc: 0.9984 - f1_score: 0.9808 - val_loss: 0.0848 - val_custum_accuracy: 0.9772 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9943 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 67/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.0561 - custum_accuracy: 0.9807 - precision: 0.9804 - recall: 0.9804 - auc: 0.9974 - f1_score: 0.9804 - val_loss: 0.0764 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9955 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 68/100
# 43/43 [==============================] - 30s 701ms/step - loss: 0.0571 - custum_accuracy: 0.9793 - precision: 0.9790 - recall: 0.9790 - auc: 0.9977 - f1_score: 0.9790 - val_loss: 0.0973 - val_custum_accuracy: 0.9683 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9927 - val_f1_score: 0.9703 - lr: 1.0000e-05
# Epoch 69/100
# 43/43 [==============================] - 30s 691ms/step - loss: 0.0619 - custum_accuracy: 0.9786 - precision: 0.9782 - recall: 0.9782 - auc: 0.9974 - f1_score: 0.9782 - val_loss: 0.0944 - val_custum_accuracy: 0.9754 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9919 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 70/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.0488 - custum_accuracy: 0.9814 - precision: 0.9819 - recall: 0.9819 - auc: 0.9987 - f1_score: 0.9819 - val_loss: 0.0845 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9946 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 71/100
# 43/43 [==============================] - 31s 704ms/step - loss: 0.0586 - custum_accuracy: 0.9804 - precision: 0.9801 - recall: 0.9801 - auc: 0.9979 - f1_score: 0.9801 - val_loss: 0.0890 - val_custum_accuracy: 0.9777 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9943 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 72/100
# 43/43 [==============================] - 30s 700ms/step - loss: 0.0575 - custum_accuracy: 0.9815 - precision: 0.9812 - recall: 0.9812 - auc: 0.9979 - f1_score: 0.9812 - val_loss: 0.0941 - val_custum_accuracy: 0.9817 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9920 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 73/100
# 43/43 [==============================] - 30s 695ms/step - loss: 0.0528 - custum_accuracy: 0.9783 - precision: 0.9804 - recall: 0.9804 - auc: 0.9981 - f1_score: 0.9804 - val_loss: 0.0829 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9950 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 74/100
# 43/43 [==============================] - 30s 703ms/step - loss: 0.0555 - custum_accuracy: 0.9811 - precision: 0.9808 - recall: 0.9808 - auc: 0.9974 - f1_score: 0.9808 - val_loss: 0.0933 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9913 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 75/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.0575 - custum_accuracy: 0.9804 - precision: 0.9801 - recall: 0.9801 - auc: 0.9976 - f1_score: 0.9801 - val_loss: 0.1050 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9908 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 76/100
# 43/43 [==============================] - 30s 695ms/step - loss: 0.0504 - custum_accuracy: 0.9826 - precision: 0.9823 - recall: 0.9823 - auc: 0.9981 - f1_score: 0.9823 - val_loss: 0.1019 - val_custum_accuracy: 0.9705 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9933 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 77/100
# 43/43 [==============================] - ETA: 0s - loss: 0.0575 - custum_accuracy: 0.9800 - precision: 0.9797 - recall: 0.9797 - auc: 0.9978 - f1_score: 0.9797
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1e-05.
# 43/43 [==============================] - 30s 708ms/step - loss: 0.0575 - custum_accuracy: 0.9800 - precision: 0.9797 - recall: 0.9797 - auc: 0.9978 - f1_score: 0.9797 - val_loss: 0.0834 - val_custum_accuracy: 0.9750 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9945 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 78/100
# 43/43 [==============================] - 30s 690ms/step - loss: 0.0485 - custum_accuracy: 0.9829 - precision: 0.9826 - recall: 0.9826 - auc: 0.9986 - f1_score: 0.9826 - val_loss: 0.0923 - val_custum_accuracy: 0.9754 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9943 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 79/100
# 43/43 [==============================] - 30s 692ms/step - loss: 0.0531 - custum_accuracy: 0.9800 - precision: 0.9797 - recall: 0.9797 - auc: 0.9982 - f1_score: 0.9797 - val_loss: 0.0947 - val_custum_accuracy: 0.9732 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9939 - val_f1_score: 0.9703 - lr: 1.0000e-05
# Epoch 80/100
# 43/43 [==============================] - 30s 687ms/step - loss: 0.0514 - custum_accuracy: 0.9807 - precision: 0.9804 - recall: 0.9804 - auc: 0.9984 - f1_score: 0.9804 - val_loss: 0.0819 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9948 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 81/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.0534 - custum_accuracy: 0.9836 - precision: 0.9834 - recall: 0.9834 - auc: 0.9977 - f1_score: 0.9834 - val_loss: 0.0851 - val_custum_accuracy: 0.9772 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9948 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 82/100
# 43/43 [==============================] - 30s 695ms/step - loss: 0.0479 - custum_accuracy: 0.9821 - precision: 0.9826 - recall: 0.9826 - auc: 0.9987 - f1_score: 0.9826 - val_loss: 0.0833 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9945 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 83/100
# 43/43 [==============================] - 30s 691ms/step - loss: 0.0522 - custum_accuracy: 0.9807 - precision: 0.9804 - recall: 0.9804 - auc: 0.9984 - f1_score: 0.9804 - val_loss: 0.0835 - val_custum_accuracy: 0.9866 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9951 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 84/100
# 43/43 [==============================] - 30s 702ms/step - loss: 0.0499 - custum_accuracy: 0.9829 - precision: 0.9826 - recall: 0.9826 - auc: 0.9985 - f1_score: 0.9826 - val_loss: 0.0916 - val_custum_accuracy: 0.9723 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9946 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 85/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.0549 - custum_accuracy: 0.9751 - precision: 0.9771 - recall: 0.9771 - auc: 0.9981 - f1_score: 0.9771 - val_loss: 0.1013 - val_custum_accuracy: 0.9754 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9915 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 86/100
# 43/43 [==============================] - 30s 689ms/step - loss: 0.0484 - custum_accuracy: 0.9847 - precision: 0.9852 - recall: 0.9852 - auc: 0.9981 - f1_score: 0.9852 - val_loss: 0.1022 - val_custum_accuracy: 0.9705 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9936 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 87/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.0521 - custum_accuracy: 0.9799 - precision: 0.9804 - recall: 0.9804 - auc: 0.9979 - f1_score: 0.9804 - val_loss: 0.0753 - val_custum_accuracy: 0.9866 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9956 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 88/100
# 43/43 [==============================] - 30s 691ms/step - loss: 0.0533 - custum_accuracy: 0.9818 - precision: 0.9815 - recall: 0.9815 - auc: 0.9981 - f1_score: 0.9815 - val_loss: 0.0860 - val_custum_accuracy: 0.9866 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9951 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 89/100
# 43/43 [==============================] - 30s 686ms/step - loss: 0.0571 - custum_accuracy: 0.9786 - precision: 0.9782 - recall: 0.9782 - auc: 0.9980 - f1_score: 0.9782 - val_loss: 0.0768 - val_custum_accuracy: 0.9866 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9953 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 90/100
# 43/43 [==============================] - 30s 686ms/step - loss: 0.0532 - custum_accuracy: 0.9836 - precision: 0.9834 - recall: 0.9834 - auc: 0.9979 - f1_score: 0.9834 - val_loss: 0.0972 - val_custum_accuracy: 0.9777 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9947 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 91/100
# 43/43 [==============================] - 30s 694ms/step - loss: 0.0531 - custum_accuracy: 0.9811 - precision: 0.9808 - recall: 0.9808 - auc: 0.9982 - f1_score: 0.9808 - val_loss: 0.0895 - val_custum_accuracy: 0.9772 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9945 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 92/100
# 43/43 [==============================] - 30s 691ms/step - loss: 0.0525 - custum_accuracy: 0.9826 - precision: 0.9823 - recall: 0.9823 - auc: 0.9981 - f1_score: 0.9823 - val_loss: 0.0660 - val_custum_accuracy: 0.9817 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9958 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 93/100
# 43/43 [==============================] - 30s 692ms/step - loss: 0.0492 - custum_accuracy: 0.9844 - precision: 0.9841 - recall: 0.9841 - auc: 0.9983 - f1_score: 0.9841 - val_loss: 0.0799 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9948 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 94/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.0486 - custum_accuracy: 0.9840 - precision: 0.9838 - recall: 0.9838 - auc: 0.9982 - f1_score: 0.9838 - val_loss: 0.0983 - val_custum_accuracy: 0.9777 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9924 - val_f1_score: 0.9752 - lr: 1.0000e-05
# Epoch 95/100
# 43/43 [==============================] - 30s 693ms/step - loss: 0.0558 - custum_accuracy: 0.9789 - precision: 0.9793 - recall: 0.9793 - auc: 0.9981 - f1_score: 0.9793 - val_loss: 0.0869 - val_custum_accuracy: 0.9772 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9939 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 96/100
# 43/43 [==============================] - 30s 696ms/step - loss: 0.0500 - custum_accuracy: 0.9818 - precision: 0.9815 - recall: 0.9815 - auc: 0.9983 - f1_score: 0.9815 - val_loss: 0.0963 - val_custum_accuracy: 0.9661 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9947 - val_f1_score: 0.9678 - lr: 1.0000e-05
# Epoch 97/100
# 43/43 [==============================] - 30s 690ms/step - loss: 0.0477 - custum_accuracy: 0.9840 - precision: 0.9838 - recall: 0.9838 - auc: 0.9984 - f1_score: 0.9838 - val_loss: 0.0805 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9927 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 98/100
# 43/43 [==============================] - 30s 688ms/step - loss: 0.0525 - custum_accuracy: 0.9820 - precision: 0.9834 - recall: 0.9834 - auc: 0.9981 - f1_score: 0.9834 - val_loss: 0.0958 - val_custum_accuracy: 0.9656 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9940 - val_f1_score: 0.9728 - lr: 1.0000e-05
# Epoch 99/100
# 43/43 [==============================] - 30s 688ms/step - loss: 0.0551 - custum_accuracy: 0.9815 - precision: 0.9812 - recall: 0.9812 - auc: 0.9978 - f1_score: 0.9812 - val_loss: 0.0906 - val_custum_accuracy: 0.9821 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9900 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 100/100
# 43/43 [==============================] - 30s 689ms/step - loss: 0.0525 - custum_accuracy: 0.9799 - precision: 0.9804 - recall: 0.9804 - auc: 0.9979 - f1_score: 0.9804 - val_loss: 0.0981 - val_custum_accuracy: 0.9799 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9918 - val_f1_score: 0.9777 - lr: 1.0000e-05

# %%
plt.figure(figsize = (8, 8))
plt.plot(history.history['custum_accuracy'])
plt.plot(history.history['val_custum_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc ='lower right')
plt.show()


plt.figure(figsize=(8, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc ='upper right')
plt.show()

plt.figure(figsize=(8, 8))
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('precision')
plt.legend(['precision', 'val_precision'], loc = 'lower right')
plt.show()

plt.figure(figsize=(8, 8))
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'],loc='lower right')
plt.show()

plt.figure(figsize=(8, 8))
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model Auc')
plt.xlabel('Epoch')
plt.ylabel('Auc')
plt.legend(['Training Auc', 'Validation Auc'],loc='lower right')
plt.show()

# %%
plt.figure(figsize =(8, 8))
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc= 'lower right')
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = ensemble_model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 16/16 [==============================] - 3s 41ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9804580152671756
# F1-Score for each class: [0.98091603 0.98      ]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.98
# specificity: 0.9809160305343512

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = ensemble_model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 16/16 [==============================] - 1s 42ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = ensemble_model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 9/9 [==============================] - 2s 263ms/step - loss: 0.0668 - custum_accuracy: 0.9797 - precision: 0.9800 - recall: 0.9800 - auc: 0.9947 - f1_score: 0.9800
# Test loss: 0.06678497791290283
# Test accuracy: 0.9797149300575256
# Test precision: 0.9800000190734863
# Test recall: 0.9800000190734863
# Test AUC: 0.9946809411048889
# Test F1 Score: 0.9800000190734863

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = ensemble_model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 16/16 [==============================] - 1s 42ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       262
#            1       0.98      0.98      0.98       250
#
#     accuracy                           0.98       512
#    macro avg       0.98      0.98      0.98       512
# weighted avg       0.98      0.98      0.98       512

# %%
import pandas as pd


# Generate a classification report (replace this with your actual data)
report = classification_report(all_true_labels, y_pred_labels, output_dict=True)

# Convert to DataFrame
report_df = pd.DataFrame(report).transpose()

# Drop the 'support' column, as it's not suitable for the heatmap
report_df = report_df.drop(columns=['support'])

# Draw the heatmap with the default colormap
plt.figure(figsize=(10, 6))
sns.heatmap(report_df, annot=True, cbar=False)
plt.title("Classification Report")
plt.show()

# %%
def generate_grad_cam(ensemble_model, img_array, target_layer, output_layer):
    grad_model = Model(
        [ensemble_model.inputs],
        [ensemble_model.get_layer(target_layer).output, ensemble_model.get_layer(output_layer).output]
    )

    with tf.GradientTape() as tape:
        conv_output, model_output = grad_model(img_array)
        loss = model_output[:, 1]  
    grads = tape.gradient(loss, conv_output)

    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    conv_output = conv_output.numpy()[0]
    pooled_grads = pooled_grads.numpy()
    for i in range(pooled_grads.shape[-1]):
        conv_output[:, :, i] *= pooled_grads[i]

    heatmap = np.mean(conv_output, axis=-1)
    heatmap = np.maximum(heatmap, 0)

    heatmap /= np.max(heatmap)
    return heatmap

output_layer_name1 = model1.output.name.split("/")[0]
output_layer_name2 = model2.output.name.split("/")[0]

num_images = 5

for i in range(num_images):
    batch = next(test_generator)

    img_array = batch[0]
    label = batch[1]
    #conv2d_8,multiply_9 ,multiply_10,add_3 (Add)

    heatmap1 = generate_grad_cam(model1, img_array, 'conv2d_8', output_layer_name1)
    heatmap2 = generate_grad_cam(model2, img_array, 'add_3', output_layer_name2)

    target_size = max(heatmap1.shape[0], heatmap2.shape[0]), max(heatmap1.shape[1], 
                                                                                    heatmap2.shape[1])
    heatmap1_resized = tf.image.resize(heatmap1[..., np.newaxis], target_size)[..., 0]
    heatmap2_resized = tf.image.resize(heatmap2[..., np.newaxis], target_size)[..., 0]
    # heatmap3_resized = tf.image.resize(heatmap3[..., np.newaxis], target_size)[..., 0]
    
    heatmap = (heatmap1_resized + heatmap2_resized) / 2.0

    heatmap_resized = tf.image.resize(heatmap[..., np.newaxis], (224, 224))[..., 0]
    heatmap_weighted = heatmap_resized * 1

    weighted_img = heatmap_weighted[..., np.newaxis] * img_array[0]
    weighted_img /= np.max(weighted_img) 

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img_array[0])
    plt.title(f'Original Image (Label: {label[0]})')

    plt.subplot(1, 3, 2)
    plt.imshow(weighted_img[..., 0],cmap='jet')
    plt.title('Weighted Image')

    plt.show()
