# %% [markdown]
# <h1>
#     Batch size = 8
#     First Conv2D = units 64,
#     branch_0 = Conv2D(64, (1, 1), padding='same',
#                           activation='relu',kernel_initializer='he_normal')(x)
#     Branch is 64 units this time
#
#     loop, 32, 32, 64, 16
# </h1>

# %%
# import zipfile

# f = zipfile.ZipFile("DRD_Split.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"DRD_Split_Cloud")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# # !pip install tensorflow-addons==0.18.0
# # !pip install scikit-learn
# !pip install seaborn

# %%
from tensorflow_addons.metrics import F1Score

# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

train_dir = '/root/DRD_CLAHE_Cloud/DR_CLAHE/train'
test_dir = '/root/DRD_CLAHE_Cloud/DR_CLAHE/test'

batch_size = 8
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/DRD_CLAHE_Cloud/DR_CLAHE/train/diabetic'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2708 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(64, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def simple_model_1(input_shape):
    inputs = Input(shape = input_shape)
    #Input convolution
    x = Conv2D(64, (3, 3), activation = 'leaky_relu',
               padding = 'same',kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)
    
    #First Dethwise Convolution
    x = Conv2D(64, (3, 3),  
               padding = 'same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)

    
    #Second convolutional layer
    x = Conv2D(32, (3, 3), 
               padding = 'same',kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)
    
    
    x = GlobalAveragePooling2D()(x)
    # outputs = Dense(num_classes, activation = 'softmax')(x)
    model_1 = Model(inputs, x)
    
    return model_1

def resnet_inception_simple(input_shape):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(32, (7, 7), strides=(1, 1), padding='same', activation='relu',
               kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual and Inception Blocks
    for filters in [32, 32, 64, 16]:
        # Residual Block
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x)
        x_r = BatchNormalization()(x_r)
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x_r)
        x_r = BatchNormalization()(x_r)

        # Inception Block
        branch_0 = Conv2D(64, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_0 = BatchNormalization()(branch_0)

        branch_1 = Conv2D(64, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_1 = BatchNormalization()(branch_1)
        branch_1 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_1)
        branch_1 = BatchNormalization()(branch_1)

        branch_2 = Conv2D(64, (1, 1), padding='same', activation='relu',
                          kernel_initializer='he_normal')(x)
        branch_2 = BatchNormalization()(branch_2)
        branch_2 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_2)
        branch_2 = BatchNormalization()(branch_2)
        x_i = concatenate([branch_0, branch_1,branch_2], axis = -1)
    
        # Make sure the number of filters after concatenation in x_i matches with x_r
        x_i = Conv2D(filters, (1, 1), padding = 'same', activation = 'relu')(x_i)
        x_i = BatchNormalization()(x_i)
        
        x_r = attention_block_2(x_r)
        x_i = attention_block_2(x_i)
        
        # Combine Residual and Inception Outputs
        x = Add()([x_r, x_i])
        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    # outputs = Dense(2, activation = 'softmax')(x)
    model = Model(inputs, x)
    
    return model

def build_ensemble_model(input_shape):
    inputs = Input(shape = input_shape)

    model_1 = simple_model_1(input_shape)
    output1 = model_1(inputs) 
    
    IR_output = resnet_inception_simple(input_shape)(inputs)
    
    combined_result = concatenate([output1, IR_output])
    
    combined_result = Dropout(0.3)(combined_result)
    
    # 最后的分类层
    outputs = Dense(2, activation='softmax')(combined_result)
    model = Model(inputs = inputs, outputs=outputs)
    
    return model

# %%
ensemble_model = build_ensemble_model(input_shape)
ensemble_model.summary()
# Out:
# 2023-12-10 18:17:43.066707: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-10 18:17:43.664364: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  model (Functional)             (None, 32)           150371      ['input_1[0][0]']
#
#  model_1 (Functional)           (None, 16)           479352      ['input_1[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 48)           0           ['model[0][0]',
#                                                                   'model_1[0][0]']
#
#  dropout (Dropout)              (None, 48)           0           ['concatenate_4[0][0]']
#
#  dense (Dense)                  (None, 2)            98          ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 629,821
# Trainable params: 626,525
# Non-trainable params: 3,296
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


ensemble_model.compile(
    optimizer='adam',
    loss = 'categorical_crossentropy',
    metrics=[
        'accuracy', 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'macro')
    ]
)
lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)
# early_stopping = EarlyStopping(monitor='val_loss', 
#                                patience=20, verbose=1, 
#                                restore_best_weights=True)

# %%
history = ensemble_model.fit(train_generator, epochs = 80, validation_data=(validation_generator), callbacks = [lr_reduction])
# Out:
# Epoch 1/80
# 2023-12-10 18:17:51.369793: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-10 18:17:53.192103: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 339/339 [==============================] - 44s 107ms/step - loss: 0.4083 - accuracy: 0.8168 - precision: 0.8168 - recall: 0.8168 - auc: 0.8971 - f1_score: 0.8167 - val_loss: 0.8384 - val_accuracy: 0.5866 - val_precision: 0.5866 - val_recall: 0.5866 - val_auc: 0.6657 - val_f1_score: 0.5153 - lr: 0.0010
# Epoch 2/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.3520 - accuracy: 0.8578 - precision: 0.8578 - recall: 0.8578 - auc: 0.9256 - f1_score: 0.8578 - val_loss: 1.7102 - val_accuracy: 0.4926 - val_precision: 0.4926 - val_recall: 0.4926 - val_auc: 0.6986 - val_f1_score: 0.3300 - lr: 0.0010
# Epoch 3/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.3044 - accuracy: 0.8789 - precision: 0.8789 - recall: 0.8789 - auc: 0.9435 - f1_score: 0.8789 - val_loss: 3.0625 - val_accuracy: 0.4926 - val_precision: 0.4926 - val_recall: 0.4926 - val_auc: 0.5586 - val_f1_score: 0.3300 - lr: 0.0010
# Epoch 4/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.3023 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9443 - f1_score: 0.8811 - val_loss: 1.5631 - val_accuracy: 0.4926 - val_precision: 0.4926 - val_recall: 0.4926 - val_auc: 0.6565 - val_f1_score: 0.3300 - lr: 0.0010
# Epoch 5/80
# 339/339 [==============================] - 33s 98ms/step - loss: 0.2817 - accuracy: 0.8837 - precision: 0.8837 - recall: 0.8837 - auc: 0.9516 - f1_score: 0.8837 - val_loss: 0.8782 - val_accuracy: 0.6658 - val_precision: 0.6658 - val_recall: 0.6658 - val_auc: 0.7878 - val_f1_score: 0.6238 - lr: 0.0010
# Epoch 6/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.2614 - accuracy: 0.8973 - precision: 0.8973 - recall: 0.8973 - auc: 0.9582 - f1_score: 0.8973 - val_loss: 0.3053 - val_accuracy: 0.8713 - val_precision: 0.8713 - val_recall: 0.8713 - val_auc: 0.9476 - val_f1_score: 0.8709 - lr: 0.0010
# Epoch 7/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.2502 - accuracy: 0.9066 - precision: 0.9066 - recall: 0.9066 - auc: 0.9617 - f1_score: 0.9066 - val_loss: 0.3247 - val_accuracy: 0.8985 - val_precision: 0.8985 - val_recall: 0.8985 - val_auc: 0.9447 - val_f1_score: 0.8985 - lr: 0.0010
# Epoch 8/80
# 339/339 [==============================] - 34s 101ms/step - loss: 0.2558 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9595 - f1_score: 0.9032 - val_loss: 0.2417 - val_accuracy: 0.9010 - val_precision: 0.9010 - val_recall: 0.9010 - val_auc: 0.9648 - val_f1_score: 0.9007 - lr: 0.0010
# Epoch 9/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.2375 - accuracy: 0.9136 - precision: 0.9136 - recall: 0.9136 - auc: 0.9644 - f1_score: 0.9136 - val_loss: 0.4963 - val_accuracy: 0.7921 - val_precision: 0.7921 - val_recall: 0.7921 - val_auc: 0.8976 - val_f1_score: 0.7849 - lr: 0.0010
# Epoch 10/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.2150 - accuracy: 0.9243 - precision: 0.9243 - recall: 0.9243 - auc: 0.9706 - f1_score: 0.9243 - val_loss: 0.6873 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7993 - val_f1_score: 0.6976 - lr: 0.0010
# Epoch 11/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.2046 - accuracy: 0.9254 - precision: 0.9254 - recall: 0.9254 - auc: 0.9738 - f1_score: 0.9254 - val_loss: 0.6884 - val_accuracy: 0.7327 - val_precision: 0.7327 - val_recall: 0.7327 - val_auc: 0.8640 - val_f1_score: 0.7145 - lr: 0.0010
# Epoch 12/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.2238 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9691 - f1_score: 0.9191 - val_loss: 1.1551 - val_accuracy: 0.6411 - val_precision: 0.6411 - val_recall: 0.6411 - val_auc: 0.7353 - val_f1_score: 0.5960 - lr: 0.0010
# Epoch 13/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.2144 - accuracy: 0.9206 - precision: 0.9206 - recall: 0.9206 - auc: 0.9711 - f1_score: 0.9206 - val_loss: 0.8519 - val_accuracy: 0.6856 - val_precision: 0.6856 - val_recall: 0.6856 - val_auc: 0.8003 - val_f1_score: 0.6558 - lr: 0.0010
# Epoch 14/80
# 339/339 [==============================] - 34s 99ms/step - loss: 0.1985 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9746 - f1_score: 0.9302 - val_loss: 0.8260 - val_accuracy: 0.6411 - val_precision: 0.6411 - val_recall: 0.6411 - val_auc: 0.7522 - val_f1_score: 0.5945 - lr: 0.0010
# Epoch 15/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.2124 - accuracy: 0.9247 - precision: 0.9247 - recall: 0.9247 - auc: 0.9715 - f1_score: 0.9247 - val_loss: 0.2871 - val_accuracy: 0.8911 - val_precision: 0.8911 - val_recall: 0.8911 - val_auc: 0.9577 - val_f1_score: 0.8898 - lr: 0.0010
# Epoch 16/80
# 339/339 [==============================] - 34s 100ms/step - loss: 0.2107 - accuracy: 0.9243 - precision: 0.9243 - recall: 0.9243 - auc: 0.9720 - f1_score: 0.9243 - val_loss: 0.1840 - val_accuracy: 0.9282 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9788 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 17/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1858 - accuracy: 0.9354 - precision: 0.9354 - recall: 0.9354 - auc: 0.9777 - f1_score: 0.9354 - val_loss: 0.5642 - val_accuracy: 0.8342 - val_precision: 0.8342 - val_recall: 0.8342 - val_auc: 0.8963 - val_f1_score: 0.8319 - lr: 0.0010
# Epoch 18/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1987 - accuracy: 0.9265 - precision: 0.9265 - recall: 0.9265 - auc: 0.9751 - f1_score: 0.9265 - val_loss: 1.5172 - val_accuracy: 0.6139 - val_precision: 0.6139 - val_recall: 0.6139 - val_auc: 0.7256 - val_f1_score: 0.5521 - lr: 0.0010
# Epoch 19/80
# 339/339 [==============================] - 32s 94ms/step - loss: 0.1942 - accuracy: 0.9306 - precision: 0.9306 - recall: 0.9306 - auc: 0.9762 - f1_score: 0.9306 - val_loss: 0.9652 - val_accuracy: 0.5817 - val_precision: 0.5817 - val_recall: 0.5817 - val_auc: 0.6675 - val_f1_score: 0.5462 - lr: 0.0010
# Epoch 20/80
# 339/339 [==============================] - 34s 101ms/step - loss: 0.1786 - accuracy: 0.9324 - precision: 0.9324 - recall: 0.9324 - auc: 0.9800 - f1_score: 0.9324 - val_loss: 0.3360 - val_accuracy: 0.8589 - val_precision: 0.8589 - val_recall: 0.8589 - val_auc: 0.9330 - val_f1_score: 0.8570 - lr: 0.0010
# Epoch 21/80
# 339/339 [==============================] - 34s 100ms/step - loss: 0.2026 - accuracy: 0.9291 - precision: 0.9291 - recall: 0.9291 - auc: 0.9736 - f1_score: 0.9291 - val_loss: 0.4029 - val_accuracy: 0.8713 - val_precision: 0.8713 - val_recall: 0.8713 - val_auc: 0.9303 - val_f1_score: 0.8708 - lr: 0.0010
# Epoch 22/80
# 339/339 [==============================] - 36s 105ms/step - loss: 0.1844 - accuracy: 0.9365 - precision: 0.9365 - recall: 0.9365 - auc: 0.9783 - f1_score: 0.9365 - val_loss: 0.1802 - val_accuracy: 0.9282 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9808 - val_f1_score: 0.9281 - lr: 0.0010
# Epoch 23/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1908 - accuracy: 0.9365 - precision: 0.9365 - recall: 0.9365 - auc: 0.9764 - f1_score: 0.9365 - val_loss: 0.6854 - val_accuracy: 0.7450 - val_precision: 0.7450 - val_recall: 0.7450 - val_auc: 0.8474 - val_f1_score: 0.7295 - lr: 0.0010
# Epoch 24/80
# 339/339 [==============================] - 32s 96ms/step - loss: 0.1750 - accuracy: 0.9394 - precision: 0.9394 - recall: 0.9394 - auc: 0.9802 - f1_score: 0.9394 - val_loss: 0.3478 - val_accuracy: 0.8243 - val_precision: 0.8243 - val_recall: 0.8243 - val_auc: 0.9236 - val_f1_score: 0.8196 - lr: 0.0010
# Epoch 25/80
# 339/339 [==============================] - 34s 100ms/step - loss: 0.1819 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9796 - f1_score: 0.9328 - val_loss: 0.3968 - val_accuracy: 0.8589 - val_precision: 0.8589 - val_recall: 0.8589 - val_auc: 0.9389 - val_f1_score: 0.8560 - lr: 0.0010
# Epoch 26/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1783 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9793 - f1_score: 0.9350 - val_loss: 0.8034 - val_accuracy: 0.7178 - val_precision: 0.7178 - val_recall: 0.7178 - val_auc: 0.8071 - val_f1_score: 0.6961 - lr: 0.0010
# Epoch 27/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1963 - accuracy: 0.9269 - precision: 0.9269 - recall: 0.9269 - auc: 0.9757 - f1_score: 0.9269 - val_loss: 0.5321 - val_accuracy: 0.7302 - val_precision: 0.7302 - val_recall: 0.7302 - val_auc: 0.8065 - val_f1_score: 0.7297 - lr: 0.0010
# Epoch 28/80
# 339/339 [==============================] - 34s 101ms/step - loss: 0.1853 - accuracy: 0.9339 - precision: 0.9339 - recall: 0.9339 - auc: 0.9778 - f1_score: 0.9339 - val_loss: 1.6273 - val_accuracy: 0.5495 - val_precision: 0.5495 - val_recall: 0.5495 - val_auc: 0.7064 - val_f1_score: 0.4440 - lr: 0.0010
# Epoch 29/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1611 - accuracy: 0.9439 - precision: 0.9439 - recall: 0.9439 - auc: 0.9832 - f1_score: 0.9439 - val_loss: 0.5367 - val_accuracy: 0.7376 - val_precision: 0.7376 - val_recall: 0.7376 - val_auc: 0.8548 - val_f1_score: 0.7205 - lr: 0.0010
# Epoch 30/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1633 - accuracy: 0.9417 - precision: 0.9417 - recall: 0.9417 - auc: 0.9830 - f1_score: 0.9416 - val_loss: 0.7620 - val_accuracy: 0.7054 - val_precision: 0.7054 - val_recall: 0.7054 - val_auc: 0.8231 - val_f1_score: 0.6804 - lr: 0.0010
# Epoch 31/80
# 339/339 [==============================] - 32s 96ms/step - loss: 0.1601 - accuracy: 0.9428 - precision: 0.9428 - recall: 0.9428 - auc: 0.9833 - f1_score: 0.9428 - val_loss: 0.2363 - val_accuracy: 0.9084 - val_precision: 0.9084 - val_recall: 0.9084 - val_auc: 0.9665 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 32/80
# 339/339 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.9383 - precision: 0.9383 - recall: 0.9383 - auc: 0.9798 - f1_score: 0.9383
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 339/339 [==============================] - 33s 98ms/step - loss: 0.1764 - accuracy: 0.9383 - precision: 0.9383 - recall: 0.9383 - auc: 0.9798 - f1_score: 0.9383 - val_loss: 0.4094 - val_accuracy: 0.8416 - val_precision: 0.8416 - val_recall: 0.8416 - val_auc: 0.9210 - val_f1_score: 0.8387 - lr: 0.0010
# Epoch 33/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1578 - accuracy: 0.9439 - precision: 0.9439 - recall: 0.9439 - auc: 0.9836 - f1_score: 0.9439 - val_loss: 0.1376 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9847 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 34/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1452 - accuracy: 0.9494 - precision: 0.9494 - recall: 0.9494 - auc: 0.9858 - f1_score: 0.9494 - val_loss: 0.1280 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9871 - val_f1_score: 0.9653 - lr: 1.0000e-04
# Epoch 35/80
# 339/339 [==============================] - 32s 96ms/step - loss: 0.1392 - accuracy: 0.9513 - precision: 0.9513 - recall: 0.9513 - auc: 0.9872 - f1_score: 0.9513 - val_loss: 0.1317 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9884 - val_f1_score: 0.9529 - lr: 1.0000e-04
# Epoch 36/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1489 - accuracy: 0.9520 - precision: 0.9520 - recall: 0.9520 - auc: 0.9848 - f1_score: 0.9520 - val_loss: 0.1254 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9881 - val_f1_score: 0.9653 - lr: 1.0000e-04
# Epoch 37/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1299 - accuracy: 0.9594 - precision: 0.9594 - recall: 0.9594 - auc: 0.9877 - f1_score: 0.9594 - val_loss: 0.1304 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9884 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 38/80
# 339/339 [==============================] - 33s 98ms/step - loss: 0.1324 - accuracy: 0.9535 - precision: 0.9535 - recall: 0.9535 - auc: 0.9884 - f1_score: 0.9535 - val_loss: 0.1220 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9910 - val_f1_score: 0.9480 - lr: 1.0000e-04
# Epoch 39/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1371 - accuracy: 0.9575 - precision: 0.9575 - recall: 0.9575 - auc: 0.9869 - f1_score: 0.9575 - val_loss: 0.1235 - val_accuracy: 0.9604 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9894 - val_f1_score: 0.9604 - lr: 1.0000e-04
# Epoch 40/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1292 - accuracy: 0.9568 - precision: 0.9568 - recall: 0.9568 - auc: 0.9882 - f1_score: 0.9568 - val_loss: 0.1308 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9891 - val_f1_score: 0.9530 - lr: 1.0000e-04
# Epoch 41/80
# 339/339 [==============================] - 35s 103ms/step - loss: 0.1289 - accuracy: 0.9590 - precision: 0.9590 - recall: 0.9590 - auc: 0.9880 - f1_score: 0.9590 - val_loss: 0.1170 - val_accuracy: 0.9604 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9909 - val_f1_score: 0.9604 - lr: 1.0000e-04
# Epoch 42/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1435 - accuracy: 0.9538 - precision: 0.9538 - recall: 0.9538 - auc: 0.9853 - f1_score: 0.9538 - val_loss: 0.1451 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9870 - val_f1_score: 0.9480 - lr: 1.0000e-04
# Epoch 43/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1176 - accuracy: 0.9590 - precision: 0.9590 - recall: 0.9590 - auc: 0.9907 - f1_score: 0.9590 - val_loss: 0.1107 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9918 - val_f1_score: 0.9629 - lr: 1.0000e-04
# Epoch 44/80
# 339/339 [==============================] - 35s 104ms/step - loss: 0.1267 - accuracy: 0.9546 - precision: 0.9546 - recall: 0.9546 - auc: 0.9892 - f1_score: 0.9546 - val_loss: 0.1329 - val_accuracy: 0.9604 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9848 - val_f1_score: 0.9604 - lr: 1.0000e-04
# Epoch 45/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1238 - accuracy: 0.9572 - precision: 0.9572 - recall: 0.9572 - auc: 0.9900 - f1_score: 0.9572 - val_loss: 0.1359 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9871 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 46/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1302 - accuracy: 0.9501 - precision: 0.9501 - recall: 0.9501 - auc: 0.9890 - f1_score: 0.9501 - val_loss: 0.1159 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9915 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 47/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1252 - accuracy: 0.9605 - precision: 0.9605 - recall: 0.9605 - auc: 0.9894 - f1_score: 0.9605 - val_loss: 0.1172 - val_accuracy: 0.9604 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9909 - val_f1_score: 0.9604 - lr: 1.0000e-04
# Epoch 48/80
# 339/339 [==============================] - 33s 99ms/step - loss: 0.1279 - accuracy: 0.9575 - precision: 0.9575 - recall: 0.9575 - auc: 0.9887 - f1_score: 0.9575 - val_loss: 0.1122 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9909 - val_f1_score: 0.9629 - lr: 1.0000e-04
# Epoch 49/80
# 339/339 [==============================] - 33s 98ms/step - loss: 0.1232 - accuracy: 0.9597 - precision: 0.9597 - recall: 0.9597 - auc: 0.9895 - f1_score: 0.9597 - val_loss: 0.1028 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9920 - val_f1_score: 0.9653 - lr: 1.0000e-04
# Epoch 50/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1160 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9908 - f1_score: 0.9642 - val_loss: 0.1290 - val_accuracy: 0.9554 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9868 - val_f1_score: 0.9554 - lr: 1.0000e-04
# Epoch 51/80
# 339/339 [==============================] - 32s 94ms/step - loss: 0.1180 - accuracy: 0.9620 - precision: 0.9620 - recall: 0.9620 - auc: 0.9903 - f1_score: 0.9620 - val_loss: 0.1058 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9920 - val_f1_score: 0.9678 - lr: 1.0000e-04
# Epoch 52/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1156 - accuracy: 0.9616 - precision: 0.9616 - recall: 0.9616 - auc: 0.9908 - f1_score: 0.9616 - val_loss: 0.1463 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9833 - val_f1_score: 0.9629 - lr: 1.0000e-04
# Epoch 53/80
# 339/339 [==============================] - 33s 98ms/step - loss: 0.1123 - accuracy: 0.9645 - precision: 0.9645 - recall: 0.9645 - auc: 0.9914 - f1_score: 0.9645 - val_loss: 0.1111 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9901 - val_f1_score: 0.9678 - lr: 1.0000e-04
# Epoch 54/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1163 - accuracy: 0.9586 - precision: 0.9586 - recall: 0.9586 - auc: 0.9909 - f1_score: 0.9586 - val_loss: 0.1229 - val_accuracy: 0.9604 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9889 - val_f1_score: 0.9604 - lr: 1.0000e-04
# Epoch 55/80
# 339/339 [==============================] - 33s 98ms/step - loss: 0.1030 - accuracy: 0.9682 - precision: 0.9682 - recall: 0.9682 - auc: 0.9929 - f1_score: 0.9682 - val_loss: 0.1208 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9895 - val_f1_score: 0.9530 - lr: 1.0000e-04
# Epoch 56/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1122 - accuracy: 0.9616 - precision: 0.9616 - recall: 0.9616 - auc: 0.9918 - f1_score: 0.9616 - val_loss: 0.1180 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9908 - val_f1_score: 0.9629 - lr: 1.0000e-04
# Epoch 57/80
# 339/339 [==============================] - 36s 106ms/step - loss: 0.1078 - accuracy: 0.9631 - precision: 0.9631 - recall: 0.9631 - auc: 0.9920 - f1_score: 0.9631 - val_loss: 0.1732 - val_accuracy: 0.9455 - val_precision: 0.9455 - val_recall: 0.9455 - val_auc: 0.9795 - val_f1_score: 0.9455 - lr: 1.0000e-04
# Epoch 58/80
# 339/339 [==============================] - 36s 107ms/step - loss: 0.1188 - accuracy: 0.9594 - precision: 0.9594 - recall: 0.9594 - auc: 0.9907 - f1_score: 0.9594 - val_loss: 0.1194 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9888 - val_f1_score: 0.9653 - lr: 1.0000e-04
# Epoch 59/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1128 - accuracy: 0.9653 - precision: 0.9653 - recall: 0.9653 - auc: 0.9906 - f1_score: 0.9653 - val_loss: 0.0866 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9949 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 60/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1110 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - auc: 0.9914 - f1_score: 0.9627 - val_loss: 0.1238 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9885 - val_f1_score: 0.9703 - lr: 1.0000e-04
# Epoch 61/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1054 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9915 - f1_score: 0.9675 - val_loss: 0.1166 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9901 - val_f1_score: 0.9678 - lr: 1.0000e-04
# Epoch 62/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1106 - accuracy: 0.9609 - precision: 0.9609 - recall: 0.9609 - auc: 0.9918 - f1_score: 0.9609 - val_loss: 0.1188 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9893 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 63/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1171 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - auc: 0.9905 - f1_score: 0.9627 - val_loss: 0.1224 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9889 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 64/80
# 339/339 [==============================] - 32s 96ms/step - loss: 0.1091 - accuracy: 0.9623 - precision: 0.9623 - recall: 0.9623 - auc: 0.9924 - f1_score: 0.9623 - val_loss: 0.1197 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9902 - val_f1_score: 0.9628 - lr: 1.0000e-04
# Epoch 65/80
# 339/339 [==============================] - 33s 98ms/step - loss: 0.1098 - accuracy: 0.9638 - precision: 0.9638 - recall: 0.9638 - auc: 0.9918 - f1_score: 0.9638 - val_loss: 0.1337 - val_accuracy: 0.9505 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9889 - val_f1_score: 0.9505 - lr: 1.0000e-04
# Epoch 66/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1080 - accuracy: 0.9586 - precision: 0.9586 - recall: 0.9586 - auc: 0.9922 - f1_score: 0.9586 - val_loss: 0.1176 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9916 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 67/80
# 339/339 [==============================] - 32s 95ms/step - loss: 0.1084 - accuracy: 0.9623 - precision: 0.9623 - recall: 0.9623 - auc: 0.9913 - f1_score: 0.9623 - val_loss: 0.0969 - val_accuracy: 0.9752 - val_precision: 0.9752 - val_recall: 0.9752 - val_auc: 0.9918 - val_f1_score: 0.9752 - lr: 1.0000e-04
# Epoch 68/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1119 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - auc: 0.9915 - f1_score: 0.9627 - val_loss: 0.1250 - val_accuracy: 0.9480 - val_precision: 0.9480 - val_recall: 0.9480 - val_auc: 0.9902 - val_f1_score: 0.9480 - lr: 1.0000e-04
# Epoch 69/80
# 339/339 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9660 - precision: 0.9660 - recall: 0.9660 - auc: 0.9928 - f1_score: 0.9660
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1032 - accuracy: 0.9660 - precision: 0.9660 - recall: 0.9660 - auc: 0.9928 - f1_score: 0.9660 - val_loss: 0.1084 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9927 - val_f1_score: 0.9579 - lr: 1.0000e-04
# Epoch 70/80
# 339/339 [==============================] - 34s 99ms/step - loss: 0.1001 - accuracy: 0.9645 - precision: 0.9645 - recall: 0.9645 - auc: 0.9930 - f1_score: 0.9645 - val_loss: 0.1153 - val_accuracy: 0.9653 - val_precision: 0.9653 - val_recall: 0.9653 - val_auc: 0.9908 - val_f1_score: 0.9653 - lr: 1.0000e-05
# Epoch 71/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1009 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9933 - f1_score: 0.9642 - val_loss: 0.1111 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9913 - val_f1_score: 0.9628 - lr: 1.0000e-05
# Epoch 72/80
# 339/339 [==============================] - 32s 96ms/step - loss: 0.1052 - accuracy: 0.9660 - precision: 0.9660 - recall: 0.9660 - auc: 0.9927 - f1_score: 0.9660 - val_loss: 0.1015 - val_accuracy: 0.9703 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9928 - val_f1_score: 0.9703 - lr: 1.0000e-05
# Epoch 73/80
# 339/339 [==============================] - 32s 96ms/step - loss: 0.1061 - accuracy: 0.9657 - precision: 0.9657 - recall: 0.9657 - auc: 0.9920 - f1_score: 0.9657 - val_loss: 0.1241 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9893 - val_f1_score: 0.9530 - lr: 1.0000e-05
# Epoch 74/80
# 339/339 [==============================] - 32s 96ms/step - loss: 0.1000 - accuracy: 0.9660 - precision: 0.9660 - recall: 0.9660 - auc: 0.9932 - f1_score: 0.9660 - val_loss: 0.1219 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9856 - val_f1_score: 0.9678 - lr: 1.0000e-05
# Epoch 75/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.1003 - accuracy: 0.9620 - precision: 0.9620 - recall: 0.9620 - auc: 0.9937 - f1_score: 0.9620 - val_loss: 0.1222 - val_accuracy: 0.9554 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9882 - val_f1_score: 0.9554 - lr: 1.0000e-05
# Epoch 76/80
# 339/339 [==============================] - 33s 97ms/step - loss: 0.1024 - accuracy: 0.9653 - precision: 0.9653 - recall: 0.9653 - auc: 0.9927 - f1_score: 0.9653 - val_loss: 0.0991 - val_accuracy: 0.9678 - val_precision: 0.9678 - val_recall: 0.9678 - val_auc: 0.9919 - val_f1_score: 0.9678 - lr: 1.0000e-05
# Epoch 77/80
# 339/339 [==============================] - 33s 96ms/step - loss: 0.0980 - accuracy: 0.9668 - precision: 0.9668 - recall: 0.9668 - auc: 0.9939 - f1_score: 0.9668 - val_loss: 0.1088 - val_accuracy: 0.9604 - val_precision: 0.9604 - val_recall: 0.9604 - val_auc: 0.9929 - val_f1_score: 0.9604 - lr: 1.0000e-05
# Epoch 78/80
# 339/339 [==============================] - 35s 103ms/step - loss: 0.0990 - accuracy: 0.9671 - precision: 0.9671 - recall: 0.9671 - auc: 0.9935 - f1_score: 0.9671 - val_loss: 0.1159 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9910 - val_f1_score: 0.9629 - lr: 1.0000e-05
# Epoch 79/80
# 339/339 [==============================] - ETA: 0s - loss: 0.0980 - accuracy: 0.9649 - precision: 0.9649 - recall: 0.9649 - auc: 0.9937 - f1_score: 0.9649
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1e-05.
# 339/339 [==============================] - 33s 97ms/step - loss: 0.0980 - accuracy: 0.9649 - precision: 0.9649 - recall: 0.9649 - auc: 0.9937 - f1_score: 0.9649 - val_loss: 0.1202 - val_accuracy: 0.9530 - val_precision: 0.9530 - val_recall: 0.9530 - val_auc: 0.9891 - val_f1_score: 0.9530 - lr: 1.0000e-05
# Epoch 80/80
# 339/339 [==============================] - 36s 105ms/step - loss: 0.1001 - accuracy: 0.9657 - precision: 0.9657 - recall: 0.9657 - auc: 0.9932 - f1_score: 0.9657 - val_loss: 0.1107 - val_accuracy: 0.9579 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9923 - val_f1_score: 0.9579 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = ensemble_model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["diabetic", "normal"], yticklabels=["diabetic", "normal"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 2s 35ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9206983642681583
# F1-Score for each class: [0.91617934 0.92521739]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9925373134328358
# specificity: 0.8514492753623188

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = ensemble_model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 17/17 [==============================] - 1s 36ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = ensemble_model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 69/69 [==============================] - 2s 23ms/step - loss: 0.2578 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9696 - f1_score: 0.9197
# Test loss: 0.2577526569366455
# Test accuracy: 0.9200000166893005
# Test precision: 0.9200000166893005
# Test recall: 0.9200000166893005
# Test AUC: 0.9695751667022705
# Test F1 Score: 0.9197282791137695

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = ensemble_model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 17/17 [==============================] - 1s 37ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.85      0.92       276
#            1       0.87      0.99      0.93       268
#
#     accuracy                           0.92       544
#    macro avg       0.93      0.92      0.92       544
# weighted avg       0.93      0.92      0.92       544

# %%
import pandas as pd


# Generate a classification report (replace this with your actual data)
report = classification_report(all_true_labels, y_pred_labels, output_dict=True)

# Convert to DataFrame
report_df = pd.DataFrame(report).transpose()

# Drop the 'support' column, as it's not suitable for the heatmap
report_df = report_df.drop(columns=['support'])

# Draw the heatmap with the default colormap
plt.figure(figsize=(10, 6))
sns.heatmap(report_df, annot=True, cbar=False)
plt.title("Classification Report")
plt.show()

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del resnet_inception_simple


from numba import cuda

cuda.select_device(0)
cuda.close()
