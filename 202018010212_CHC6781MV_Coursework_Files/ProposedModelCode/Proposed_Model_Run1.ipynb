# %%
# import zipfile

# f = zipfile.ZipFile("DRD_Split.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"DRD_Split_Cloud")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# # !pip install tensorflow-addons==0.18.0
# # !pip install scikit-learn
# !pip install seaborn

# %%
from tensorflow_addons.metrics import F1Score

# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

train_dir = 'DRD_Split_Cloud/DRD_Split/train'
test_dir = 'DRD_Split_Cloud/DRD_Split/test'

batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = 'DRD_Split_Cloud/DRD_Split/train/diabetic'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2708 images belonging to 2 classes.
# Found 404 images belonging to 2 classes.
# Found 550 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def simple_model_1(input_shape):
    inputs = Input(shape = input_shape)
    #Input convolution
    x = Conv2D(128, (3, 3), activation = 'leaky_relu',
               padding = 'same',kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)
    
    #First Dethwise Convolution
    x = Conv2D(64, (3, 3),  
               padding = 'same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)

    
    #Second convolutional layer
    x = Conv2D(32, (3, 3), 
               padding = 'same',kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = attention_block_2(x)
    x = MaxPooling2D(2, 2)(x)
    
    
    x = GlobalAveragePooling2D()(x)
    model_1 = Model(inputs, x)
    
    return model_1

def resnet_inception_simple(input_shape):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(32, (7, 7), strides=(1, 1), padding='same', activation='relu',
               kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual and Inception Blocks
    for filters in [32, 32, 64, 32]:
        # Residual Block
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x)
        x_r = BatchNormalization()(x_r)
        x_r = Conv2D(filters, (3, 3), strides=(1, 1), padding='same', 
                     activation='relu',kernel_initializer='he_normal')(x_r)
        x_r = BatchNormalization()(x_r)

        # Inception Block
        branch_0 = Conv2D(96, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_0 = BatchNormalization()(branch_0)

        branch_1 = Conv2D(64, (1, 1), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(x)
        branch_1 = BatchNormalization()(branch_1)
        branch_1 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_1)
        branch_1 = BatchNormalization()(branch_1)

        branch_2 = Conv2D(128, (1, 1), padding='same', activation='relu',
                          kernel_initializer='he_normal')(x)
        branch_2 = BatchNormalization()(branch_2)
        branch_2 = Conv2D(32, (3, 3), padding='same', 
                          activation='relu',kernel_initializer='he_normal')(branch_2)
        branch_2 = BatchNormalization()(branch_2)
#         branch_2 = Conv2D(64, (3, 3), padding='same', activation='relu')(branch_2)
#         branch_2 = BatchNormalization()(branch_2)

#         branch_3 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(x)
#         branch_3 = Conv2D(64, (1, 1), padding='same', activation='relu')(branch_3)
#         branch_3 = BatchNormalization()(branch_3)

        # Ensure concatenation along the channel axis
        x_i = concatenate([branch_0, branch_1,branch_2], axis = -1)
    
        # Make sure the number of filters after concatenation in x_i matches with x_r
        x_i = Conv2D(filters, (1, 1), padding = 'same', activation = 'relu')(x_i)
        x_i = BatchNormalization()(x_i)
        
        x_r = attention_block_2(x_r)
        x_i = attention_block_2(x_i)

        # Combine Residual and Inception Outputs
        x = Add()([x_r, x_i])
        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    model = Model(inputs, x)
    
    return model



def build_ensemble_model(input_shape):
    inputs = Input(shape = input_shape)

    model_1 = simple_model_1(input_shape)
    output1 = model_1(inputs) 
    
    IR_output = resnet_inception_simple(input_shape)(inputs)
    
    combined_result = concatenate([output1, IR_output])
    
    combined_result = Dropout(0.3)(combined_result)
    
    # 最后的分类层
    outputs = Dense(2, activation='softmax')(combined_result)
    model = Model(inputs = inputs, outputs=outputs)
    
    return model

# %%
model1 = simple_model_1(input_shape)
model1.summary()
# Out:
# 2023-12-08 16:47:16.755858: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-08 16:47:17.304761: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c1:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 12  3584        ['input_1[0][0]']
#                                 8)
#
#  batch_normalization (BatchNorm  (None, 224, 224, 12  512        ['conv2d[0][0]']
#  alization)                     8)
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 96  110688      ['batch_normalization[0][0]']
#                                 )
#
#  activation (Activation)        (None, 224, 224, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 224, 224, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 224, 224, 12  0           ['batch_normalization[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 12  0           ['multiply[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 64  73792       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 96  55392       ['activation_2[0][0]']
#                                 )
#
#  activation_3 (Activation)      (None, 112, 112, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 1)  97          ['activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 112, 112, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 112, 112, 64  0           ['activation_2[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['multiply_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   18464       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 32)  128         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 32)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 96)   27744       ['activation_5[0][0]']
#
#  activation_6 (Activation)      (None, 56, 56, 96)   0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 1)    97          ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 56, 56, 1)    0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 56, 56, 32)   0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 32)  0           ['multiply_2[0][0]']
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['max_pooling2d_2[0][0]']
#  alAveragePooling2D)
#
# ==================================================================================================
# Total params: 290,851
# Trainable params: 290,403
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %%
model2 = resnet_inception_simple(input_shape)
model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_9 (Conv2D)              (None, 224, 224, 32  4736        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 224, 224, 32  128        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 112, 112, 32  0          ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 112, 112, 64  2112        ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 112, 112, 12  4224        ['max_pooling2d_3[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 112, 112, 64  256        ['conv2d_13[0][0]']
#  rmalization)                   )
#
#  batch_normalization_9 (BatchNo  (None, 112, 112, 12  512        ['conv2d_15[0][0]']
#  rmalization)                   8)
#
#  conv2d_12 (Conv2D)             (None, 112, 112, 96  3168        ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 112, 112, 32  18464       ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 112, 112, 32  36896       ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 112, 112, 32  9248        ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 112, 112, 96  384        ['conv2d_12[0][0]']
#  rmalization)                   )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_14[0][0]']
#  rmalization)                   )
#
#  batch_normalization_10 (BatchN  (None, 112, 112, 32  128        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 32  128        ['conv2d_10[0][0]']
#  rmalization)                   )
#
#  concatenate (Concatenate)      (None, 112, 112, 16  0           ['batch_normalization_6[0][0]',
#                                 0)                                'batch_normalization_8[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 112, 112, 32  9248        ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 112, 112, 32  5152        ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 32  128        ['conv2d_11[0][0]']
#  rmalization)                   )
#
#  batch_normalization_11 (BatchN  (None, 112, 112, 32  128        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 112, 112, 96  27744       ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 112, 112, 96  27744       ['batch_normalization_11[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 112, 112, 96  0           ['conv2d_18[0][0]']
#                                 )
#
#  activation_10 (Activation)     (None, 112, 112, 96  0           ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 112, 112, 1)  97          ['activation_8[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 112, 112, 1)  97          ['activation_10[0][0]']
#
#  activation_9 (Activation)      (None, 112, 112, 1)  0           ['conv2d_19[0][0]']
#
#  activation_11 (Activation)     (None, 112, 112, 1)  0           ['conv2d_21[0][0]']
#
#  multiply_3 (Multiply)          (None, 112, 112, 32  0           ['batch_normalization_5[0][0]',
#                                 )                                 'activation_9[0][0]']
#
#  multiply_4 (Multiply)          (None, 112, 112, 32  0           ['batch_normalization_11[0][0]',
#                                 )                                 'activation_11[0][0]']
#
#  add (Add)                      (None, 112, 112, 32  0           ['multiply_3[0][0]',
#                                 )                                 'multiply_4[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 32)  0           ['add[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 56, 56, 64)   2112        ['max_pooling2d_4[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 56, 56, 128)  4224        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 56, 56, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 56, 56, 128)  512        ['conv2d_27[0][0]']
#  ormalization)
#
#  conv2d_24 (Conv2D)             (None, 56, 56, 96)   3168        ['max_pooling2d_4[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 56, 56, 32)   18464       ['batch_normalization_15[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 56, 56, 32)   36896       ['batch_normalization_17[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 56, 56, 32)   9248        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 56, 56, 96)  384         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 56, 56, 32)  128         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 56, 56, 32)  128         ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 160)  0           ['batch_normalization_14[0][0]',
#                                                                   'batch_normalization_16[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 56, 56, 32)   9248        ['batch_normalization_12[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 56, 56, 32)   5152        ['concatenate_1[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 56, 56, 32)  128         ['conv2d_29[0][0]']
#  ormalization)
#
#  conv2d_30 (Conv2D)             (None, 56, 56, 96)   27744       ['batch_normalization_13[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 56, 56, 96)   27744       ['batch_normalization_19[0][0]']
#
#  activation_12 (Activation)     (None, 56, 56, 96)   0           ['conv2d_30[0][0]']
#
#  activation_14 (Activation)     (None, 56, 56, 96)   0           ['conv2d_32[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 56, 56, 1)    97          ['activation_12[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 56, 56, 1)    97          ['activation_14[0][0]']
#
#  activation_13 (Activation)     (None, 56, 56, 1)    0           ['conv2d_31[0][0]']
#
#  activation_15 (Activation)     (None, 56, 56, 1)    0           ['conv2d_33[0][0]']
#
#  multiply_5 (Multiply)          (None, 56, 56, 32)   0           ['batch_normalization_13[0][0]',
#                                                                   'activation_13[0][0]']
#
#  multiply_6 (Multiply)          (None, 56, 56, 32)   0           ['batch_normalization_19[0][0]',
#                                                                   'activation_15[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 32)   0           ['multiply_5[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 32)  0           ['add_1[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 28, 28, 64)   2112        ['max_pooling2d_5[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 28, 28, 128)  4224        ['max_pooling2d_5[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 128)  512        ['conv2d_39[0][0]']
#  ormalization)
#
#  conv2d_36 (Conv2D)             (None, 28, 28, 96)   3168        ['max_pooling2d_5[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 28, 28, 32)   18464       ['batch_normalization_23[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 28, 28, 32)   36896       ['batch_normalization_25[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 28, 28, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 96)  384         ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 32)  128         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 28, 28, 32)  128         ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 64)  256         ['conv2d_34[0][0]']
#  ormalization)
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 160)  0           ['batch_normalization_22[0][0]',
#                                                                   'batch_normalization_24[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 28, 28, 64)   36928       ['batch_normalization_20[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 28, 28, 64)   10304       ['concatenate_2[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 28, 28, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  conv2d_42 (Conv2D)             (None, 28, 28, 96)   55392       ['batch_normalization_21[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 28, 28, 96)   55392       ['batch_normalization_27[0][0]']
#
#  activation_16 (Activation)     (None, 28, 28, 96)   0           ['conv2d_42[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 96)   0           ['conv2d_44[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 28, 28, 1)    97          ['activation_16[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 28, 28, 1)    97          ['activation_18[0][0]']
#
#  activation_17 (Activation)     (None, 28, 28, 1)    0           ['conv2d_43[0][0]']
#
#  activation_19 (Activation)     (None, 28, 28, 1)    0           ['conv2d_45[0][0]']
#
#  multiply_7 (Multiply)          (None, 28, 28, 64)   0           ['batch_normalization_21[0][0]',
#                                                                   'activation_17[0][0]']
#
#  multiply_8 (Multiply)          (None, 28, 28, 64)   0           ['batch_normalization_27[0][0]',
#                                                                   'activation_19[0][0]']
#
#  add_2 (Add)                    (None, 28, 28, 64)   0           ['multiply_7[0][0]',
#                                                                   'multiply_8[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 64)  0           ['add_2[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 64)   4160        ['max_pooling2d_6[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 14, 14, 128)  8320        ['max_pooling2d_6[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 64)  256         ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 96)   6240        ['max_pooling2d_6[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 32)   18464       ['batch_normalization_31[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 32)   36896       ['batch_normalization_33[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 32)   18464       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 96)  384         ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 32)  128         ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 32)  128         ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 32)  128         ['conv2d_46[0][0]']
#  ormalization)
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 160)  0           ['batch_normalization_30[0][0]',
#                                                                   'batch_normalization_32[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 32)   9248        ['batch_normalization_28[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 32)   5152        ['concatenate_3[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 32)  128         ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 32)  128         ['conv2d_53[0][0]']
#  ormalization)
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 96)   27744       ['batch_normalization_29[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 14, 14, 96)   27744       ['batch_normalization_35[0][0]']
#
#  activation_20 (Activation)     (None, 14, 14, 96)   0           ['conv2d_54[0][0]']
#
#  activation_22 (Activation)     (None, 14, 14, 96)   0           ['conv2d_56[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 1)    97          ['activation_20[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 14, 14, 1)    97          ['activation_22[0][0]']
#
#  activation_21 (Activation)     (None, 14, 14, 1)    0           ['conv2d_55[0][0]']
#
#  activation_23 (Activation)     (None, 14, 14, 1)    0           ['conv2d_57[0][0]']
#
#  multiply_9 (Multiply)          (None, 14, 14, 32)   0           ['batch_normalization_29[0][0]',
#                                                                   'activation_21[0][0]']
#
#  multiply_10 (Multiply)         (None, 14, 14, 32)   0           ['batch_normalization_35[0][0]',
#                                                                   'activation_23[0][0]']
#
#  add_3 (Add)                    (None, 14, 14, 32)   0           ['multiply_9[0][0]',
#                                                                   'multiply_10[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 32)    0           ['add_3[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 32)          0           ['max_pooling2d_7[0][0]']
#  obalAveragePooling2D)
#
# ==================================================================================================
# Total params: 705,000
# Trainable params: 701,160
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
ensemble_model = build_ensemble_model(input_shape)
ensemble_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  model_2 (Functional)           (None, 32)           290851      ['input_3[0][0]']
#
#  model_3 (Functional)           (None, 32)           705000      ['input_3[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 64)           0           ['model_2[0][0]',
#                                                                   'model_3[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['concatenate_8[0][0]']
#
#  dense (Dense)                  (None, 2)            130         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 995,981
# Trainable params: 991,693
# Non-trainable params: 4,288
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


def custum_accuracy(y_true, y_pred):
    # 将预测值四舍五入为0或1
    y_pred_rounded = K.round(y_pred)
    # 比较预测值和真实值
    correct_predictions = K.equal(y_true, y_pred_rounded)
    # 将布尔值转换为浮点数并计算平均值，得到准确率
    return K.mean(K.cast(correct_predictions, 'float32'))

def custom_categorical_crossentropy(y_true, y_pred):
    # 避免0值导致数值问题
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
    # 计算分类交叉熵
    crossentropy = -K.mean(K.sum(y_true * K.log(y_pred), axis=-1))
    return crossentropy


ensemble_model.compile(
    optimizer='adam',
    loss = custom_categorical_crossentropy,
    metrics=[
        custum_accuracy, 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)
lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)
early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=20, verbose=1, 
                               restore_best_weights=True)

# %%
history = ensemble_model.fit(train_generator, epochs = 100, validation_data=(validation_generator), callbacks = [lr_reduction, early_stopping])
# Out:
# Epoch 1/100
# 2023-12-08 16:47:25.244083: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-08 16:47:27.693141: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 85/85 [==============================] - 41s 369ms/step - loss: 0.3622 - custum_accuracy: 0.8490 - precision: 0.8490 - recall: 0.8490 - auc: 0.9213 - f1_score: 0.8490 - val_loss: 0.7592 - val_custum_accuracy: 0.5087 - val_precision: 0.5074 - val_recall: 0.5074 - val_auc: 0.6136 - val_f1_score: 0.5074 - lr: 0.0010
# Epoch 2/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.2644 - custum_accuracy: 0.8971 - precision: 0.8977 - recall: 0.8977 - auc: 0.9570 - f1_score: 0.8977 - val_loss: 0.7139 - val_custum_accuracy: 0.5327 - val_precision: 0.5322 - val_recall: 0.5322 - val_auc: 0.6374 - val_f1_score: 0.5322 - lr: 0.0010
# Epoch 3/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.2357 - custum_accuracy: 0.9190 - precision: 0.9195 - recall: 0.9195 - auc: 0.9656 - f1_score: 0.9195 - val_loss: 1.1380 - val_custum_accuracy: 0.5207 - val_precision: 0.5198 - val_recall: 0.5198 - val_auc: 0.6156 - val_f1_score: 0.5198 - lr: 0.0010
# Epoch 4/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.2249 - custum_accuracy: 0.9240 - precision: 0.9239 - recall: 0.9239 - auc: 0.9685 - f1_score: 0.9239 - val_loss: 1.3959 - val_custum_accuracy: 0.5274 - val_precision: 0.5297 - val_recall: 0.5297 - val_auc: 0.6063 - val_f1_score: 0.5297 - lr: 0.0010
# Epoch 5/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.2152 - custum_accuracy: 0.9243 - precision: 0.9247 - recall: 0.9247 - auc: 0.9705 - f1_score: 0.9247 - val_loss: 0.5134 - val_custum_accuracy: 0.6995 - val_precision: 0.6980 - val_recall: 0.6980 - val_auc: 0.8013 - val_f1_score: 0.6980 - lr: 0.0010
# Epoch 6/100
# 85/85 [==============================] - 29s 338ms/step - loss: 0.2060 - custum_accuracy: 0.9271 - precision: 0.9273 - recall: 0.9273 - auc: 0.9730 - f1_score: 0.9273 - val_loss: 0.3313 - val_custum_accuracy: 0.8659 - val_precision: 0.8663 - val_recall: 0.8663 - val_auc: 0.9311 - val_f1_score: 0.8663 - lr: 0.0010
# Epoch 7/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1916 - custum_accuracy: 0.9366 - precision: 0.9372 - recall: 0.9372 - auc: 0.9765 - f1_score: 0.9372 - val_loss: 0.2708 - val_custum_accuracy: 0.8750 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9554 - val_f1_score: 0.8787 - lr: 0.0010
# Epoch 8/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1930 - custum_accuracy: 0.9364 - precision: 0.9361 - recall: 0.9361 - auc: 0.9758 - f1_score: 0.9361 - val_loss: 0.3369 - val_custum_accuracy: 0.8558 - val_precision: 0.8589 - val_recall: 0.8589 - val_auc: 0.9376 - val_f1_score: 0.8589 - lr: 0.0010
# Epoch 9/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.1790 - custum_accuracy: 0.9374 - precision: 0.9376 - recall: 0.9376 - auc: 0.9795 - f1_score: 0.9376 - val_loss: 0.3866 - val_custum_accuracy: 0.8712 - val_precision: 0.8688 - val_recall: 0.8688 - val_auc: 0.9414 - val_f1_score: 0.8688 - lr: 0.0010
# Epoch 10/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1733 - custum_accuracy: 0.9471 - precision: 0.9468 - recall: 0.9468 - auc: 0.9796 - f1_score: 0.9468 - val_loss: 0.4112 - val_custum_accuracy: 0.8087 - val_precision: 0.8119 - val_recall: 0.8119 - val_auc: 0.9037 - val_f1_score: 0.8119 - lr: 0.0010
# Epoch 11/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1820 - custum_accuracy: 0.9413 - precision: 0.9413 - recall: 0.9413 - auc: 0.9782 - f1_score: 0.9413 - val_loss: 0.6409 - val_custum_accuracy: 0.6630 - val_precision: 0.6708 - val_recall: 0.6708 - val_auc: 0.8126 - val_f1_score: 0.6708 - lr: 0.0010
# Epoch 12/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.1655 - custum_accuracy: 0.9424 - precision: 0.9424 - recall: 0.9424 - auc: 0.9813 - f1_score: 0.9424 - val_loss: 0.1063 - val_custum_accuracy: 0.9736 - val_precision: 0.9728 - val_recall: 0.9728 - val_auc: 0.9938 - val_f1_score: 0.9728 - lr: 0.0010
# Epoch 13/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.1421 - custum_accuracy: 0.9535 - precision: 0.9535 - recall: 0.9535 - auc: 0.9857 - f1_score: 0.9535 - val_loss: 0.2551 - val_custum_accuracy: 0.8572 - val_precision: 0.8589 - val_recall: 0.8589 - val_auc: 0.9571 - val_f1_score: 0.8589 - lr: 0.0010
# Epoch 14/100
# 85/85 [==============================] - 29s 334ms/step - loss: 0.1306 - custum_accuracy: 0.9573 - precision: 0.9575 - recall: 0.9575 - auc: 0.9882 - f1_score: 0.9575 - val_loss: 0.1216 - val_custum_accuracy: 0.9577 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9905 - val_f1_score: 0.9579 - lr: 0.0010
# Epoch 15/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1337 - custum_accuracy: 0.9555 - precision: 0.9553 - recall: 0.9553 - auc: 0.9871 - f1_score: 0.9553 - val_loss: 0.1388 - val_custum_accuracy: 0.9490 - val_precision: 0.9505 - val_recall: 0.9505 - val_auc: 0.9864 - val_f1_score: 0.9505 - lr: 0.0010
# Epoch 16/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1410 - custum_accuracy: 0.9520 - precision: 0.9520 - recall: 0.9520 - auc: 0.9851 - f1_score: 0.9520 - val_loss: 0.2222 - val_custum_accuracy: 0.9072 - val_precision: 0.9059 - val_recall: 0.9059 - val_auc: 0.9705 - val_f1_score: 0.9059 - lr: 0.0010
# Epoch 17/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1207 - custum_accuracy: 0.9586 - precision: 0.9586 - recall: 0.9586 - auc: 0.9901 - f1_score: 0.9586 - val_loss: 0.1583 - val_custum_accuracy: 0.9370 - val_precision: 0.9381 - val_recall: 0.9381 - val_auc: 0.9839 - val_f1_score: 0.9381 - lr: 0.0010
# Epoch 18/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1080 - custum_accuracy: 0.9621 - precision: 0.9620 - recall: 0.9620 - auc: 0.9918 - f1_score: 0.9620 - val_loss: 0.0810 - val_custum_accuracy: 0.9817 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9967 - val_f1_score: 0.9827 - lr: 0.0010
# Epoch 19/100
# 85/85 [==============================] - 29s 334ms/step - loss: 0.1251 - custum_accuracy: 0.9590 - precision: 0.9590 - recall: 0.9590 - auc: 0.9885 - f1_score: 0.9590 - val_loss: 0.2201 - val_custum_accuracy: 0.9019 - val_precision: 0.9035 - val_recall: 0.9035 - val_auc: 0.9714 - val_f1_score: 0.9035 - lr: 0.0010
# Epoch 20/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1129 - custum_accuracy: 0.9647 - precision: 0.9645 - recall: 0.9645 - auc: 0.9905 - f1_score: 0.9645 - val_loss: 0.2140 - val_custum_accuracy: 0.9250 - val_precision: 0.9257 - val_recall: 0.9257 - val_auc: 0.9719 - val_f1_score: 0.9257 - lr: 0.0010
# Epoch 21/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.1224 - custum_accuracy: 0.9619 - precision: 0.9620 - recall: 0.9620 - auc: 0.9887 - f1_score: 0.9620 - val_loss: 0.1249 - val_custum_accuracy: 0.9625 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9910 - val_f1_score: 0.9629 - lr: 0.0010
# Epoch 22/100
# 85/85 [==============================] - 28s 333ms/step - loss: 0.1132 - custum_accuracy: 0.9593 - precision: 0.9597 - recall: 0.9597 - auc: 0.9910 - f1_score: 0.9597 - val_loss: 0.1711 - val_custum_accuracy: 0.9168 - val_precision: 0.9158 - val_recall: 0.9158 - val_auc: 0.9820 - val_f1_score: 0.9158 - lr: 0.0010
# Epoch 23/100
# 85/85 [==============================] - 29s 333ms/step - loss: 0.1275 - custum_accuracy: 0.9585 - precision: 0.9583 - recall: 0.9583 - auc: 0.9885 - f1_score: 0.9583 - val_loss: 0.1735 - val_custum_accuracy: 0.9260 - val_precision: 0.9282 - val_recall: 0.9282 - val_auc: 0.9804 - val_f1_score: 0.9282 - lr: 0.0010
# Epoch 24/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1083 - custum_accuracy: 0.9635 - precision: 0.9638 - recall: 0.9638 - auc: 0.9916 - f1_score: 0.9638 - val_loss: 0.0894 - val_custum_accuracy: 0.9697 - val_precision: 0.9703 - val_recall: 0.9703 - val_auc: 0.9952 - val_f1_score: 0.9703 - lr: 0.0010
# Epoch 25/100
# 85/85 [==============================] - 28s 331ms/step - loss: 0.1112 - custum_accuracy: 0.9662 - precision: 0.9660 - recall: 0.9660 - auc: 0.9900 - f1_score: 0.9660 - val_loss: 0.1007 - val_custum_accuracy: 0.9591 - val_precision: 0.9579 - val_recall: 0.9579 - val_auc: 0.9944 - val_f1_score: 0.9579 - lr: 0.0010
# Epoch 26/100
# 85/85 [==============================] - 28s 332ms/step - loss: 0.1086 - custum_accuracy: 0.9662 - precision: 0.9660 - recall: 0.9660 - auc: 0.9914 - f1_score: 0.9660 - val_loss: 0.1674 - val_custum_accuracy: 0.9553 - val_precision: 0.9554 - val_recall: 0.9554 - val_auc: 0.9826 - val_f1_score: 0.9554 - lr: 0.0010
# Epoch 27/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.1022 - custum_accuracy: 0.9691 - precision: 0.9690 - recall: 0.9690 - auc: 0.9922 - f1_score: 0.9690 - val_loss: 0.0911 - val_custum_accuracy: 0.9808 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9968 - val_f1_score: 0.9802 - lr: 0.0010
# Epoch 28/100
# 85/85 [==============================] - ETA: 0s - loss: 0.1012 - custum_accuracy: 0.9654 - precision: 0.9657 - recall: 0.9657 - auc: 0.9926 - f1_score: 0.9657
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 85/85 [==============================] - 29s 343ms/step - loss: 0.1012 - custum_accuracy: 0.9654 - precision: 0.9657 - recall: 0.9657 - auc: 0.9926 - f1_score: 0.9657 - val_loss: 0.1076 - val_custum_accuracy: 0.9611 - val_precision: 0.9629 - val_recall: 0.9629 - val_auc: 0.9927 - val_f1_score: 0.9629 - lr: 0.0010
# Epoch 29/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.1007 - custum_accuracy: 0.9649 - precision: 0.9649 - recall: 0.9649 - auc: 0.9930 - f1_score: 0.9649 - val_loss: 0.0675 - val_custum_accuracy: 0.9784 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9953 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 30/100
# 85/85 [==============================] - 28s 333ms/step - loss: 0.0895 - custum_accuracy: 0.9669 - precision: 0.9668 - recall: 0.9668 - auc: 0.9948 - f1_score: 0.9668 - val_loss: 0.0643 - val_custum_accuracy: 0.9880 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9958 - val_f1_score: 0.9876 - lr: 1.0000e-04
# Epoch 31/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0811 - custum_accuracy: 0.9705 - precision: 0.9708 - recall: 0.9708 - auc: 0.9955 - f1_score: 0.9708 - val_loss: 0.0837 - val_custum_accuracy: 0.9808 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9938 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 32/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0786 - custum_accuracy: 0.9754 - precision: 0.9753 - recall: 0.9753 - auc: 0.9956 - f1_score: 0.9753 - val_loss: 0.0860 - val_custum_accuracy: 0.9784 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9937 - val_f1_score: 0.9777 - lr: 1.0000e-04
# Epoch 33/100
# 85/85 [==============================] - 29s 334ms/step - loss: 0.0853 - custum_accuracy: 0.9687 - precision: 0.9690 - recall: 0.9690 - auc: 0.9946 - f1_score: 0.9690 - val_loss: 0.0828 - val_custum_accuracy: 0.9832 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9943 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 34/100
# 85/85 [==============================] - 29s 334ms/step - loss: 0.0796 - custum_accuracy: 0.9728 - precision: 0.9727 - recall: 0.9727 - auc: 0.9950 - f1_score: 0.9727 - val_loss: 0.0779 - val_custum_accuracy: 0.9841 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9948 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 35/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0779 - custum_accuracy: 0.9724 - precision: 0.9723 - recall: 0.9723 - auc: 0.9957 - f1_score: 0.9723 - val_loss: 0.0707 - val_custum_accuracy: 0.9832 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9949 - val_f1_score: 0.9827 - lr: 1.0000e-04
# Epoch 36/100
# 85/85 [==============================] - 29s 334ms/step - loss: 0.0836 - custum_accuracy: 0.9726 - precision: 0.9727 - recall: 0.9727 - auc: 0.9951 - f1_score: 0.9727 - val_loss: 0.0830 - val_custum_accuracy: 0.9808 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9945 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 37/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0668 - custum_accuracy: 0.9788 - precision: 0.9790 - recall: 0.9790 - auc: 0.9967 - f1_score: 0.9790 - val_loss: 0.0853 - val_custum_accuracy: 0.9793 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9947 - val_f1_score: 0.9802 - lr: 1.0000e-04
# Epoch 38/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0745 - custum_accuracy: 0.9781 - precision: 0.9782 - recall: 0.9782 - auc: 0.9957 - f1_score: 0.9782 - val_loss: 0.0687 - val_custum_accuracy: 0.9856 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9955 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 39/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0679 - custum_accuracy: 0.9787 - precision: 0.9786 - recall: 0.9786 - auc: 0.9965 - f1_score: 0.9786 - val_loss: 0.0746 - val_custum_accuracy: 0.9841 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9952 - val_f1_score: 0.9851 - lr: 1.0000e-04
# Epoch 40/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0754 - custum_accuracy: 0.9765 - precision: 0.9764 - recall: 0.9764 - auc: 0.9951 - f1_score: 0.9764
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 85/85 [==============================] - 29s 340ms/step - loss: 0.0754 - custum_accuracy: 0.9765 - precision: 0.9764 - recall: 0.9764 - auc: 0.9951 - f1_score: 0.9764 - val_loss: 0.0675 - val_custum_accuracy: 0.9880 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9955 - val_f1_score: 0.9876 - lr: 1.0000e-04
# Epoch 41/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0709 - custum_accuracy: 0.9728 - precision: 0.9727 - recall: 0.9727 - auc: 0.9967 - f1_score: 0.9727 - val_loss: 0.0815 - val_custum_accuracy: 0.9851 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9940 - val_f1_score: 0.9876 - lr: 1.0000e-05
# Epoch 42/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0674 - custum_accuracy: 0.9765 - precision: 0.9764 - recall: 0.9764 - auc: 0.9968 - f1_score: 0.9764 - val_loss: 0.0832 - val_custum_accuracy: 0.9793 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9952 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 43/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0698 - custum_accuracy: 0.9751 - precision: 0.9753 - recall: 0.9753 - auc: 0.9968 - f1_score: 0.9753 - val_loss: 0.0633 - val_custum_accuracy: 0.9880 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9960 - val_f1_score: 0.9876 - lr: 1.0000e-05
# Epoch 44/100
# 85/85 [==============================] - 29s 334ms/step - loss: 0.0625 - custum_accuracy: 0.9805 - precision: 0.9804 - recall: 0.9804 - auc: 0.9976 - f1_score: 0.9804 - val_loss: 0.0778 - val_custum_accuracy: 0.9832 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9952 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 45/100
# 85/85 [==============================] - 28s 331ms/step - loss: 0.0741 - custum_accuracy: 0.9743 - precision: 0.9742 - recall: 0.9742 - auc: 0.9963 - f1_score: 0.9742 - val_loss: 0.0707 - val_custum_accuracy: 0.9779 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9952 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 46/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0644 - custum_accuracy: 0.9784 - precision: 0.9790 - recall: 0.9790 - auc: 0.9972 - f1_score: 0.9790 - val_loss: 0.0654 - val_custum_accuracy: 0.9841 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9953 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 47/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0707 - custum_accuracy: 0.9766 - precision: 0.9767 - recall: 0.9767 - auc: 0.9968 - f1_score: 0.9767 - val_loss: 0.0747 - val_custum_accuracy: 0.9856 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9956 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 48/100
# 85/85 [==============================] - 28s 333ms/step - loss: 0.0694 - custum_accuracy: 0.9787 - precision: 0.9786 - recall: 0.9786 - auc: 0.9963 - f1_score: 0.9786 - val_loss: 0.0691 - val_custum_accuracy: 0.9856 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9954 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 49/100
# 85/85 [==============================] - 28s 333ms/step - loss: 0.0711 - custum_accuracy: 0.9750 - precision: 0.9749 - recall: 0.9749 - auc: 0.9963 - f1_score: 0.9749 - val_loss: 0.0689 - val_custum_accuracy: 0.9808 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9956 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 50/100
# 85/85 [==============================] - 28s 333ms/step - loss: 0.0668 - custum_accuracy: 0.9790 - precision: 0.9790 - recall: 0.9790 - auc: 0.9965 - f1_score: 0.9790 - val_loss: 0.0692 - val_custum_accuracy: 0.9865 - val_precision: 0.9876 - val_recall: 0.9876 - val_auc: 0.9955 - val_f1_score: 0.9876 - lr: 1.0000e-05
# Epoch 51/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0630 - custum_accuracy: 0.9794 - precision: 0.9793 - recall: 0.9793 - auc: 0.9973 - f1_score: 0.9793 - val_loss: 0.0781 - val_custum_accuracy: 0.9832 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9954 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 52/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0611 - custum_accuracy: 0.9794 - precision: 0.9793 - recall: 0.9793 - auc: 0.9969 - f1_score: 0.9793 - val_loss: 0.0807 - val_custum_accuracy: 0.9832 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9946 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 53/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0705 - custum_accuracy: 0.9766 - precision: 0.9767 - recall: 0.9767 - auc: 0.9959 - f1_score: 0.9767
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1e-05.
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0705 - custum_accuracy: 0.9766 - precision: 0.9767 - recall: 0.9767 - auc: 0.9959 - f1_score: 0.9767 - val_loss: 0.0804 - val_custum_accuracy: 0.9803 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9949 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 54/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0618 - custum_accuracy: 0.9793 - precision: 0.9797 - recall: 0.9797 - auc: 0.9977 - f1_score: 0.9797 - val_loss: 0.0743 - val_custum_accuracy: 0.9856 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9944 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 55/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0598 - custum_accuracy: 0.9820 - precision: 0.9819 - recall: 0.9819 - auc: 0.9973 - f1_score: 0.9819 - val_loss: 0.0743 - val_custum_accuracy: 0.9856 - val_precision: 0.9851 - val_recall: 0.9851 - val_auc: 0.9956 - val_f1_score: 0.9851 - lr: 1.0000e-05
# Epoch 56/100
# 85/85 [==============================] - 29s 334ms/step - loss: 0.0657 - custum_accuracy: 0.9772 - precision: 0.9771 - recall: 0.9771 - auc: 0.9969 - f1_score: 0.9771 - val_loss: 0.0708 - val_custum_accuracy: 0.9832 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9955 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 57/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0617 - custum_accuracy: 0.9774 - precision: 0.9775 - recall: 0.9775 - auc: 0.9976 - f1_score: 0.9775 - val_loss: 0.0672 - val_custum_accuracy: 0.9832 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9951 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 58/100
# 85/85 [==============================] - 29s 334ms/step - loss: 0.0606 - custum_accuracy: 0.9762 - precision: 0.9764 - recall: 0.9764 - auc: 0.9978 - f1_score: 0.9764 - val_loss: 0.0782 - val_custum_accuracy: 0.9832 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9952 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 59/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0648 - custum_accuracy: 0.9805 - precision: 0.9804 - recall: 0.9804 - auc: 0.9970 - f1_score: 0.9804 - val_loss: 0.0741 - val_custum_accuracy: 0.9793 - val_precision: 0.9802 - val_recall: 0.9802 - val_auc: 0.9959 - val_f1_score: 0.9802 - lr: 1.0000e-05
# Epoch 60/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0648 - custum_accuracy: 0.9781 - precision: 0.9782 - recall: 0.9782 - auc: 0.9970 - f1_score: 0.9782 - val_loss: 0.0815 - val_custum_accuracy: 0.9769 - val_precision: 0.9777 - val_recall: 0.9777 - val_auc: 0.9949 - val_f1_score: 0.9777 - lr: 1.0000e-05
# Epoch 61/100
# 85/85 [==============================] - 29s 335ms/step - loss: 0.0654 - custum_accuracy: 0.9790 - precision: 0.9790 - recall: 0.9790 - auc: 0.9964 - f1_score: 0.9790 - val_loss: 0.0879 - val_custum_accuracy: 0.9817 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9934 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 62/100
# 85/85 [==============================] - 29s 337ms/step - loss: 0.0572 - custum_accuracy: 0.9831 - precision: 0.9830 - recall: 0.9830 - auc: 0.9978 - f1_score: 0.9830 - val_loss: 0.0799 - val_custum_accuracy: 0.9803 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9945 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 63/100
# 85/85 [==============================] - ETA: 0s - loss: 0.0728 - custum_accuracy: 0.9754 - precision: 0.9753 - recall: 0.9753 - auc: 0.9958 - f1_score: 0.9753Restoring model weights from the end of the best epoch: 43.
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0728 - custum_accuracy: 0.9754 - precision: 0.9753 - recall: 0.9753 - auc: 0.9958 - f1_score: 0.9753 - val_loss: 0.0868 - val_custum_accuracy: 0.9832 - val_precision: 0.9827 - val_recall: 0.9827 - val_auc: 0.9951 - val_f1_score: 0.9827 - lr: 1.0000e-05
# Epoch 63: early stopping

# %%
plt.figure(figsize = (8, 8))
plt.plot(history.history['custum_accuracy'])
plt.plot(history.history['val_custum_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc ='lower right')
plt.show()


plt.figure(figsize=(8, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc ='upper right')
plt.show()

plt.figure(figsize=(8, 8))
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('precision')
plt.legend(['precision', 'val_precision'], loc = 'lower right')
plt.show()

plt.figure(figsize=(8, 8))
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'],loc='lower right')
plt.show()

plt.figure(figsize=(8, 8))
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model Auc')
plt.xlabel('Epoch')
plt.ylabel('Auc')
plt.legend(['Training Auc', 'Validation Auc'],loc='lower right')
plt.show()

# %%
plt.figure(figsize =(8, 8))
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc= 'lower right')
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = ensemble_model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 17/17 [==============================] - 2s 55ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9779304376048034
# F1-Score for each class: [0.97841727 0.97744361]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9774436090225563
# specificity: 0.9784172661870504

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = ensemble_model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 17/17 [==============================] - 1s 55ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = ensemble_model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 18/18 [==============================] - 2s 95ms/step - loss: 0.0693 - custum_accuracy: 0.9792 - precision: 0.9782 - recall: 0.9782 - auc: 0.9959 - f1_score: 0.9782
# Test loss: 0.06933257728815079
# Test accuracy: 0.9791666865348816
# Test precision: 0.9781818389892578
# Test recall: 0.9781818389892578
# Test AUC: 0.9958810210227966
# Test F1 Score: 0.978181779384613

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = ensemble_model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 17/17 [==============================] - 1s 55ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       278
#            1       0.98      0.98      0.98       266
#
#     accuracy                           0.98       544
#    macro avg       0.98      0.98      0.98       544
# weighted avg       0.98      0.98      0.98       544

# %%
import pandas as pd


# Generate a classification report (replace this with your actual data)
report = classification_report(all_true_labels, y_pred_labels, output_dict=True)

# Convert to DataFrame
report_df = pd.DataFrame(report).transpose()

# Drop the 'support' column, as it's not suitable for the heatmap
report_df = report_df.drop(columns=['support'])

# Draw the heatmap with the default colormap
plt.figure(figsize=(10, 6))
sns.heatmap(report_df, annot=True, cbar=False)
plt.title("Classification Report")
plt.show()

# %%
def generate_grad_cam(ensemble_model, img_array, target_layer, output_layer):
    grad_model = Model(
        [ensemble_model.inputs],
        [ensemble_model.get_layer(target_layer).output, ensemble_model.get_layer(output_layer).output]
    )

    with tf.GradientTape() as tape:
        conv_output, model_output = grad_model(img_array)
        loss = model_output[:, 1]  
    grads = tape.gradient(loss, conv_output)

    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    conv_output = conv_output.numpy()[0]
    pooled_grads = pooled_grads.numpy()
    for i in range(pooled_grads.shape[-1]):
        conv_output[:, :, i] *= pooled_grads[i]

    heatmap = np.mean(conv_output, axis=-1)
    heatmap = np.maximum(heatmap, 0)

    heatmap /= np.max(heatmap)
    return heatmap

output_layer_name1 = model1.output.name.split("/")[0]
output_layer_name2 = model2.output.name.split("/")[0]

num_images = 5

for i in range(num_images):
    batch = next(test_generator)

    img_array = batch[0]
    label = batch[1]
    #conv2d_8,multiply_9 ,multiply_10,add_3 (Add)

    heatmap1 = generate_grad_cam(model1, img_array, 'conv2d_8', output_layer_name1)
    heatmap2 = generate_grad_cam(model2, img_array, 'add_3', output_layer_name2)

    target_size = max(heatmap1.shape[0], heatmap2.shape[0]), max(heatmap1.shape[1], 
                                                                                    heatmap2.shape[1])
    heatmap1_resized = tf.image.resize(heatmap1[..., np.newaxis], target_size)[..., 0]
    heatmap2_resized = tf.image.resize(heatmap2[..., np.newaxis], target_size)[..., 0]
    # heatmap3_resized = tf.image.resize(heatmap3[..., np.newaxis], target_size)[..., 0]
    
    heatmap = (heatmap1_resized + heatmap2_resized) / 2.0

    heatmap_resized = tf.image.resize(heatmap[..., np.newaxis], (224, 224))[..., 0]
    heatmap_weighted = heatmap_resized * 1

    weighted_img = heatmap_weighted[..., np.newaxis] * img_array[0]
    weighted_img /= np.max(weighted_img) 

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img_array[0])
    plt.title(f'Original Image (Label: {label[0]})')

    plt.subplot(1, 3, 2)
    plt.imshow(weighted_img[..., 0],cmap='jet')
    plt.title('Weighted Image')

    plt.show()
